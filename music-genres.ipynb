# %% [markdown]
# # The Rise and Fall of Different Music Genres
# #### By: Will Slotterback, Erik Ryde, and Todd Roberts
# In deciding what to work on for this project we first thought about interesting datasets we could use. One dataset which came to mind was the Billboard Hot 100. Billboard has been tracking the top 100 most popular songs in the U.S. every week since the late 50's so they've amassed a massive dataset of musical tastes in the U.S. This data already provides a really interesting picture of changing preferences in the U.S. but on its own its hard to tease out broad musical trends. To do this we need a way to categorize the different songs. The obvious choice is to do it by genre, but Billboard doesn't have data on the genre of song, just its popularity. To get this data we instead need to turn to the Spotify API where we can correlate the genre of an artist with songs that artist has produced. Though this isn't a perfect method -- artists do often cross genres and produce new types of songs -- it is accurate enough to produce valuable results. Using this data we can then plot the rise and fall of different musical genres in American history and understand questions like: What is the most popular genre of all time? Spoiler: It's not Ska.

# %% [markdown]
# ## Gathering our Data
# The first step in collecting our data is scraping the Billboard Hot 100 to gather the list of most popular songs. Billboard used to provide an API for this, but has since deprecated it, so we chose instead to use the [billboard-top-100](https://github.com/darthbatman/billboard-top-100) library. Billboard chart urls follow the predictable pattern of `billboard.com/charts/*chart_name*/*date*` so this library takes a chart name, and a date, and scrapes the HTML for that chart in order to produce a list of the songs in that chart. We wrote a utility function around this  that allowed us to fetch all of the charts starting from a specific date and write them to a file. This function (and a few other utility functions) can be seen in our [source](https://github.com/slotterbackW/music-genres/blob/master/billboard-api/billboard.js).
#
# Running this function with the date: *August 9th, 1958* or the earliest date Billboard charts are available produced a very large dataset, as you can see below.

# %%
with open('./data/songs.txt') as songs_file:
    list_of_songs = songs_file.readlines()
    print(len(list_of_songs))
# Out:
# 314501

# %% [markdown]
# Wow that's a lot of music! For reference the average song is about three minutes long, so if you listened to all the songs in our dataset one after another it would take you 655 days, or over a year and a half.
#
# Our dataset is not complete, however. We want to be able to look at broad trends in the data we have, but right now the individual songs are too granular. We need to categorize these songs by their genre. As mentioned above, to do this we'll use the Spotify API to fetch the genre for a song's artist and then correlate that with the song. Unfortunately our data isn't the cleanest right now, so before we fetch genre's we need to clean it up a little bit.
#
# The first problem with our data is that the artist names we have don't always represent one artist. For example the 1960's classic *Stuck On You* lists "Elvis Presley With The Jordanaires" as the artist. As is obvious to human reader this is actually two artists, *Elvis Presley* and *The Jordanaires*, but the computer doesn't know that. Our method for solving this is to split artist names on a series of delimeters, and say that a song is officially by the first artist in that list.
#
# The other issue with our data is that there are lots of duplicates. Because especially successful songs will last on the Hot 100 chart for many weeks the same song could show up multiple times. We don't want to waste resources fetching the same artist name multiple times, so making sure the names of artists we have are unique is an important concern of ours.
#
# Ok let's get into some code. The first thing we'll do is grab the raw list of artists.

# %%
raw_artists = []
with open('./data/songs.txt') as songs_file:
    # Our data is separated by bar characters and artists are in column 2 (0-based)
    raw_artists = [line.split('|')[2] for line in songs_file]

# %% [markdown]
# Then we'll polish the raw artist data so that it only contains the primary artist we care about. To do this we'll use a method we wrote which splits a string based on a list of delimiters. [[source](https://github.com/slotterbackW/music-genres/blob/master/analysis_helpers.py#L20)]
#
# As mentioned above, we also want to remove duplicates from this data so to do that we'll store the names of our artists in a dictionary.

# %%
DELIMITERS = ['and', 'with', 'featuring', 'ft.', 'ft', '&', 'X']
# .split() only takes one argument, so we wrote our own "multi_split" function
# which splits a string based on a list of delimiters
from analysis_helpers import multi_split

# Now we'll use the delimiters to split artist names and grab the first one
# We also want to remove duplicates so we'll use a dictionary to store the results
artists = {}
for raw_artist in raw_artists[1:]:
    # We don't care about the value so we just use 0
    artists[multi_split(raw_artist, DELIMITERS)[0]] = 0
# Out:
# ['Ricky Nelson',
#  'Domenico Modugno',
#  'Perez Prado',
#  'Bobby Darin',
#  'Kalin Twins',
#  'Jack Scott',
#  'Elvis Presley',
#  'Duane Eddy',
#  'Jimmy Clanton',
#  'The Johnny Otis Show',
#  'The Coasters',
#  'Pat Boone',
#  'Peggy Lee',
#  'The Elegants',
#  'Frankie Avalon',
#  'Doris Day',
#  'The Danleers',
#  'Poni-Tails',
#  'Patti Page',
#  'Jody Reynolds',
#  'The Olympics',
#  'Johnny Cash',
#  'Jerry Butler',
#  'The Rinky-Dinks',
#  'Buddy Knox',
#  'Jimmie Rodgers',
#  'Bobby Freeman',
#  'Johnny Mathis',
#  'The Four Lads',
#  'Perry Como',
#  'Chuck Willis',
#  'The Crickets',
#  'Bobby Day',
#  'The Everly Brothers',
#  'Connie Francis',
#  'Don Gibson',
#  'Dean Martin',
#  'Big Bopper',
#  'Dean Martin',
#  'Buddy Holly',
#  'Jimmie Rodgers',
#  'Robin Luke',
#  'The Everly Brothers',
#  'Bobby Freeman',
#  'Jim Reeves',
#  'Nat King Cole',
#  'Sheb Wooley',
#  'The Slades',
#  'Clyde McPhatter',
#  'Bobby Hendricks',
#  'Faron Young',
#  'Eddie Cochran',
#  'Bobby Day',
#  'Elvis Presley',
#  'Tony',
#  'Jack Scott',
#  'Pat Boone',
#  'The Drifters',
#  'Gerry Granahan',
#  'Dion',
#  'Sam Cooke',
#  'Bobby Hamilton',
#  'Dean Martin',
#  'Eydie Gorme',
#  'Toni Arden',
#  'Jerry Lee Lewis',
#  'Bill Haley',
#  'The Platters',
#  'Jimmy Bowen',
#  'Lee Andrews',
#  'Paul Anka',
#  'Fats Domino',
#  'Little Anthony',
#  'The Diamonds',
#  "The Three G's",
#  'Marty Robbins',
#  'Jan',
#  'Royal Teens',
#  'Marty Robbins',
#  'The Diamonds',
#  'Nat King Cole',
#  'Tony Bennett',
#  'Kitty Wells',
#  'Little Willie John',
#  'Jimmie Rodgers',
#  'The Drifters',
#  'Johnny Cash',
#  'Boots Brown',
#  'Joe South',
#  'The Playmates',
#  'The Everly Brothers',
#  'Billy Vaughn',
#  'Robert',
#  'The Champs',
#  'The Champs',
#  'Jimmy Reed',
#  'Tennessee Ernie Ford',
#  'Eydie Gorme',
#  'Nat King Cole',
#  'The Kirby Stone Four',
#  'Domenico Modugno',
#  'The Elegants',
#  'Jack Scott',
#  'Ricky Nelson',
#  'Perez Prado',
#  'Jimmy Clanton',
#  'Kalin Twins',
#  'Duane Eddy',
#  'Peggy Lee',
#  'Bobby Darin',
#  'Frankie Avalon',
#  'The Johnny Otis Show',
#  'Elvis Presley',
#  'Doris Day',
#  'Pat Boone',
#  'Poni-Tails',
#  'The Everly Brothers',
#  'The Coasters',
#  'The Olympics',
#  'Dean Martin',
#  'The Danleers',
#  'Buddy Knox',
#  'Patti Page',
#  'Jimmie Rodgers',
#  'The Everly Brothers',
#  'The Rinky-Dinks',
#  'Robin Luke',
#  'The Crickets',
#  'Big Bopper',
#  'Johnny Mathis',
#  'Connie Francis',
#  'Jody Reynolds',
#  'Jerry Butler',
#  'Perry Como',
#  'Don Gibson',
#  'The Four Lads',
#  'Buddy Holly',
#  'Bobby Day',
#  'Johnny Cash',
#  'Dean Martin',
#  'Bobby Hendricks',
#  'Chuck Willis',
#  'Bobby Freeman',
#  'Eddie Cochran',
#  'Pat Boone',
#  'Bobby Freeman',
#  'Billy Vaughn',
#  'Nat King Cole',
#  'The Slades',
#  'Tony',
#  'Marty Robbins',
#  'Jerry Wallace',
#  'Clyde McPhatter',
#  'Sam Cooke',
#  'Elvis Presley',
#  'The Diamonds',
#  'Bobby Day',
#  'Jimmy Bowen',
#  'The Kirby Stone Four',
#  'Bobby Helms',
#  'Oscar McLollie',
#  'Bobby Hamilton',
#  'Little Anthony',
#  'Jimmie Rodgers',
#  'Jim Reeves',
#  'Little Willie John',
#  'Roger Williams',
#  'Faron Young',
#  'Paul Anka',
#  'Gerry Granahan',
#  'Toni Arden',
#  'The Four Preps',
#  'The Diamonds',
#  'The Jamies',
#  'The Upbeats',
#  'DeJohn Sisters',
#  'Jimmie Rodgers',
#  'The Champs',
#  'Jim Backus',
#  "The Three G's",
#  'Sheb Wooley',
#  'Jan',
#  'Boots Brown',
#  'Bill Doggett',
#  'The Platters',
#  'Royal Teens',
#  'Eydie Gorme',
#  'Betty Madigan',
#  'Janice Harper',
#  'Chuck Willis',
#  'The Quin-Tones',
#  'Dean Martin',
#  'Jimmy Reed',
#  'Jody Reynolds',
#  'Les Paul',
#  'Tommy Edwards',
#  'The Gaylords',
#  'Tommy Mara',
#  'The DeCastro Sisters',
#  'Count Basie',
#  'The Elegants',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'Jimmy Clanton',
#  'Jack Scott',
#  'Ricky Nelson',
#  'Perez Prado',
#  'Poni-Tails',
#  'Peggy Lee',
#  'Kalin Twins',
#  'Duane Eddy',
#  'The Johnny Otis Show',
#  'The Olympics',
#  'Doris Day',
#  'The Everly Brothers',
#  'Bobby Darin',
#  'Frankie Avalon',
#  'Pat Boone',
#  'Dean Martin',
#  'Jimmie Rodgers',
#  'Elvis Presley',
#  'Connie Francis',
#  'Robin Luke',
#  'Eddie Cochran',
#  'Bobby Day',
#  'Little Anthony',
#  'The Danleers',
#  'Buddy Knox',
#  'The Rinky-Dinks',
#  'Big Bopper',
#  'The Crickets',
#  'Buddy Holly',
#  'Patti Page',
#  'Johnny Mathis',
#  'The Coasters',
#  'Perry Como',
#  'Bobby Freeman',
#  'Marty Robbins',
#  'Billy Vaughn',
#  'Tommy Edwards',
#  'Bobby Day',
#  'Bobby Hendricks',
#  'Don Gibson',
#  'The Four Preps',
#  'Sam Cooke',
#  'Jerry Butler',
#  'Bobby Freeman',
#  'The Four Lads',
#  'Jerry Wallace',
#  'Chuck Willis',
#  'Jimmie Rodgers',
#  'Jimmy Bowen',
#  'The Diamonds',
#  'Elvis Presley',
#  'Johnny Cash',
#  'Nat King Cole',
#  'Chuck Berry',
#  'Tony',
#  'Les Paul',
#  'Dean Martin',
#  'The Jamies',
#  'Johnny Cash',
#  'Toni Arden',
#  'Pat Boone',
#  'George Hamilton IV',
#  'Eydie Gorme',
#  'Boots Brown',
#  'Betty Madigan',
#  'The Champs',
#  'Faron Young',
#  'Jody Reynolds',
#  'Ray Price',
#  'DeJohn Sisters',
#  'The Rivieras',
#  'Jim Reeves',
#  'Oscar McLollie',
#  'The Diamonds',
#  'The Tune Rockers',
#  'Paul Anka',
#  'Gogi Grant',
#  'Warren Storm',
#  'Cozy Cole',
#  'Jack Scott',
#  'Bobby Helms',
#  'The Drifters',
#  'Janice Harper',
#  'The Quin-Tones',
#  'Roger Williams',
#  'Chuck Willis',
#  'Jody Reynolds',
#  'Duane Eddy',
#  'The Upbeats',
#  'Sheb Wooley',
#  'The Shields',
#  'Dion',
#  'Dean Martin',
#  'David Seville',
#  'Little Willie John',
#  'The Slades',
#  'Eileen Rodgers',
#  'Domenico Modugno',
#  'The Elegants',
#  'The Everly Brothers',
#  'Jimmy Clanton',
#  'Ricky Nelson',
#  'Perez Prado',
#  'Jack Scott',
#  'Kalin Twins',
#  'Frankie Avalon',
#  'Jimmie Rodgers',
#  'Poni-Tails',
#  'Peggy Lee',
#  'Duane Eddy',
#  'The Olympics',
#  'Dean Martin',
#  'The Johnny Otis Show',
#  'Bobby Day',
#  'Bobby Darin',
#  'Doris Day',
#  'Eddie Cochran',
#  'The Everly Brothers',
#  'Tommy Edwards',
#  'Pat Boone',
#  'Little Anthony',
#  'Connie Francis',
#  'Elvis Presley',
#  'Patti Page',
#  'Buddy Knox',
#  'Robin Luke',
#  'Perry Como',
#  'Billy Vaughn',
#  'Bobby Hendricks',
#  'The Rinky-Dinks',
#  'Johnny Mathis',
#  'The Danleers',
#  'Buddy Holly',
#  'The Coasters',
#  'The Four Preps',
#  'Marty Robbins',
#  'Big Bopper',
#  'Sam Cooke',
#  'The Crickets',
#  'The Quin-Tones',
#  'Bobby Freeman',
#  'Jimmie Rodgers',
#  'Nat King Cole',
#  'Bobby Day',
#  'Jerry Butler',
#  'Les Paul',
#  'Jerry Wallace',
#  'Chuck Willis',
#  'Don Gibson',
#  'Duane Eddy',
#  'Johnny Cash',
#  'Roger Williams',
#  'Chuck Berry',
#  'The Jamies',
#  'Johnny Cash',
#  'Jimmy Bowen',
#  'The Tune Rockers',
#  'The Diamonds',
#  'Betty Madigan',
#  'Boots Brown',
#  'Eydie Gorme',
#  'Chuck Willis',
#  'Jody Reynolds',
#  'The Champs',
#  'George Hamilton IV',
#  'The Shields',
#  'Elvis Presley',
#  'The Four Lads',
#  'Ray Price',
#  'The Rivieras',
#  'The Tommy Dorsey Orchestra',
#  'Bobby Freeman',
#  'Tony',
#  'Tommy Mara',
#  'David Seville',
#  'Andy Williams',
#  'The McGuire Sisters',
#  'Cozy Cole',
#  'Janice Harper',
#  'Gogi Grant',
#  'Dion',
#  'Dale Wright',
#  'Eileen Rodgers',
#  'Pat Boone',
#  'Dean Martin',
#  'Jack Scott',
#  'Warren Storm',
#  'Oscar McLollie',
#  'Jody Reynolds',
#  'The Playboys',
#  'Tommy Sands',
#  'The Chargers',
#  'The Kingsmen',
#  'Johnnie Ray',
#  'Dale Hawkins',
#  'Teresa Brewer',
#  'Jill Corey',
#  'Domenico Modugno',
#  'The Elegants',
#  'The Everly Brothers',
#  'Jimmy Clanton',
#  'Perez Prado',
#  'Ricky Nelson',
#  'Jack Scott',
#  'Bobby Day',
#  'Frankie Avalon',
#  'The Olympics',
#  'Tommy Edwards',
#  'Peggy Lee',
#  'Little Anthony',
#  'Poni-Tails',
#  'Dean Martin',
#  'Jimmie Rodgers',
#  'The Johnny Otis Show',
#  'Doris Day',
#  'Duane Eddy',
#  'Connie Francis',
#  'Kalin Twins',
#  'The Everly Brothers',
#  'The Quin-Tones',
#  'Pat Boone',
#  'Roger Williams',
#  'Billy Vaughn',
#  'The Four Preps',
#  'Robin Luke',
#  'Perry Como',
#  'Johnny Cash',
#  'Eddie Cochran',
#  'The Danleers',
#  'Buddy Knox',
#  'Big Bopper',
#  'Sam Cooke',
#  'Bobby Hendricks',
#  'Johnny Mathis',
#  'The Rinky-Dinks',
#  'Marty Robbins',
#  'Les Paul',
#  'Nat King Cole',
#  'Betty Madigan',
#  'Dion',
#  'The Tommy Dorsey Orchestra',
#  'Bobby Darin',
#  'The Shields',
#  'Buddy Holly',
#  'The Jamies',
#  'Don Gibson',
#  'Bobby Freeman',
#  'Duane Eddy',
#  'Chuck Berry',
#  'Bobby Day',
#  'Jimmie Rodgers',
#  'Patti Page',
#  'Elvis Presley',
#  'Johnny Cash',
#  'Jerry Wallace',
#  'The Tune Rockers',
#  'The Crickets',
#  'Chuck Willis',
#  'Boots Brown',
#  'Eydie Gorme',
#  'The Four Lads',
#  'Jimmy Bowen',
#  'Cozy Cole',
#  'The Champs',
#  'Andy Williams',
#  'Eileen Rodgers',
#  'Dale Hawkins',
#  'Ray Price',
#  'George Hamilton IV',
#  'Chuck Willis',
#  'The Coasters',
#  'George Hamilton IV',
#  'Tommy Mara',
#  'Dale Wright',
#  'Jim Reeves',
#  'Faron Young',
#  'The Diamonds',
#  'Johnnie Ray',
#  'The Rivieras',
#  'Gogi Grant',
#  'The Kingsmen',
#  'Jerry Lee Lewis',
#  'Pat Boone',
#  'The Playboys',
#  'Tony Bennett',
#  'Tommy Sands',
#  'Oscar McLollie',
#  'Little Willie John',
#  'Ray Price',
#  'Carl Smith',
#  'Ivory Joe Hunter',
#  'Robert Mitchum',
#  'Doug Franklin',
#  'Jody Reynolds',
#  'Jack Scott',
#  'Dean Martin',
#  'Tony',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'The Elegants',
#  'Tommy Edwards',
#  'Jimmy Clanton',
#  'Bobby Day',
#  'Poni-Tails',
#  'The Olympics',
#  'Little Anthony',
#  'Robin Luke',
#  'Perez Prado',
#  'Jack Scott',
#  'Ricky Nelson',
#  'The Everly Brothers',
#  'Jimmie Rodgers',
#  'Eddie Cochran',
#  'Frankie Avalon',
#  'Connie Francis',
#  'Doris Day',
#  'The Quin-Tones',
#  'Dean Martin',
#  'Peggy Lee',
#  'The Four Preps',
#  'Johnny Cash',
#  'Jerry Wallace',
#  'Roger Williams',
#  'Marty Robbins',
#  'Duane Eddy',
#  'Chuck Berry',
#  'The Jamies',
#  'The Tommy Dorsey Orchestra',
#  'The Johnny Otis Show',
#  'The Shields',
#  'Betty Madigan',
#  'Big Bopper',
#  'Buddy Knox',
#  'Dion',
#  'Les Paul',
#  'Sam Cooke',
#  'Kalin Twins',
#  'Duane Eddy',
#  'Billy Vaughn',
#  'The Danleers',
#  'Tony Bennett',
#  'Jimmie Rodgers',
#  'Perry Como',
#  'Bobby Hendricks',
#  'The Tune Rockers',
#  'Andy Williams',
#  'Cozy Cole',
#  'Nat King Cole',
#  'Buddy Holly',
#  'Johnny Mathis',
#  'Eileen Rodgers',
#  'Pat Boone',
#  'Chuck Willis',
#  'Bobby Freeman',
#  'Bobby Darin',
#  'Harvey',
#  'Bobby Day',
#  'Joni James',
#  'The Playboys',
#  'Dale Hawkins',
#  'Don Gibson',
#  'Conway Twitty',
#  'Boots Brown',
#  'Jimmy Bowen',
#  'The Crickets',
#  'The Rinky-Dinks',
#  'Gordon MacRae',
#  'Patti Page',
#  'Little Richard',
#  'Jerry Lee Lewis',
#  'Tommy Sands',
#  'Doug Franklin',
#  'The Applejacks',
#  'The Rivieras',
#  'Elvis Presley',
#  'Tommy Mara',
#  'The Champs',
#  'The Slades',
#  'Jody Reynolds',
#  'Faron Young',
#  'The Redjacks',
#  'Jan',
#  'The Kingsmen',
#  'Earl Grant',
#  'Robert Mitchum',
#  'Jim Reeves',
#  'The Coasters',
#  'Johnny Cash',
#  'Cozy Cole',
#  'Dale Wright',
#  'Chuck Willis',
#  'The Diamonds',
#  'Johnnie Ray',
#  'Eydie Gorme',
#  'The Platters',
#  'George Hamilton IV',
#  'The Four Lads',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'Tommy Edwards',
#  'The Elegants',
#  'Bobby Day',
#  'Jimmy Clanton',
#  'Little Anthony',
#  'Robin Luke',
#  'Poni-Tails',
#  'The Everly Brothers',
#  'Eddie Cochran',
#  'Roger Williams',
#  'Jack Scott',
#  'Jerry Wallace',
#  'Perez Prado',
#  'The Olympics',
#  'Connie Francis',
#  'Doris Day',
#  'Ricky Nelson',
#  'The Tommy Dorsey Orchestra',
#  'The Four Preps',
#  'The Quin-Tones',
#  'Chuck Berry',
#  'Jimmie Rodgers',
#  'Johnny Cash',
#  'The Jamies',
#  'Frankie Avalon',
#  'Dion',
#  'Dean Martin',
#  'Tony Bennett',
#  'The Shields',
#  'Les Paul',
#  'Peggy Lee',
#  'Big Bopper',
#  'Andy Williams',
#  'Buddy Knox',
#  'Duane Eddy',
#  'Marty Robbins',
#  'Sam Cooke',
#  'Betty Madigan',
#  'Conway Twitty',
#  'The Johnny Otis Show',
#  'Cozy Cole',
#  'The Tune Rockers',
#  'Eileen Rodgers',
#  'Harvey',
#  'Gordon MacRae',
#  'Bobby Day',
#  'Earl Grant',
#  'Tommy Sands',
#  'Joni James',
#  'Duane Eddy',
#  'Nat King Cole',
#  'Pat Boone',
#  'Jimmie Rodgers',
#  'Patti Page',
#  'Bobby Hendricks',
#  'The Danleers',
#  'The Champs',
#  'Jane Morgan',
#  'Billy Vaughn',
#  'Dale Hawkins',
#  'Little Richard',
#  'Kalin Twins',
#  'The Applejacks',
#  'Johnny Mathis',
#  'The Playboys',
#  'Perry Como',
#  'Pat Boone',
#  'Jerry Lee Lewis',
#  'Cozy Cole',
#  'Bobby Darin',
#  'The Rinky-Dinks',
#  'Ruth Brown',
#  'Bobby Freeman',
#  'Georgie Young',
#  'Ritchie Valens',
#  'Dale Wright',
#  'Boots Brown',
#  'Doug Franklin',
#  'The Four Esquires',
#  'Pat Boone',
#  'George Hamilton IV',
#  'The Four Coins',
#  'Ivan',
#  'The Slades',
#  'Don Gibson',
#  'The Teddy Bears',
#  'The Redjacks',
#  'Jody Reynolds',
#  'The Platters',
#  'Fats Domino',
#  'Eddie Fontaine',
#  'Elvis Presley',
#  'Jimmy Bowen',
#  'Jackie Wilson',
#  'Sonny James',
#  'Steve Lawrence',
#  'George Hamilton IV',
#  'The Swallows',
#  'Tommy Edwards',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'Bobby Day',
#  'The Elegants',
#  'Little Anthony',
#  'Robin Luke',
#  'Eddie Cochran',
#  'Jimmy Clanton',
#  'Roger Williams',
#  'Poni-Tails',
#  'The Everly Brothers',
#  'Jerry Wallace',
#  'The Tommy Dorsey Orchestra',
#  'Earl Grant',
#  'Big Bopper',
#  'Connie Francis',
#  'Chuck Berry',
#  'Jack Scott',
#  'Perez Prado',
#  'The Shields',
#  'Doris Day',
#  'Tony Bennett',
#  'The Four Preps',
#  'Andy Williams',
#  'The Olympics',
#  'The Quin-Tones',
#  'The Jamies',
#  'Jimmie Rodgers',
#  'Dion',
#  'Dean Martin',
#  'Eileen Rodgers',
#  'Conway Twitty',
#  'Les Paul',
#  'Buddy Knox',
#  'Ricky Nelson',
#  'Sam Cooke',
#  'Duane Eddy',
#  'Cozy Cole',
#  'Peggy Lee',
#  'Marty Robbins',
#  'Bobby Hendricks',
#  'Gordon MacRae',
#  'Billy Vaughn',
#  'Dale Hawkins',
#  'Pat Boone',
#  'The Johnny Otis Show',
#  'Patti Page',
#  'Harvey',
#  'The Tune Rockers',
#  'The Applejacks',
#  'Jerry Lee Lewis',
#  'Jane Morgan',
#  'The Four Esquires',
#  'Pat Boone',
#  'Little Richard',
#  'Ruth Brown',
#  'Bobby Day',
#  'The Ames Brothers',
#  'The Ames Brothers',
#  'Betty Madigan',
#  'Joni James',
#  'The Platters',
#  'Frankie Avalon',
#  'Johnny Cash',
#  'Don Gibson',
#  'The Slades',
#  'Tommy Sands',
#  'Georgie Young',
#  'Boots Brown',
#  'Nat King Cole',
#  'Ed Townsend',
#  'Eddie Fontaine',
#  'Johnny Mathis',
#  'The Four Coins',
#  'Ritchie Valens',
#  'Dale Wright',
#  'Bobby Freeman',
#  'Don Gibson',
#  'The Teddy Bears',
#  'Pat Boone',
#  'Johnny Mathis',
#  'The Kingston Trio',
#  'The Playboys',
#  'Ivan',
#  'Kalin Twins',
#  'The Playmates',
#  'Cozy Cole',
#  'Jack Scott',
#  'Perry Como',
#  'Cyclones',
#  'Lee Allen',
#  'Jackie Wilson',
#  'Sonny James',
#  'George Hamilton IV',
#  'Dicky Doo',
#  'Steve Lawrence',
#  'The Rinky-Dinks',
#  'Robert Mitchum',
#  'Kalin Twins',
#  'Tommy Edwards',
#  'The Everly Brothers',
#  'Bobby Day',
#  'Domenico Modugno',
#  'The Elegants',
#  'Little Anthony',
#  'Robin Luke',
#  'The Tommy Dorsey Orchestra',
#  'Eddie Cochran',
#  'Roger Williams',
#  'Jerry Wallace',
#  'Jimmy Clanton',
#  'Earl Grant',
#  'Poni-Tails',
#  'Big Bopper',
#  'The Shields',
#  'Andy Williams',
#  'Perez Prado',
#  'Chuck Berry',
#  'Conway Twitty',
#  'The Everly Brothers',
#  'Cozy Cole',
#  'Tony Bennett',
#  'Jack Scott',
#  'Bobby Hendricks',
#  'Eileen Rodgers',
#  'Dion',
#  'Connie Francis',
#  'Buddy Knox',
#  'Jimmie Rodgers',
#  'The Quin-Tones',
#  'The Olympics',
#  'The Four Preps',
#  'The Ames Brothers',
#  'Pat Boone',
#  'The Jamies',
#  'The Kingston Trio',
#  'Peggy Lee',
#  'Gordon MacRae',
#  'The Applejacks',
#  'Sam Cooke',
#  'The Platters',
#  'Dean Martin',
#  'Dale Hawkins',
#  'Doris Day',
#  'Patti Page',
#  'Ricky Nelson',
#  'Jane Morgan',
#  'Duane Eddy',
#  'Ruth Brown',
#  'Joni James',
#  'Les Paul',
#  'Billy Vaughn',
#  'Pat Boone',
#  'Little Richard',
#  'The Teddy Bears',
#  'The Four Esquires',
#  'Marty Robbins',
#  'Ed Townsend',
#  'Johnny Mathis',
#  'The Tune Rockers',
#  'Don Gibson',
#  'Georgie Young',
#  'Eddie Fontaine',
#  'The Ames Brothers',
#  'Frankie Avalon',
#  'The Johnny Otis Show',
#  'Harvey',
#  'Betty Johnson',
#  'Johnny Cash',
#  'Don Gibson',
#  'The Four Coins',
#  'Georgia Gibbs',
#  'Jack Scott',
#  'Kalin Twins',
#  'The Slades',
#  'The Playboys',
#  'Cozy Cole',
#  'Robert Mitchum',
#  'Jerry Lee Lewis',
#  'The Playmates',
#  'Pat Boone',
#  'Cyclones',
#  'Ritchie Valens',
#  'Tommy Sands',
#  'Dicky Doo',
#  'Johnny Tillotson',
#  'Johnny Cash',
#  'Ivan',
#  'Clyde McPhatter',
#  'Bobby Day',
#  'Donnie Owens',
#  'The Platters',
#  'Betty Madigan',
#  'Bobby Darin',
#  "Lord Rockingham's XI",
#  'The Five Blobs',
#  'Paul Anka',
#  'Teresa Brewer',
#  'Andy Rose',
#  'Tommy Edwards',
#  'Bobby Day',
#  'The Everly Brothers',
#  'Little Anthony',
#  'Robin Luke',
#  'Domenico Modugno',
#  'Earl Grant',
#  'The Elegants',
#  'The Tommy Dorsey Orchestra',
#  'Roger Williams',
#  'Big Bopper',
#  'Eddie Cochran',
#  'Cozy Cole',
#  'Jimmy Clanton',
#  'The Shields',
#  'Conway Twitty',
#  'The Kingston Trio',
#  'Jerry Wallace',
#  'The Everly Brothers',
#  'Tony Bennett',
#  'Poni-Tails',
#  'Andy Williams',
#  'Pat Boone',
#  'Dion',
#  'Jane Morgan',
#  'Jimmie Rodgers',
#  'The Applejacks',
#  'Eileen Rodgers',
#  'The Ames Brothers',
#  'Perez Prado',
#  'Jack Scott',
#  'Dale Hawkins',
#  'Sam Cooke',
#  'Chuck Berry',
#  'The Quin-Tones',
#  'Bobby Hendricks',
#  'Buddy Knox',
#  'Ruth Brown',
#  'Gordon MacRae',
#  'The Teddy Bears',
#  'Harvey',
#  'The Olympics',
#  'Connie Francis',
#  'Pat Boone',
#  'The Jamies',
#  'Johnny Mathis',
#  'Georgia Gibbs',
#  'Patti Page',
#  'Les Paul',
#  'Little Richard',
#  'The Platters',
#  'Jack Scott',
#  'The Ames Brothers',
#  'The Tune Rockers',
#  'Cozy Cole',
#  'Peggy Lee',
#  'Doris Day',
#  'Georgie Young',
#  'Ed Townsend',
#  'The Slades',
#  'Joni James',
#  'Kalin Twins',
#  'Dicky Doo',
#  'Duane Eddy',
#  'Marty Robbins',
#  'Dean Martin',
#  'Don Gibson',
#  'Ivan',
#  'Don Gibson',
#  'Ricky Nelson',
#  'Ricky Nelson',
#  'The Four Preps',
#  'Betty Johnson',
#  'Teresa Brewer',
#  'Johnny Cash',
#  'Donnie Owens',
#  'Robert Mitchum',
#  'Bobby Darin',
#  'The Four Esquires',
#  'Ritchie Valens',
#  'Paul Anka',
#  'Frankie Avalon',
#  'The Five Blobs',
#  'Tommy Sands',
#  'Perez Prado',
#  'Connie Francis',
#  'Perry Como',
#  'Johnny Cash',
#  'Jerry Vale',
#  'Betty Madigan',
#  'Bobby Day',
#  'Andy Rose',
#  'Jerry Lee Lewis',
#  'Mitch Miller',
#  'Frankie Avalon',
#  'Jack Scott',
#  'Nat King Cole',
#  'Billy Vaughn',
#  'Johnny Tillotson',
#  'Frankie Avalon',
#  ...]

# %% [markdown]
# Now that we have a collection of unique artist names the next step is to fetch the genres for those artists from the Spotify API. This is so that we can correlate the genre of an artist with their songs and eventually do our analysis. Our methodology for this is to use Spotify's search API to search for the name of the artist and then say that the first result returned is the artist we're looking for. We'll then grab the genres listed for that artist and write the artist's name and genres to a file. The result of this process (which you can see in our [source](https://github.com/slotterbackW/music-genres/blob/master/spotify.py#L25)) is shown below.

# %%
artist_genres = {}
with open('./data/artists.txt') as artists_file:
    header = artists_file.readline()
    for line in artists_file:
        split_line = line.strip().split('|')
        artist_genres[split_line[0]] = eval(split_line[2])
artist_genres
# Out:
# {'Ricky Nelson': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'lounge',
#   'merseybeat',
#   'nashville sound',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Domenico Modugno': ['classic italian pop', 'italian pop'],
#  'Bobby Darin': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'swing',
#   'vocal jazz'],
#  'Kalin Twins': [],
#  'Jack Scott': ['brill building pop',
#   'deep adult standards',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'Elvis Presley': ['christmas', 'rock-and-roll', 'rockabilly'],
#  'Duane Eddy': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'surf music'],
#  'Jimmy Clanton': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'swamp pop'],
#  'The Coasters': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'lounge',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'Pat Boone': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'rock-and-roll',
#   'rockabilly'],
#  'Peggy Lee': ['adult standards',
#   'cabaret',
#   'christmas',
#   'lounge',
#   'swing',
#   'vocal jazz'],
#  'The Elegants': ['doo-wop', 'rhythm and blues'],
#  'Frankie Avalon': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'Doris Day': ['adult standards',
#   'brill building pop',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'The Danleers': ['doo-wop'],
#  'Patti Page': ['adult standards',
#   'brill building pop',
#   'cabaret',
#   'christmas',
#   'deep adult standards',
#   'easy listening',
#   'lounge',
#   'nashville sound'],
#  'Jody Reynolds': [],
#  'The Olympics': ['doo-wop', 'rhythm and blues'],
#  'Johnny Cash': ['outlaw country', 'traditional country'],
#  'Jerry Butler': ['beach music',
#   'brill building pop',
#   'chicago soul',
#   'classic soul',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'soul'],
#  'Buddy Knox': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Jimmie Rodgers': ['appalachian folk',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'old-time',
#   'outlaw country',
#   'traditional blues',
#   'traditional country',
#   'traditional folk',
#   'western swing'],
#  'Bobby Freeman': ['doo-wop', 'rhythm and blues', 'rock-and-roll'],
#  'Johnny Mathis': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'mellow gold',
#   'operatic pop',
#   'vocal jazz'],
#  'The Four Lads': ['adult standards',
#   'christmas',
#   'deep adult standards',
#   'vocal harmony group'],
#  'Perry Como': ['adult standards',
#   'brill building pop',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'Chuck Willis': ['doo-wop',
#   'jazz blues',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Crickets': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'Bobby Day': ['doo-wop', 'rhythm and blues', 'rock-and-roll', 'rockabilly'],
#  'The Everly Brothers': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'lounge',
#   'mellow gold',
#   'nashville sound',
#   'rock-and-roll',
#   'rockabilly'],
#  'Connie Francis': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'easy listening',
#   'lounge',
#   'rock-and-roll',
#   'rockabilly'],
#  'Don Gibson': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'rockabilly',
#   'traditional country',
#   'western swing'],
#  'Dean Martin': ['adult standards',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'Buddy Holly': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'rock-and-roll',
#   'rockabilly'],
#  'Robin Luke': [],
#  'Jim Reeves': ['adult standards',
#   'christmas',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country'],
#  'Nat King Cole': ['adult standards', 'christmas', 'vocal jazz'],
#  'Sheb Wooley': ['comic'],
#  'The Slades': [],
#  'Clyde McPhatter': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Bobby Hendricks': [],
#  'Faron Young': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Eddie Cochran': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Drifters': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'lounge',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'Gerry Granahan': [],
#  'Dion': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'lounge',
#   'rock-and-roll',
#   'rockabilly'],
#  'Sam Cooke': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'classic soul',
#   'rock-and-roll',
#   'soul'],
#  'Bobby Hamilton': [],
#  'Toni Arden': [],
#  'Jerry Lee Lewis': ['adult standards',
#   'brill building pop',
#   'piano rock',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country'],
#  'The Platters': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'lounge',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'vocal jazz'],
#  'Jimmy Bowen': [],
#  'Lee Andrews': ['doo-wop'],
#  'Paul Anka': ['adult standards',
#   'brill building pop',
#   'canadian pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'rock-and-roll',
#   'rockabilly'],
#  'Fats Domino': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'louisiana blues',
#   'lounge',
#   'new orleans blues',
#   'piano blues',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'Little Anthony': [],
#  'The Diamonds': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Marty Robbins': ['christmas',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country'],
#  'Royal Teens': [],
#  'Tony Bennett': ['adult standards',
#   'christmas',
#   'easy listening',
#   'vocal jazz'],
#  'Kitty Wells': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Little Willie John': ['rhythm and blues',
#   'rock-and-roll',
#   'soul',
#   'southern soul'],
#  'Joe South': ['bubblegum pop', 'folk rock', 'merseybeat'],
#  'The Playmates': [],
#  'Billy Vaughn': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'romantico',
#   'space age pop'],
#  'The Champs': ['rock-and-roll', 'rockabilly'],
#  'Jimmy Reed': ['blues',
#   'blues-rock',
#   'chicago blues',
#   'electric blues',
#   'harmonica blues',
#   'rhythm and blues',
#   'rock-and-roll',
#   'traditional blues'],
#  'Tennessee Ernie Ford': ['christmas',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Jerry Wallace': ['country gospel', 'nashville sound'],
#  'Bobby Helms': ['christmas'],
#  'Oscar McLollie': ['jump blues'],
#  'Roger Williams': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge'],
#  'The Four Preps': ['christmas',
#   'deep adult standards',
#   'vocal harmony group'],
#  'The Jamies': [],
#  'The Upbeats': ['drum and bass', 'jungle', 'liquid funk', 'neurofunk'],
#  'Jim Backus': [],
#  'Bill Doggett': ['jazz organ', 'rhythm and blues', 'soul jazz'],
#  'Betty Madigan': [],
#  'The Quin-Tones': ['classic girl group'],
#  'Les Paul': ['space age pop'],
#  'Tommy Edwards': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'deep adult standards',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'The Gaylords': ['deep adult standards', 'vocal harmony group'],
#  'Tommy Mara': [],
#  'The DeCastro Sisters': ['deep adult standards'],
#  'Count Basie': ['adult standards',
#   'bebop',
#   'big band',
#   'christmas',
#   'cool jazz',
#   'jazz',
#   'jazz piano',
#   'lounge',
#   'stride',
#   'swing',
#   'vocal jazz'],
#  'Chuck Berry': ['blues-rock',
#   'christmas',
#   'classic rock',
#   'folk rock',
#   'rock',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'George Hamilton IV': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Ray Price': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'The Rivieras': ['classic garage rock', 'surf music'],
#  'The Tune Rockers': [],
#  'Gogi Grant': ['deep adult standards'],
#  'Warren Storm': ['swamp pop'],
#  'Cozy Cole': [],
#  'The Shields': [],
#  'David Seville': [],
#  'Eileen Rodgers': ['deep adult standards'],
#  'Andy Williams': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'mellow gold',
#   'vocal jazz'],
#  'The McGuire Sisters': ['adult standards',
#   'christmas',
#   'deep adult standards',
#   'vocal harmony group'],
#  'Dale Wright': [],
#  'The Playboys': [],
#  'Tommy Sands': [],
#  'The Chargers': [],
#  'The Kingsmen': [],
#  'Johnnie Ray': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'deep adult standards',
#   'rock-and-roll'],
#  'Dale Hawkins': ['rock-and-roll', 'rockabilly'],
#  'Teresa Brewer': ['adult standards', 'christmas', 'deep adult standards'],
#  'Carl Smith': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Ivory Joe Hunter': ['jazz blues', 'piano blues', 'rhythm and blues'],
#  'Robert Mitchum': ['lounge'],
#  'Doug Franklin': [],
#  'Joni James': ['adult standards',
#   'cabaret',
#   'christmas',
#   'deep adult standards',
#   'easy listening',
#   'lounge'],
#  'Conway Twitty': ['country',
#   'country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country'],
#  'Little Richard': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'motown',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'The Applejacks': ['british invasion', 'merseybeat', 'rock-and-roll'],
#  'Earl Grant': ['space age pop'],
#  'Jane Morgan': ['deep adult standards'],
#  'Ruth Brown': ['jazz blues',
#   'jump blues',
#   'rhythm and blues',
#   'rock-and-roll',
#   'soul',
#   'southern soul'],
#  'Ritchie Valens': ['adult standards',
#   'brill building pop',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Four Coins': ['deep adult standards', 'vocal harmony group'],
#  'Ivan': ['italian disco'],
#  'The Teddy Bears': [],
#  'Eddie Fontaine': [],
#  'Jackie Wilson': ['adult standards',
#   'brill building pop',
#   'chicago soul',
#   'christmas',
#   'classic soul',
#   'lounge',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'Sonny James': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Steve Lawrence': ['adult standards',
#   'brill building pop',
#   'cabaret',
#   'christmas',
#   'deep adult standards',
#   'easy listening',
#   'lounge'],
#  'The Swallows': ['rhythm and blues'],
#  'The Ames Brothers': ['adult standards',
#   'christmas',
#   'deep adult standards',
#   'vocal harmony group'],
#  'Ed Townsend': [],
#  'The Kingston Trio': ['american folk revival',
#   'christmas',
#   'cowboy western',
#   'folk',
#   'folk rock',
#   'traditional folk'],
#  'Cyclones': [],
#  'Lee Allen': [],
#  'Dicky Doo': [],
#  'Betty Johnson': ['deep adult standards'],
#  'Georgia Gibbs': ['deep adult standards'],
#  'Johnny Tillotson': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Donnie Owens': [],
#  "Lord Rockingham's XI": [],
#  'The Five Blobs': [],
#  'Andy Rose': [],
#  'Jerry Vale': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'operatic pop',
#   'vocal jazz'],
#  'Mitch Miller': ['christmas', 'easy listening'],
#  'The Royaltones': [],
#  'Tab Hunter': [],
#  'Frank Sinatra': ['adult standards', 'christmas', 'easy listening', 'lounge'],
#  'Jodie Sands': ['deep adult standards'],
#  'Louis Prima': ['adult standards',
#   'christmas',
#   'jump blues',
#   'lounge',
#   'soul',
#   'swing',
#   'vocal jazz'],
#  'Enoch Light': ['easy listening', 'exotica', 'lounge'],
#  'Johnny Otis': ['jazz blues',
#   'jump blues',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'The Fontane Sisters': ['deep adult standards', 'vocal harmony group'],
#  'Nappy Brown': ['jump blues', 'rhythm and blues'],
#  'Johnny Nash': [],
#  'Roy Hamilton': [],
#  'Bob Kayli': ['deep motown'],
#  'Bernie Lowe Orchestra': [],
#  'Billy Grammer': ['deep adult standards'],
#  'The Crests': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'The Four Aces': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'deep adult standards',
#   'easy listening',
#   'lounge',
#   'vocal harmony group'],
#  'June Valli': ['deep adult standards'],
#  'Dee Clark': ['brill building pop',
#   'chicago soul',
#   'doo-wop',
#   'rhythm and blues'],
#  'The Cadillacs': ['doo-wop', 'rhythm and blues', 'rock-and-roll'],
#  'Reg Owen': [],
#  'Tony Dallara': ['classic italian pop'],
#  'Neil Sedaka': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'lounge',
#   'mellow gold',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'LaVern Baker': ['brill building pop',
#   'doo-wop',
#   'jump blues',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'southern soul'],
#  'Lloyd Price': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'louisiana blues',
#   'memphis blues',
#   'new orleans blues',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Augie Rios': ['christmas'],
#  'James Brown': ['christmas',
#   'deep funk',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul'],
#  'Art Lund': [],
#  'Eugene Church': [],
#  'Polly Bergen': [],
#  'Bill Parsons': [],
#  'Bing Crosby': ['adult standards', 'christmas', 'easy listening'],
#  'Ray Charles': ['adult standards',
#   'christmas',
#   'classic soul',
#   'jazz blues',
#   'piano blues',
#   'soul',
#   'soul blues',
#   'vocal jazz'],
#  'The Accents': [],
#  'The 5 Chanels': [],
#  'Wade Flemons': ['deep northern soul'],
#  'Stan Freberg': ['comic'],
#  'Jesse Belvin': ['rhythm and blues'],
#  'Ray Anthony': ['big band',
#   'christmas',
#   'easy listening',
#   'exotica',
#   'lounge',
#   'swing'],
#  'Edmundo Ros': ['ballroom', 'christmas', 'easy listening', 'lounge', 'mambo'],
#  'The Mills Brothers': ['adult standards',
#   'big band',
#   'cabaret',
#   'christmas',
#   'lounge',
#   'swing',
#   'vocal harmony group',
#   'vocal jazz'],
#  'Jesse Lee Turner': [],
#  'Della Reese': ['cabaret', 'christmas', 'vocal jazz'],
#  'Cyril Stapleton': [],
#  "Chris Barber's Jazz Band": ['dixieland'],
#  'The Four Knights': ['deep adult standards', 'vocal harmony group'],
#  'Billy Williams': ['deep adult standards'],
#  'The Flamingos': ['brill building pop', 'doo-wop', 'rhythm and blues'],
#  'Linda Laurie': ['vintage swoon'],
#  'Billy Graves': [],
#  'Cathy Carr': ['deep adult standards'],
#  'The Mark IV': ['deep classic garage rock'],
#  'The Bell Notes': [],
#  'Brook Benton': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'soul',
#   'southern soul'],
#  'Link Wray': ['garage rock',
#   'native american',
#   'protopunk',
#   'psychedelic rock',
#   'punk blues',
#   'rock-and-roll',
#   'rockabilly',
#   'surf music'],
#  'Thomas Wayne': [],
#  'Frankie Ford': ['rhythm and blues', 'rock-and-roll', 'rockabilly'],
#  'Nicola Paone': [],
#  'Jaye P. Morgan': ['deep adult standards'],
#  'The Skyliners': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Dodie Stevens': [],
#  'John Fred': ['swamp pop'],
#  'The Chordettes': ['adult standards',
#   'brill building pop',
#   'classic girl group',
#   'doo-wop',
#   'rock-and-roll',
#   'vocal harmony group'],
#  'Dean Reed': [],
#  'The Fleetwoods': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'vocal harmony group'],
#  'The Virtues': [],
#  'Graduates': [],
#  'Rod Bernard': ['swamp pop'],
#  'Jimmy Barnes': ['australian pop', 'australian rock'],
#  'Hank Ballard': ['rhythm and blues'],
#  'Eddy Arnold': ['christmas',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Dave "Baby" Cortez': ['jazz organ'],
#  'The Impalas': ['doo-wop'],
#  'Marv Johnson': ['motown', 'rhythm and blues'],
#  'The Intruders': ['classic soul',
#   'disco',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul',
#   'southern soul'],
#  'The Quarter Notes': [],
#  'Diane Maxwell': [],
#  'Dean': [],
#  'Sammy Turner': [],
#  'Tommy Dee': ['deep adult standards'],
#  'The Genies': ['doo-wop'],
#  'The Fiestas': ['doo-wop'],
#  'Kathy Linden': ['deep adult standards'],
#  'Billy Storm': [],
#  'Carl Dobkins, Jr.': ['deep adult standards'],
#  'The Mary Kaye Trio': ['lounge', 'song poem'],
#  'Wilbert Harrison': ['rhythm and blues', 'rock-and-roll'],
#  'Edward Byrnes': ['deep adult standards'],
#  'The Falcons': ['rhythm and blues'],
#  'David Hill': ['orchestral performance'],
#  'Jimmy Beck': [],
#  'Tony Bellus': ['deep adult standards'],
#  'Johnny Horton': ['country',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'rock-and-roll',
#   'rockabilly',
#   'traditional country',
#   'western swing'],
#  'The Trumpeteers': ['gospel singers',
#   'vintage gospel',
#   'vocal harmony group'],
#  'George Jones': ['country',
#   'country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country'],
#  'Sarah Vaughan': ['adult standards',
#   'bebop',
#   'cabaret',
#   'christmas',
#   'cool jazz',
#   'jazz',
#   'lounge',
#   'soul',
#   'swing',
#   'vocal jazz'],
#  'Ruby Wright': [],
#  'Freddy Cannon': ['brill building pop',
#   'bubblegum pop',
#   'doo-wop',
#   'merseybeat',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Wailers': ['dub', 'reggae', 'roots reggae', 'ska'],
#  'Preston Epps': [],
#  'Chubby Checker': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'Ray Peterson': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Al Martino': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'Dinah Washington': ['adult standards',
#   'cabaret',
#   'christmas',
#   'jazz blues',
#   'lounge',
#   'soul',
#   'swing',
#   'vocal jazz'],
#  'The Mystics': ['doo-wop'],
#  'Vaughn Monroe': ['adult standards',
#   'big band',
#   'cabaret',
#   'christmas',
#   'lounge',
#   'swing'],
#  'Big Jay McNeely': ['jazz blues',
#   'jazz saxophone',
#   'jump blues',
#   'rhythm and blues'],
#  'Don French': [],
#  'The Frantics': ['comic'],
#  'Stonewall Jackson': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Sil Austin': [],
#  'The Megatrons': [],
#  'Carl Mann': ['rock-and-roll', 'rockabilly'],
#  'Carl Perkins': ['rock-and-roll', 'rockabilly'],
#  'Ronnie Hawkins': ['canadian blues', 'rock-and-roll', 'rockabilly'],
#  'Hugo': [],
#  'Huelyn Duvall': ['neo-rockabilly'],
#  'Arthur Lyman': ['easy listening', 'exotica', 'jazz vibraphone', 'lounge'],
#  'Little Bill': [],
#  'Jacky Noguez': ['accordion'],
#  'Skip': [],
#  'Anita Bryant': ['deep adult standards'],
#  'The Tempos': [],
#  'Bobby Rydell': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'lounge',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Roger Smith': ['deep smooth jazz', 'smooth jazz'],
#  'Jerry Keller': [],
#  'Jackie Lee': ['lift kit'],
#  'Phil Phillips': ['doo-wop', 'swamp pop'],
#  'Bo Diddley': ['blues',
#   'chicago blues',
#   'classic rock',
#   'electric blues',
#   'funk',
#   'garage rock',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'traditional blues'],
#  'The Tassels': [],
#  'The Eternals': [],
#  'The Shirelles': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'classic girl group',
#   'doo-wop',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul'],
#  'Rusty York': [],
#  'The Knightsbridge Strings': ['light music'],
#  'Ray Sharpe': [],
#  'Floyd Robinson': [],
#  'Richard Barrett': [],
#  'The Browns': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'vocal harmony group'],
#  'Santo': [],
#  'Marvin Rainwater': [],
#  'Mitchell Torok': [],
#  'Nina Simone': ['adult standards',
#   'christmas',
#   'jazz blues',
#   'neo soul',
#   'soul',
#   'soul jazz',
#   'vocal jazz'],
#  'Hawkshaw Hawkins': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'The Tradewinds': [],
#  'Bob Beckham': [],
#  'Webb Pierce': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Ivo Robic': ['classic schlager', 'croatian pop', 'vintage schlager'],
#  'Bob McFadden': [],
#  'The Dubs': ['doo-wop', 'rhythm and blues'],
#  'Dick Flood': [],
#  'Bobby Vee': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'lounge',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Jerry Fuller': [],
#  'The Strangers': [],
#  'Homer': [],
#  "Jivin' Gene": ['swamp pop'],
#  'Sandy Nelson': ['rock-and-roll', 'space age pop', 'surf music'],
#  'Johnny Restivo': [],
#  'Fireflies': [],
#  'Wink Martindale': ['deep adult standards'],
#  'The Clovers': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Paul Evans': [],
#  'Leslie Uggams': [],
#  'E.C. Beatty': [],
#  'Boyd Bennett': ['traditional rockabilly'],
#  'The Isley Brothers': ['classic soul',
#   'disco',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul',
#   'southern soul'],
#  'Ernie Fields': ['deep adult standards'],
#  'Cliff Richard': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'mellow gold',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly',
#   'soft rock'],
#  'Chet Atkins': ['nashville sound', 'traditional country'],
#  'Fireballs': [],
#  'The Islanders': [],
#  'Kitty Kallen': ['deep adult standards'],
#  'Guy Mitchell': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'cowboy western',
#   'deep adult standards',
#   'lounge',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Passions': [],
#  'The Miracles': ['brill building pop',
#   'classic soul',
#   'disco',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'Johnny Preston': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Tommy Facenda': [],
#  'The Spacemen': [],
#  'The Revels': ['surf music'],
#  'Bobby Comstock': [],
#  'Paul Gayten': [],
#  'Rocco Granata': ['classic italian pop', 'classic schlager'],
#  'The Nutty Squirrels': [],
#  'Miss Toni Fisher': ['deep adult standards'],
#  'Don Costa': ['easy listening', 'exotica', 'lounge', 'space age pop'],
#  'Larry Hall': ['christian relaxative', 'deep adult standards'],
#  'Titus Turner': ['jump blues'],
#  'Willy Alberti': ['dutch pop', 'levenslied', "traditional rock 'n roll"],
#  "Bill Black's Combo": [],
#  'April Stevens': ['lounge'],
#  'Bonnie Guitar': [],
#  'Dorothy Collins': [],
#  'Rod Lauren': [],
#  'Brenda Lee': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'nashville sound',
#   'rockabilly'],
#  'Mark Dinning': [],
#  'Jimmy Jones': ['bmore',
#   'brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Joe Turner': [],
#  'The Viscounts': [],
#  'The Knockouts': [],
#  'Ray Smith': ['rock-and-roll', 'rockabilly'],
#  'The Five Satins': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Percy Faith': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge'],
#  'Adam Wade': ['deep adult standards'],
#  'The Fireballs': ['surf music'],
#  'Debbie Reynolds': ['show tunes'],
#  'Roy Orbison': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'mellow gold',
#   'rock',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Little Dippers': [],
#  'Frank Chacksfield': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge'],
#  'Jamie Horton': [],
#  'The Fireflies': [],
#  'The Rays': ['doo-wop'],
#  'Elton Anderson': [],
#  'Connie Stevens': [],
#  'Dorsey Burnette': ['traditional rockabilly'],
#  'Barrett Strong': ['motown'],
#  'Buster Brown': ['jump blues'],
#  'Bob Crewe': [],
#  'Marty Wilde': ['brill building pop',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Pete Fountain': ['dixieland', 'jazz clarinet', 'new orleans jazz'],
#  'Narvel Felts': [],
#  'Billy Walker': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Nat Kendrick': [],
#  'Rosco Gordon': ['memphis blues', 'rhythm and blues'],
#  'Billy Bland': [],
#  'The Brothers Four': ['adult standards',
#   'american folk revival',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'folk',
#   'folk rock',
#   'traditional folk',
#   'vocal harmony group'],
#  'Monty Kelly': [],
#  'Lenny Welch': [],
#  'Harold Dorman': [],
#  'Les Compagnons De La Chanson': ['chanson'],
#  'Charlie Rich': ['country',
#   'country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Jessie Hill': ['louisiana blues', 'new orleans blues'],
#  'Sammy Masters': [],
#  'Ron Holden': [],
#  'Henry Mancini': ['adult standards',
#   'christmas',
#   'classic soundtrack',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'Ray Bryant Combo': [],
#  'Teddy Randazzo': [],
#  'The Temptations': ['brill building pop',
#   'christmas',
#   'classic soul',
#   'disco',
#   'funk',
#   'memphis soul',
#   'motown',
#   'soul'],
#  'Sir Chauncey': [],
#  'Walter Brennan': ['cowboy western'],
#  'Jeanne Black': ['deep adult standards'],
#  'Etta James': ['adult standards',
#   'christmas',
#   'classic soul',
#   'jazz blues',
#   'soul',
#   'soul blues',
#   'vocal jazz'],
#  'Ella Fitzgerald': ['adult standards',
#   'christmas',
#   'jazz blues',
#   'swing',
#   'vocal jazz'],
#  'Charlie Ryan': [],
#  'Frank DeVol': ['easy listening', 'space age pop'],
#  'The Beau-Marks': [],
#  'Larry Bright': [],
#  'Hank Locklin': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'The Fendermen': [],
#  'Ike Clanton': [],
#  'Hollywood Argyles': [],
#  'Dante': ['spanish hip hop'],
#  'The Dyna-Sores': [],
#  'Jon Thomas': [],
#  'The Videls': ['doo-wop', 'soda pop'],
#  'Donnie Brooks': [],
#  'Bobby Marchan': ['rhythm and blues', 'southern soul'],
#  'Art Mooney': ['deep adult standards'],
#  'Deane Hawley': [],
#  'Garry Mills': [],
#  'Red River Dave': [],
#  'Brian Hyland': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Joanie Sommers': [],
#  'The Bobbettes': ['classic girl group', 'doo-wop', 'rhythm and blues'],
#  'The Demensions': ['doo-wop', 'soda pop'],
#  'Rusty Draper': ['deep adult standards'],
#  'The Ventures': ['lounge', 'rock-and-roll', 'rockabilly', 'surf music'],
#  'Anthony Newley': [],
#  'Johnny Burnette': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rock-and-roll',
#   'rockabilly'],
#  'Ferrante': [],
#  'Hank Thompson': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Etta': [],
#  'Jerry Byrd': ['hawaiian', 'steel guitar'],
#  'The Ivy Three': [],
#  'Frankie Lymon': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Johnny Bond': ['country gospel',
#   'cowboy western',
#   'traditional country',
#   'western swing'],
#  'The Statues': [],
#  'Jo Ann Campbell': [],
#  'The Innocents': [],
#  'Skeeter Davis': ['brill building pop',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country'],
#  'Jimmy Charles': [],
#  'The Paradons': ['doo-wop'],
#  'Larry Verne': [],
#  'Wanda Jackson': ['rock-and-roll', 'rockabilly'],
#  'Paul Chaplain': [],
#  'Rosemary Clooney': ['adult standards',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'swing',
#   'vocal jazz'],
#  'Denny Reed': [],
#  'Bob Luman': ['rock-and-roll', 'rockabilly', 'western swing'],
#  'The Piltdown Men': [],
#  'The Chiffons': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'classic girl group',
#   'doo-wop',
#   'folk rock',
#   'merseybeat',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Joe Jones': [],
#  'Cowboy Copas': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Maurice Williams': ['doo-wop'],
#  'The Blue Notes': [],
#  'Floyd Cramer': ['christmas', 'easy listening', 'lounge', 'nashville sound'],
#  'U.S. Bonds': [],
#  'Ray Ellis': [],
#  'The Mark II': [],
#  'Bud': [],
#  'Kathy Young': [],
#  'Lolita': [],
#  'Lawrence Welk': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'polka'],
#  'Damita Jo': [],
#  'Ernie Freeman': ['space age pop'],
#  'David Carroll': ['exotica', 'space age pop'],
#  'Bobby Peterson': [],
#  'Charles Wolcott': [],
#  'The Chimes': ['doo-wop'],
#  'James Booker': ['boogie-woogie',
#   'jazz blues',
#   'louisiana blues',
#   'new orleans blues',
#   'piano blues'],
#  'Mantovani': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'operatic pop'],
#  'The Heartbeats': ['doo-wop', 'rhythm and blues'],
#  'Etta Jones': ['cabaret', 'christmas', 'vocal jazz'],
#  'Bert Kaempfert': ['adult standards',
#   'ballroom',
#   'christmas',
#   'easy listening',
#   'lounge'],
#  'Austin Taylor': [],
#  'Cornbread': [],
#  'Richie Allen': [],
#  'Ferlin Husky': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'The Blue Diamonds': ['classic schlager',
#   'indorock',
#   "traditional rock 'n roll"],
#  'Al Caiola': ['ballroom',
#   'christmas',
#   'easy listening',
#   'exotica',
#   'lounge',
#   'mambo'],
#  'The Ramblers': ['nueva ola chilena', 'surf music'],
#  'Hank Snow': ['canadian country',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'The Shells': [],
#  "Jerry Murad's Harmonicats": [],
#  'Shelby Flint': ['movie tunes'],
#  'Mickey': [],
#  'Thelma Carpenter': [],
#  'Ben E. King': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'classic soul',
#   'motown',
#   'quiet storm',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'southern soul'],
#  'The Capris': ['doo-wop', 'rhythm and blues'],
#  'Maxine Brown': ['brill building pop',
#   'classic soul',
#   'rhythm and blues',
#   'southern soul'],
#  'Lenny Miles': [],
#  'Ella Johnson': ['jump blues'],
#  'Cleveland Crochet': ['swamp blues', 'swamp pop'],
#  'H.B. Barnum': [],
#  'The String-A-Longs': ['surf music'],
#  'Ronnie Savoy': [],
#  'Ramrods': [],
#  'Ronnie Love': [],
#  'Buzz Clifford': [],
#  'Freddy King': [],
#  'The Goodtimers': [],
#  'The "5" Royales': ['rhythm and blues'],
#  'Jorgen Ingmann': [],
#  'Mello-Kings': [],
#  'The Sevilles': [],
#  'Gene Pitney': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'lounge',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Carla Thomas': ['classic soul',
#   'memphis soul',
#   'motown',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'Mary Wells': ['brill building pop',
#   'classic soul',
#   'funk',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'Johnny Maestro': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Rochell': [],
#  'Debbie Dean': ['deep motown'],
#  'Kokomo': [],
#  'Chuck Jackson': ['classic soul',
#   'motown',
#   'northern soul',
#   'rhythm and blues',
#   'southern soul'],
#  'The Vibrations': ['chicago soul', 'northern soul'],
#  'Dickie Goodman': [],
#  'The Pentagons': ['doo-wop'],
#  'Cathy Jean': [],
#  'Aretha Franklin': ['christmas',
#   'classic soul',
#   'jazz blues',
#   'memphis soul',
#   'soul',
#   'southern soul'],
#  'Ernestine Anderson': ['cabaret', 'christmas', 'vocal jazz'],
#  'Fred Darian': [],
#  'The Echoes': ['soda pop'],
#  'Del Shannon': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Larks': [],
#  'The Marcels': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Herb Lance': [],
#  'The Tokens': ['doo-wop'],
#  'The Enchanters': [],
#  'Linda Scott': ['brill building pop'],
#  'Dick Lee': [],
#  'Otis Williams': [],
#  'Kay Starr': ['adult standards',
#   'big band',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'swing',
#   'vocal jazz'],
#  'Gene McDaniels': [],
#  'Ernie K-Doe': ['louisiana blues',
#   'new orleans blues',
#   'new orleans funk',
#   'rhythm and blues'],
#  'Shep': [],
#  'Paul Revere': [],
#  'Janie Grant': [],
#  'The Texans': [],
#  'Sammy Kaye': [],
#  'The Frogmen': ['surf music'],
#  'Andy Stewart': ['traditional scottish folk'],
#  'Eddie Harris': ['bebop', 'hard bop', 'jazz', 'jazz funk', 'soul jazz'],
#  'Merv Griffin': [],
#  'The Rollers': [],
#  'Claude Gray': [],
#  'Audrey Arno': [],
#  'The Strollers': [],
#  'Roy Drusky': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country'],
#  'Ral Donner': [],
#  'The Limeliters': ['american folk revival', 'traditional folk'],
#  'The Marathons': [],
#  'Piero Soffici': [],
#  'Bobby Lewis': [],
#  'The Starlets': ['classic girl group'],
#  'Oscar Black': [],
#  'Lale Anderson': [],
#  'Joe Barry': ['swamp pop'],
#  'Jeanette (Baby) Washington': [],
#  'Little Caesar': ['glam metal',
#   'hard rock',
#   'modern hard rock',
#   'sleaze rock'],
#  'Donnie': [],
#  'Tony Orlando': ['brill building pop', 'bubblegum pop'],
#  'Jimmy Witter': [],
#  'The Edsels': ['doo-wop'],
#  'The Timetones': [],
#  'Russell Byrd': [],
#  'Mina': ['classic italian pop', 'italian pop', 'ye ye'],
#  'The Blossoms': ['brill building pop', 'classic girl group'],
#  'The Harptones': ['doo-wop', 'rhythm and blues'],
#  'Louise Brown': [],
#  'The Regents': ['doo-wop'],
#  'Pips': [],
#  'Gladys Knight': ['disco', 'motown', 'quiet storm'],
#  'The New Yorkers': [],
#  'The Wanderers': [],
#  'Paul Peek': [],
#  'The Dukays': ['soda pop'],
#  'The Belmonts': ['doo-wop', 'rhythm and blues'],
#  'Pat Zill': [],
#  'Patsy Cline': ['adult standards',
#   'christmas',
#   'country gospel',
#   'cowboy western',
#   'nashville sound',
#   'rockabilly',
#   'traditional country'],
#  'The Cleftones': ['brill building pop',
#   'doo-wop',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Junior Parker': ['memphis blues', 'soul blues'],
#  'Arthur Lyman Group': [],
#  'Matt Monro': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'easy listening',
#   'lounge'],
#  'Chris Kenner': ['louisiana blues', 'new orleans blues', 'rhythm and blues'],
#  'Slim Harpo': ['acoustic blues',
#   'blues',
#   'electric blues',
#   'harmonica blues',
#   'louisiana blues',
#   'rhythm and blues',
#   'swamp blues',
#   'traditional blues'],
#  'The Castells': [],
#  'The Velvets': [],
#  'Teddy Vann': [],
#  'The Delacardos': [],
#  'The Excels': [],
#  'Johnny Crawford': [],
#  'Bobby Parker': [],
#  'Frankie Calen': [],
#  'Neil Scott': [],
#  'Eddie Hodges': [],
#  'The Chanters': ['doo-wop', 'soda pop'],
#  'Adrian Kimberly': [],
#  'The Spinners': ['classic soul',
#   'disco',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul',
#   'southern soul'],
#  'Joe Dowell': [],
#  'Curtis Lee': ['brill building pop', 'doo-wop', 'rhythm and blues'],
#  'Tex Ritter': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'The Jive Five': ['doo-wop', 'rhythm and blues'],
#  'Jose Jimenez': [],
#  'Frankie Miller': ['pub rock'],
#  'The Highwaymen': ['country rock',
#   'nashville sound',
#   'outlaw country',
#   'traditional country'],
#  'The Halos': ['doo-wop', 'soda pop'],
#  'Don Shirley Trio': [],
#  'Claude King': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'The Paragons': ['dub', 'reggae', 'rock steady', 'ska'],
#  'Gary U.S. Bonds': ['rhythm and blues'],
#  'Timi Yuro': ['adult standards', 'brill building pop'],
#  'Ann-Margret': [],
#  'The Jarmels': ['doo-wop'],
#  'Ronny Douglas': [],
#  'The Dreamlovers': [],
#  'The Butanes': [],
#  'The Van Dykes': [],
#  'Barry Mann': ['doo-wop'],
#  'Lonnie Donegan': ['merseybeat', 'rock-and-roll', 'skiffle'],
#  'The Blue Jays': ['doo-wop'],
#  'The Rondels': [],
#  'Bob Moore': [],
#  'The Velaires': [],
#  'The Sensations': ['classic girl group', 'rock steady'],
#  'The Four Sportsmen': [],
#  'Ray Stevens': ['bubblegum pop',
#   'comic',
#   'country',
#   'nashville sound',
#   'traditional country'],
#  'The Chantels': ['brill building pop',
#   'classic girl group',
#   'classic soul',
#   'doo-wop',
#   'rhythm and blues'],
#  'Bobby Edwards': [],
#  'Mary Ann Fisher': [],
#  'Sue Thompson': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'merseybeat',
#   'rock-and-roll'],
#  'Hayley Mills': ['movie tunes'],
#  'The Lettermen': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal harmony group'],
#  'The Marvelettes': ['brill building pop',
#   'classic girl group',
#   'classic soul',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'The Paris Sisters': ['brill building pop', 'classic girl group'],
#  'Tommy Hunt': ['northern soul'],
#  'The Flares': [],
#  'The Dave Brubeck Quartet': ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz'],
#  'The Dovells': ['brill building pop', 'doo-wop', 'rhythm and blues'],
#  'Duals': [],
#  'The Caslons': [],
#  'Lee Dorsey': ['classic soul',
#   'deep funk',
#   'funk',
#   'motown',
#   'new orleans funk',
#   'rhythm and blues',
#   'rock-and-roll',
#   'soul'],
#  'Gloria Lynne': ['cabaret'],
#  'Bull Moose Jackson': ['jump blues', 'rhythm and blues'],
#  'Troy Shondell': [],
#  'The G-Clefs': [],
#  'Richard Hayman': ['lounge'],
#  'Tina Robin': [],
#  'Solomon Burke': ['brill building pop',
#   'christmas',
#   'classic soul',
#   'funk',
#   'lgbtq+ hip hop',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'soul',
#   'soul blues',
#   'southern soul',
#   'vocal jazz'],
#  'The Stereos': [],
#  'The Lennon Sisters': [],
#  'Jimmy Dean': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Hank Levine': [],
#  'The Parkays': [],
#  'James Darren': [],
#  'The Angels': ['australian rock', 'classic girl group'],
#  'The Impressions': ['brill building pop',
#   'chicago soul',
#   'classic soul',
#   'funk',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'soul'],
#  'Gene Thomas': ['belgian pop', 'classic belgian pop'],
#  'Glen Campbell': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk',
#   'folk rock',
#   'lounge',
#   'mellow gold',
#   'nashville sound',
#   'soft rock',
#   'traditional country'],
#  'Leroy Van Dyke': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'Kenny Dino': [],
#  'Eddie Fisher': ['adult standards',
#   'christmas',
#   'deep adult standards',
#   'easy listening'],
#  'John D. Loudermilk': [],
#  'Si Zentner': ['easy listening',
#   'exotica',
#   'jazz trombone',
#   'lounge',
#   'space age pop'],
#  'The Showmen': ['beach music'],
#  'Barbara George': [],
#  'Jimmy Elledge': [],
#  'Joey Dee': [],
#  'James Ray': [],
#  'The Crystals': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'classic girl group',
#   'doo-wop',
#   'folk rock',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly'],
#  'Jack Eubanks': [],
#  'Dick Dale': ['surf music'],
#  'Vic Dana': [],
#  'Phil McLean': [],
#  'Helen Shapiro': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Jimmy McCracklin': ['jump blues',
#   'piano blues',
#   'rhythm and blues',
#   'soul blues',
#   'southern soul'],
#  'Burl Ives': ['adult standards', 'american folk revival', 'christmas'],
#  'Sleepy King': [],
#  'Charles Brown': ['blues',
#   'christmas',
#   'jazz blues',
#   'piano blues',
#   'rhythm and blues'],
#  'Ace Cannon': [],
#  'The Corsairs': [],
#  'The Jack Halloran Singers': [],
#  'Tico': [],
#  'Don Shirley': [],
#  'Charlie Drake': [],
#  'The Ikettes': ['brill building pop'],
#  'Jack Ross': [],
#  'Gene Chandler': ['brill building pop',
#   'chicago soul',
#   'classic soul',
#   'doo-wop',
#   'motown',
#   'northern soul',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'The Marketts': ['surf music'],
#  'Billy Joe': [],
#  'Eddie Holland': ['motown'],
#  'Rod McKuen': [],
#  'Bruce Channel': [],
#  'The Megatons': [],
#  'Kenny Ball': ['dixieland', 'new orleans jazz'],
#  'Johnny Gibson': [],
#  'Huey Smith': [],
#  'The Beach Boys': ['brill building pop',
#   'folk rock',
#   'psychedelic rock',
#   'rock'],
#  'Anita': [],
#  'King Curtis': ['jazz blues', 'jazz saxophone', 'soul', 'soul jazz'],
#  'Ketty Lester': [],
#  'Arthur Alexander': ['southern soul'],
#  'Larry Finnegan': [],
#  'Dee Dee Sharp': ['brill building pop',
#   'classic girl group',
#   'doo-wop',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Shelley Fabares': ['brill building pop'],
#  'Paul Petersen': ['deep motown'],
#  'Jimmy Smith': ['bebop',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz blues',
#   'jazz funk',
#   'jazz fusion',
#   'jazz organ',
#   'soul jazz'],
#  'Jack Jones': ['adult standards',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'The Stompers': ['boston rock'],
#  'Little Junior Parker': [],
#  'Big Sambo': [],
#  'Steve Alaimo': [],
#  'Bobby Gregg': [],
#  'Ernie Maresca': [],
#  'Jimmy Soul': [],
#  'Al Casey Combo': [],
#  'Johnnie Morisette': [],
#  'Dr. Feelgood': ['blues-rock',
#   'british blues',
#   'protopunk',
#   'pub rock',
#   'rockabilly'],
#  'George Maharis': [],
#  'Nathaniel Mayer': [],
#  'William Bell': ['classic soul',
#   'funk',
#   'memphis soul',
#   'motown',
#   'soul',
#   'southern soul'],
#  'Yvonne Baker': ['northern soul'],
#  'Bertha Tillman': [],
#  'Bobby Curtola': ['deep adult standards'],
#  'Benny Spellman': [],
#  'David Rose': ['space age pop'],
#  'Joe Henderson': ['avant-garde jazz',
#   'bebop',
#   'big band',
#   'contemporary jazz',
#   'contemporary post-bop',
#   'cool jazz',
#   'free jazz',
#   'hard bop',
#   'jazz',
#   'jazz funk',
#   'jazz fusion',
#   'jazz saxophone',
#   'soul jazz',
#   'stride'],
#  'Teddy': ['emo rap'],
#  'Emilio Pericoli': [],
#  'Toni Fisher': ['deep adult standards'],
#  'John Lee Hooker': ['blues',
#   'blues-rock',
#   'classic rock',
#   'delta blues',
#   'electric blues',
#   'memphis blues',
#   'soul',
#   'traditional blues'],
#  'Richard Chamberlain': [],
#  'Nelson Riddle': ['adult standards',
#   'christmas',
#   'classic soundtrack',
#   'easy listening',
#   'exotica',
#   'lounge'],
#  'Don Gardner': [],
#  'Bobby Vinton': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'doo-wop',
#   'easy listening',
#   'folk rock',
#   'lounge',
#   'mellow gold',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Orlons': ['brill building pop',
#   'classic girl group',
#   'doo-wop',
#   'motown',
#   'rhythm and blues'],
#  'Maureen Gray': [],
#  'Jimmy Norman': [],
#  'Barbara Lynn': ['classic soul',
#   'motown',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'Little Joey': [],
#  'Dreamlovers': [],
#  'Little Eva': ['brill building pop',
#   'doo-wop',
#   'merseybeat',
#   'rhythm and blues',
#   'rock-and-roll'],
#  'Jerry Reed': ['country',
#   'country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country'],
#  'Claudine Clark': ['brill building pop'],
#  'Martin Denny': ['adult standards', 'easy listening', 'exotica', 'lounge'],
#  'Baby Cortez': [],
#  'Bobby Bare': ['country',
#   'country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'The Lafayettes': [],
#  'Billy Stewart': ['chicago soul',
#   'classic soul',
#   'funk',
#   'motown',
#   'rhythm and blues',
#   'soul'],
#  'The Castle Sisters': [],
#  'Tommy Roe': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Bent Fabric': [],
#  'Chris Montez': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'lounge',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Duprees': ['brill building pop', 'doo-wop', 'rhythm and blues'],
#  'The Springfields': ['c86'],
#  'Cathy Carroll': [],
#  'The Majors': [],
#  'Booker T.': [],
#  'The Supremes': ['brill building pop',
#   'christmas',
#   'classic girl group',
#   'classic soul',
#   'disco',
#   'folk rock',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul'],
#  'The Contours': ['brill building pop', 'motown', 'northern soul', 'soul'],
#  'The Rivingtons': ['doo-wop'],
#  'The Valentinos': ['electrofox'],
#  'Dickey Lee': [],
#  'Carole King': ['adult standards',
#   'brill building pop',
#   'folk',
#   'folk rock',
#   'folk-pop',
#   'lilith',
#   'mellow gold',
#   'rock',
#   'singer-songwriter',
#   'soft rock'],
#  'Bunker Hill': [],
#  'Kris Jensen': [],
#  'Sammy Davis Jr.': ['adult standards',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'swing',
#   'vocal jazz'],
#  'Bobby "Boris" Pickett': ['halloween'],
#  'Frank Ifield': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'merseybeat',
#   'nashville sound',
#   'rock-and-roll',
#   'rockabilly'],
#  'Rex Allen': ['cowboy western', 'western swing'],
#  'Mike Clifford': [],
#  'Buddy Greco': ['adult standards', 'christmas', 'easy listening', 'lounge'],
#  'Robert Goulet': ['adult standards', 'christmas', 'easy listening', 'lounge'],
#  'The Sherrys': ['classic girl group'],
#  'Les Cooper': [],
#  'Jimmy McGriff': ['deep funk', 'jazz funk', 'jazz organ', 'soul jazz'],
#  'Stan Kenton': ['swing'],
#  'Tommy Boyce': ['brill building pop'],
#  'David Thorne': [],
#  'Trade Martin': [],
#  'Marcie Blane': [],
#  'Marvin Gaye': ['classic soul',
#   'funk',
#   'motown',
#   'northern soul',
#   'quiet storm',
#   'soul'],
#  'The Tams': ['beach music', 'motown', 'northern soul'],
#  'Herb Alpert': ['jazz trumpet'],
#  'Bill Anderson': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'The Routers': [],
#  'The Tornadoes': ['surf music'],
#  'Dean Christie': [],
#  'The Radiants': ['chicago soul'],
#  'The Cookies': ['brill building pop', 'classic girl group'],
#  'Mark Valentino': [],
#  'Gabriel': [],
#  'Ben Colder': [],
#  'Ann Cole': [],
#  'The Excellents': ['doo-wop'],
#  'The Exciters': ['brill building pop',
#   'classic girl group',
#   'motown',
#   'northern soul'],
#  'The New Christy Minstrels': ['american folk revival', 'traditional folk'],
#  'The Emotions': ['chicago soul',
#   'classic soul',
#   'disco',
#   'funk',
#   'girl group',
#   'jazz funk',
#   'motown',
#   'post-disco',
#   'quiet storm',
#   'soul',
#   'southern soul',
#   'urban contemporary'],
#  'Lou Monte': ['christmas'],
#  'Dionne Warwick': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'disco',
#   'lounge',
#   'mellow gold',
#   'motown',
#   'quiet storm',
#   'soft rock',
#   'soul'],
#  'Lonnie Russ': [],
#  'Pat Thomas': ['highlife'],
#  'Flatt': [],
#  'Vince Guaraldi Trio': ['adult standards',
#   'christmas',
#   'jazz trio',
#   'lounge'],
#  'Pete Antell': [],
#  'The Earls': ['doo-wop'],
#  'Johnny Thunder': [],
#  'Bobby Goldsboro': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'easy listening',
#   'folk',
#   'folk rock',
#   'lounge',
#   'mellow gold',
#   'merseybeat',
#   'nashville sound',
#   'rock-and-roll',
#   'soft rock'],
#  'The Dells': ['chicago soul',
#   'classic soul',
#   'disco',
#   'doo-wop',
#   'funk',
#   'motown',
#   'quiet storm',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'The Pastel Six': ['surf music'],
#  'Sandy Stewart': [],
#  'Ned Miller': ['country gospel', 'nashville sound'],
#  'The Rebels': [],
#  'The Toy Dolls': [],
#  'Marion Worth': [],
#  'Joe Harnell': ['space age pop'],
#  'Mahalia Jackson': ['gospel'],
#  'Don Covay': ['classic soul', 'rhythm and blues', 'soul', 'southern soul'],
#  'The Rooftop Singers': ['american folk revival'],
#  'Roosevelt Fountain': [],
#  'Lou Christie': ['brill building pop',
#   'bubblegum pop',
#   'doo-wop',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll'],
#  'Jan Bradley': ['chicago soul'],
#  'Baby Jane': [],
#  'The Cascades': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'doo-wop',
#   'rock-and-roll'],
#  'The Alley Cats': [],
#  'Dobie Gray': ['northern soul'],
#  'The Moments': ['classic soul',
#   'disco',
#   'funk',
#   'motown',
#   'quiet storm',
#   'soul',
#   'southern soul'],
#  'Jerry Landis': [],
#  'Charlie Byrd': ['bebop', 'bossa nova', 'cool jazz', 'jazz', 'jazz guitar'],
#  'Bill Pursell': [],
#  'The Ribbons': [],
#  'Carl Butler': [],
#  'Rufus Thomas': ['classic soul',
#   'deep funk',
#   'funk',
#   'memphis blues',
#   'memphis soul',
#   'motown',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'The Furys': [],
#  'The Rumblers': ['surf music'],
#  'Cannonball Adderley': ['bebop',
#   'big band',
#   'contemporary post-bop',
#   'cool jazz',
#   'hard bop',
#   'jazz',
#   'jazz blues',
#   'jazz funk',
#   'jazz fusion',
#   'soul jazz',
#   'vocal jazz'],
#  'Johnny Cymbal': [],
#  'Boots Randolph': [],
#  'Jackie DeShannon': ['brill building pop', 'bubblegum pop', 'folk rock'],
#  'Johnny Beecher': [],
#  'The Shepherd Sisters': [],
#  'Rolf Harris': [],
#  'Jimmy Holiday': ['deep southern soul'],
#  'Bobby Callender': ['classic psychedelic rock'],
#  'The Rocky Fellers': [],
#  'Little Peggy March': ['brill building pop'],
#  'Baby Washington': ['beach music',
#   'classic soul',
#   'rhythm and blues',
#   'southern soul'],
#  'James Gilreath': [],
#  'The Rip Chords': ['surf music'],
#  'The Percells': [],
#  'The Appalachians': [],
#  'Kenny Chandler': [],
#  'Martha': ['indie punk', 'uk diy punk'],
#  'Darlene Love': ['brill building pop', 'christmas'],
#  'Theola Kilgore': [],
#  'Wayne Newton': ['adult standards',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'vocal jazz'],
#  'The Raindrops': ['brill building pop'],
#  'Ray Barretto': ['boogaloo',
#   'cuban rumba',
#   'latin jazz',
#   'mambo',
#   'salsa international'],
#  'Steve Allen': ['progressive uplifting trance', 'uplifting trance'],
#  'Barbara Lewis': ['brill building pop',
#   'classic soul',
#   'motown',
#   'rhythm and blues'],
#  'Matt Lucas': [],
#  'Wilson Pickett': ['brill building pop',
#   'christmas',
#   'classic rock',
#   'classic soul',
#   'disco',
#   'folk rock',
#   'funk',
#   'memphis soul',
#   'motown',
#   'rhythm and blues',
#   'rock-and-roll',
#   'rockabilly',
#   'soul',
#   'southern soul'],
#  'Lesley Gore': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'classic girl group',
#   'folk rock',
#   'motown',
#   'rock-and-roll'],
#  'Kyu Sakamoto': ['enka'],
#  'Frankie Laine': ['adult standards',
#   'brill building pop',
#   'christmas',
#   'cowboy western',
#   'deep adult standards',
#   'easy listening',
#   'lounge',
#   'nashville sound',
#   'rock-and-roll'],
#  'The Righteous Brothers': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'mellow gold',
#   'motown',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Five Du-Tones': ['chicago soul'],
#  'Otis Redding': ['christmas',
#   'classic soul',
#   'funk',
#   'memphis soul',
#   'soul',
#   'soul blues',
#   'southern soul'],
#  'Tom Glazer': [],
#  'The Tymes': ['brill building pop',
#   'classic soul',
#   'doo-wop',
#   'motown',
#   'rhythm and blues'],
#  'Joe Hinton': [],
#  'Percy Mayfield': ['jazz blues', 'rhythm and blues'],
#  'The Essex': ['classic girl group', 'rhythm and blues'],
#  'Dave Dudley': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Lonnie Mack': ['blues',
#   'blues-rock',
#   'electric blues',
#   'modern blues',
#   'southern rock',
#   'texas blues'],
#  'Ronnie Carroll': ['classic eurovision'],
#  'Doris Troy': ['brill building pop', 'northern soul', 'southern soul'],
#  'Randy': [],
#  'Kirby St. Romain': [],
#  'The Glencoves': [],
#  'The Classics': ['doo-wop', 'vocal harmony group'],
#  'The Surfaris': ['surf music'],
#  'Inez Foxx': [],
#  'James MacArthur': [],
#  'The Four Pennies': ['british invasion', 'merseybeat', 'rock-and-roll'],
#  'Roy Clark': ['country gospel',
#   'cowboy western',
#   'nashville sound',
#   'traditional country',
#   'western swing'],
#  'The Cupids': [],
#  'Mel Carter': [],
#  'The Blenders': ['a cappella', 'barbershop'],
#  'Kai Winding': ['jazz brass', 'jazz trombone', 'space age pop'],
#  'Kim Weston': ['motown', 'northern soul'],
#  'Major Lance': ['beach music',
#   'brill building pop',
#   'chicago soul',
#   'classic soul',
#   'motown',
#   'northern soul',
#   'rhythm and blues',
#   'soul'],
#  'Al Casey': ['surf music'],
#  'Andrea Carroll': [],
#  'Freddie Scott': ['southern soul'],
#  'Trini Lopez': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'merseybeat',
#   'rock-and-roll'],
#  'The Astronauts': ['surf music'],
#  'Burt Bacharach': ['adult standards',
#   'brill building pop',
#   'easy listening',
#   'lounge'],
#  'Allan Sherman': ['comic'],
#  'Johnny Caswell': ['deep northern soul'],
#  'Jack Nitzsche': ['surf music'],
#  'Little Johnny Taylor': ['soul blues'],
#  'T.K. Hulin': ['swamp pop'],
#  'The Pixies Three': ['classic girl group'],
#  'Tammy Montgomery': [],
#  'Garnet Mimms': ['northern soul'],
#  'Nancy Wilson': ['adult standards',
#   'bebop',
#   'cabaret',
#   'christmas',
#   'cool jazz',
#   'jazz',
#   'lounge',
#   'soul',
#   'vocal jazz'],
#  'The Jaynetts': ['classic girl group'],
#  'The Ronettes': ['brill building pop',
#   'christmas',
#   'classic girl group',
#   'motown',
#   'rock-and-roll'],
#  'The Busters': ['euroska', 'ska', 'ska revival', 'traditional ska'],
#  'Jimmy Durante': ['adult standards',
#   'cabaret',
#   'christmas',
#   'easy listening',
#   'lounge',
#   'swing',
#   'vocal jazz'],
#  'Tracey Dey': [],
#  'Keith Colley': [],
#  'Donald Jenkins': [],
#  'Nino Tempo': [],
#  'Patti LaBelle': ['disco',
#   'funk',
#   'motown',
#   'neo soul',
#   'new jack swing',
#   'quiet storm',
#   'r&b',
#   'soul',
#   'urban contemporary'],
#  "The O'Jays": ['classic soul',
#   'disco',
#   'funk',
#   'motown',
#   'post-disco',
#   'quiet storm',
#   'soul',
#   'southern soul',
#   'urban contemporary'],
#  'Jimmy Gilmer': [],
#  'Betty Harris': ['classic soul', 'southern soul'],
#  'Los Indios Tabajaras': ['easy listening', 'romantico'],
#  'The Village Stompers': [],
#  'The Smothers Brothers': ['comic'],
#  'Joe Perkins': [],
#  'The Hearts': [],
#  'Lou Johnson': ['northern soul'],
#  'Vito': [],
#  'Robin Ward': ['brill building pop'],
#  'The Caravelles': [],
#  'The Dynamics': ['acid jazz',
#   'afrobeat',
#   'deep funk',
#   'funk',
#   'indie jazz',
#   'nu jazz',
#   'soul'],
#  'Joey Powers': ['deep adult standards'],
#  'The Secrets': [],
#  'Joan Baez': ['american folk revival',
#   'folk',
#   'folk rock',
#   'folk-pop',
#   'singer-songwriter',
#   'traditional folk'],
#  'Murry Kellum': [],
#  'Shirley Ellis': ['northern soul'],
#  'The Murmaids': ['brill building pop', 'classic girl group'],
#  'Betty Everett': ['brill building pop',
#   'chicago soul',
#   'classic soul',
#   'motown',
#   'rhythm and blues',
#   'southern soul'],
#  'Lena Horne': ['adult standards',
#   'cabaret',
#   'christmas',
#   'lounge',
#   'vocal jazz'],
#  'Johnnie Taylor': ['classic soul',
#   'funk',
#   'memphis soul',
#   'motown',
#   'quiet storm',
#   'soul',
#   'soul blues',
#   'southern soul'],
#  'The Trashmen': ['classic garage rock', 'protopunk', 'surf music'],
#  "Brooks O'Dell": ['deep southern soul'],
#  'Jimmy Velvet': [],
#  'The Allisons': [],
#  'The Baja Marimba Band': [],
#  'Dale Ward': ['vintage swoon'],
#  'The Girlfriends': [],
#  'The Crescents': [],
#  'Anna King': [],
#  'Pete Seeger': ['american folk revival',
#   'appalachian folk',
#   'banjo',
#   'folk',
#   'old-time',
#   'traditional folk'],
#  'The Sapphires': ['northern soul'],
#  'The Beatles': ['british invasion', 'merseybeat', 'psychedelic rock', 'rock'],
#  'Lefty Frizzell': ['country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'western swing'],
#  'Hank Jacobs': [],
#  'Dusty Springfield': ['adult standards',
#   'brill building pop',
#   'british invasion',
#   'christmas',
#   'folk',
#   'folk rock',
#   'lounge',
#   'mellow gold',
#   'motown',
#   'soul'],
#  'Timmy Shaw': [],
#  'Diane Renay': ['brill building pop'],
#  'The Pyramids': ['surf music'],
#  'The Diplomats': ['dirty south rap',
#   'gangster rap',
#   'hardcore hip hop',
#   'hip hop',
#   'pop rap',
#   'rap',
#   'southern hip hop',
#   'trap music'],
#  'Tommy Tucker': [],
#  'The Drew-Vels': [],
#  'Jody Miller': ['country gospel', 'nashville sound'],
#  'The Devotions': [],
#  'Little Jr. Parker': [],
#  'Louis Armstrong': ['adult standards',
#   'christmas',
#   'dixieland',
#   'jazz trumpet',
#   'new orleans jazz',
#   'swing',
#   'vocal jazz'],
#  'The Dave Clark Five': ['british invasion',
#   'bubblegum pop',
#   'folk rock',
#   'merseybeat'],
#  'Chris Crosby': [],
#  'The Monarchs': [],
#  'Scott English': [],
#  'Donna Lynn': [],
#  'Terry Stafford': [],
#  'The Serendipity Singers': ['american folk revival'],
#  'Soul Sisters': [],
#  'The Swans': [],
#  'The Searchers': ['adult standards',
#   'brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Swinging Blue Jeans': ['adult standards',
#   'brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'Danny Williams': ['merseybeat'],
#  'Pete Drake': ['steel guitar'],
#  'Z.Z. Hill': ['soul', 'soul blues', 'southern soul', 'southern soul blues'],
#  'Tony Clarke': ['northern soul'],
#  'Justine Washington': [],
#  'Irma Thomas': ['classic soul',
#   'louisiana blues',
#   'new orleans blues',
#   'rhythm and blues',
#   'soul',
#   'southern soul'],
#  'B.B. King': ['blues',
#   'blues-rock',
#   'classic rock',
#   'electric blues',
#   'jazz blues',
#   'soul blues',
#   'traditional blues'],
#  'Barbra Streisand': ['adult standards',
#   'christmas',
#   'disco',
#   'mellow gold',
#   'soft rock'],
#  'The Reflections': [],
#  'Al Hirt': ['christmas',
#   'dixieland',
#   'easy listening',
#   'jazz trumpet',
#   'lounge',
#   'new orleans jazz',
#   'space age pop'],
#  'The Ray Charles Singers': ['easy listening'],
#  'Sugar Pie DeSanto': ['rhythm and blues', 'soul', 'southern soul'],
#  'The Bachelors': ['adult standards',
#   'brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'christmas',
#   'merseybeat',
#   'rock-and-roll'],
#  'Billy J. Kramer': ['adult standards',
#   'brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'christmas',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll',
#   'rockabilly'],
#  'The Bermudas': [],
#  'The Simon Sisters': [],
#  'The Dixie Cups': ['brill building pop', 'classic girl group'],
#  'Brenda Holloway': ['classic soul', 'motown', 'northern soul'],
#  'Barbara': ['cabaret', 'chanson'],
#  'The Rolling Stones': ['album rock',
#   'british invasion',
#   'classic rock',
#   'protopunk',
#   'rock'],
#  'Bernadette Carroll': [],
#  'Lucille Starr': ['canadian country', "traditional rock 'n roll"],
#  'The Hollies': ['album rock',
#   'art rock',
#   'blues-rock',
#   'brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'christmas',
#   'classic rock',
#   'folk',
#   'folk rock',
#   'mellow gold',
#   'merseybeat',
#   'psychedelic rock',
#   'rock',
#   'rock-and-roll',
#   'rockabilly',
#   'roots rock',
#   'soft rock'],
#  'Millie Small': ['rock steady', 'ska revival'],
#  'Christine Quaite': [],
#  'The Overlanders': ['british invasion', 'merseybeat'],
#  'Johnny Rivers': ['brill building pop',
#   'bubblegum pop',
#   'folk rock',
#   'mellow gold',
#   'merseybeat',
#   'rock-and-roll'],
#  'Round Robin': [],
#  'Alvin Robinson': [],
#  'Rufus': ['disco', 'funk', 'motown', 'post-disco', 'quiet storm', 'soul'],
#  'Rita Pavone': ['classic italian pop', 'italian pop', 'ye ye'],
#  'Clarence Ashe': ['deep southern soul'],
#  'Stevie Wonder': ['boston hardcore', 'funk', 'motown', 'quiet storm', 'soul'],
#  'Roger Miller': ['country gospel',
#   'cowboy western',
#   'folk',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'traditional folk',
#   'western swing'],
#  'The Soul Sisters': [],
#  'The Premiers': ['classic garage rock'],
#  'The Jelly Beans': ['brill building pop'],
#  'Jimmy Hughes': ['southern soul'],
#  'Earl-Jean': [],
#  'Boston Pops Orchestra Arthur Fiedler': [],
#  'Cilla Black': ['adult standards',
#   'brill building pop',
#   'bubblegum pop',
#   'christmas',
#   'merseybeat',
#   'rock-and-roll'],
#  'Buck Owens': ['country',
#   'country gospel',
#   'country rock',
#   'cowboy western',
#   'nashville sound',
#   'outlaw country',
#   'traditional country',
#   'traditional folk',
#   'western swing'],
#  'The Chartbusters': [],
#  'The Ska Kings': [],
#  'The Ray Conniff Singers': ['adult standards',
#   'christmas',
#   'easy listening',
#   'lounge'],
#  'Ronnie Dove': ['deep adult standards'],
#  'George Martin': [],
#  'Jackie Ross': ['chicago soul'],
#  'Ronny': ['classic schlager', 'schlager', 'vintage schlager', 'volksmusik'],
#  'Lulu': ['brill building pop',
#   'british invasion',
#   'bubblegum pop',
#   'folk rock',
#   'merseybeat',
#   'rock-and-roll'],
#  'The Animals': ['album rock',
#   'blues-rock',
#   'british invasion',
#   'classic rock',
#   'folk rock',
#   'hard rock',
#   'protopunk',
#   'psychedelic rock',
#   'rock',
#   'rock-and-roll'],
#  ...}

# %% [markdown]
# Now that we have aggregated all of the genres associated with our Billboard Hot 100 artists, we need to make sure that our song data, which contains the dates, is using the same artist names as the ones we cleaned above. This is done in our [source](https://github.com/slotterbackW/music-genres/blob/master/songs_cleaning.py) and rewritten to a new songs file, the results of which can be seen below. With the data munging complete, we're ready to do some analysis!

# %%
with open('./data/cleaned_songs.txt') as cleaned_songs:
    songs_header = cleaned_songs.readline().strip().split('|')
    songs_data = [song.strip().split('|') for song in cleaned_songs.readlines()]
songs_data
# Out:
# [['1958-08-09', 'Poor Little Fool', 'Ricky Nelson', '1'],
#  ['1958-08-09', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '2'],
#  ['1958-08-09', 'Patricia', 'Perez Prado', '3'],
#  ['1958-08-09', 'Splish Splash', 'Bobby Darin', '4'],
#  ['1958-08-09', 'When', 'Kalin Twins', '5'],
#  ['1958-08-09', 'My True Love', 'Jack Scott', '6'],
#  ['1958-08-09', 'Hard Headed Woman', 'Elvis Presley', '7'],
#  ['1958-08-09', "Rebel-'rouser", 'Duane Eddy', '8'],
#  ['1958-08-09', 'Just A Dream', 'Jimmy Clanton', '9'],
#  ['1958-08-09', 'Willie And The Hand Jive', 'The Johnny Otis Show', '9'],
#  ['1958-08-09', 'Yakety Yak', 'The Coasters', '11'],
#  ['1958-08-09', 'If Dreams Came True', 'Pat Boone', '12'],
#  ['1958-08-09', 'Fever', 'Peggy Lee', '13'],
#  ['1958-08-09', 'Little Star', 'The Elegants', '14'],
#  ['1958-08-09', 'Ginger Bread', 'Frankie Avalon', '15'],
#  ['1958-08-09', 'Everybody Loves A Lover', 'Doris Day', '16'],
#  ['1958-08-09', 'One Summer Night', 'The Danleers', '17'],
#  ['1958-08-09', 'Born Too Late', 'Poni-Tails', '18'],
#  ['1958-08-09',
#   'Left Right Out Of Your Heart (Hi Lee Hi Lo Hi Lup Up Up)',
#   'Patti Page',
#   '19'],
#  ['1958-08-09', 'Endless Sleep', 'Jody Reynolds', '20'],
#  ['1958-08-09', 'Western Movies', 'The Olympics', '21'],
#  ['1958-08-09', 'Guess Things Happen That Way', 'Johnny Cash', '22'],
#  ['1958-08-09', 'For Your Precious Love', 'Jerry Butler', '23'],
#  ['1958-08-09', 'Early In The Morning', 'The Rinky-Dinks', '24'],
#  ['1958-08-09', 'Somebody Touched Me', 'Buddy Knox', '25'],
#  ['1958-08-09', 'Are You Really Mine', 'Jimmie Rodgers', '26'],
#  ['1958-08-09', 'Do You Want To Dance', 'Bobby Freeman', '27'],
#  ['1958-08-09', 'A Certain Smile', 'Johnny Mathis', '28'],
#  ['1958-08-09', 'Enchanted Island', 'The Four Lads', '29'],
#  ['1958-08-09', 'Moon Talk', 'Perry Como', '30'],
#  ['1958-08-09', 'What Am I Living For', 'Chuck Willis', '31'],
#  ['1958-08-09', 'Think It Over', 'The Crickets', '32'],
#  ['1958-08-09', 'Rock-in Robin', 'Bobby Day', '33'],
#  ['1958-08-09', 'Bird Dog', 'The Everly Brothers', '34'],
#  ['1958-08-09', 'Stupid Cupid', 'Connie Francis', '35'],
#  ['1958-08-09', 'Blue Blue Day', 'Don Gibson', '36'],
#  ['1958-08-09', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '37'],
#  ['1958-08-09', 'Chantilly Lace', 'Big Bopper', '38'],
#  ['1958-08-09', 'Angel Baby', 'Dean Martin', '39'],
#  ['1958-08-09', 'Early In The Morning', 'Buddy Holly', '40'],
#  ['1958-08-09', 'Secretly', 'Jimmie Rodgers', '41'],
#  ['1958-08-09', "Susie Darlin'", 'Robin Luke', '42'],
#  ['1958-08-09', 'Devoted To You', 'The Everly Brothers', '43'],
#  ['1958-08-09', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '44'],
#  ['1958-08-09', 'Blue Boy', 'Jim Reeves', '45'],
#  ['1958-08-09', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '46'],
#  ['1958-08-09', 'The Purple People Eater', 'Sheb Wooley', '47'],
#  ['1958-08-09', 'You Cheated', 'The Slades', '48'],
#  ['1958-08-09', 'Come What May', 'Clyde McPhatter', '49'],
#  ['1958-08-09', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '50'],
#  ['1958-08-09', 'Alone With You', 'Faron Young', '51'],
#  ['1958-08-09', 'Summertime Blues', 'Eddie Cochran', '52'],
#  ['1958-08-09', 'Over And Over', 'Bobby Day', '53'],
#  ['1958-08-09', "Don't Ask Me Why", 'Elvis Presley', '54'],
#  ['1958-08-09', 'The Freeze', 'Tony', '55'],
#  ['1958-08-09', 'Leroy', 'Jack Scott', '56'],
#  ['1958-08-09', "That's How Much I Love You", 'Pat Boone', '57'],
#  ['1958-08-09', 'Drip Drop', 'The Drifters', '58'],
#  ['1958-08-09', 'No Chemise, Please', 'Gerry Granahan', '59'],
#  ['1958-08-09', 'I Wonder Why', 'Dion', '60'],
#  ['1958-08-09', 'Win Your Love For Me', 'Sam Cooke', '61'],
#  ['1958-08-09', 'Crazy Eyes For You', 'Bobby Hamilton', '62'],
#  ['1958-08-09', 'Return To Me', 'Dean Martin', '63'],
#  ['1958-08-09', 'You Need Hands', 'Eydie Gorme', '64'],
#  ['1958-08-09', 'Padre', 'Toni Arden', '65'],
#  ['1958-08-09', 'High School Confidential', 'Jerry Lee Lewis', '66'],
#  ['1958-08-09', 'Lean Jean', 'Bill Haley', '67'],
#  ['1958-08-09', "You're Making A Mistake", 'The Platters', '68'],
#  ['1958-08-09', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '69'],
#  ['1958-08-09', 'Try The Impossible', 'Lee Andrews', '70'],
#  ['1958-08-09', 'Midnight', 'Paul Anka', '71'],
#  ['1958-08-09', 'Little Mary', 'Fats Domino', '72'],
#  ['1958-08-09', 'Tears On My Pillow', 'Little Anthony', '73'],
#  ['1958-08-09', 'Kathy-O', 'The Diamonds', '74'],
#  ['1958-08-09', "Let's Go Steady For The Summer", "The Three G's", '75'],
#  ['1958-08-09', 'Just Married', 'Marty Robbins', '76'],
#  ['1958-08-09', 'Jennie Lee', 'Jan', '77'],
#  ['1958-08-09', "Harvey's Got A Girl Friend", 'Royal Teens', '78'],
#  ['1958-08-09',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '79'],
#  ['1958-08-09', 'Happy Years', 'The Diamonds', '80'],
#  ['1958-08-09', 'Looking Back', 'Nat King Cole', '81'],
#  ['1958-08-09', 'Young And Warm And Wonderful', 'Tony Bennett', '81'],
#  ['1958-08-09', 'Jealousy', 'Kitty Wells', '83'],
#  ['1958-08-09', "You're A Sweetheart", 'Little Willie John', '84'],
#  ['1958-08-09', 'The Wizard', 'Jimmie Rodgers', '85'],
#  ['1958-08-09', 'Moonlight Bay', 'The Drifters', '86'],
#  ['1958-08-09', 'Come In Stranger', 'Johnny Cash', '87'],
#  ['1958-08-09', 'Cerveza', 'Boots Brown', '88'],
#  ['1958-08-09',
#   'The Purple People Eater Meets The Witch Doctor',
#   'Joe South',
#   '89'],
#  ['1958-08-09', "Don't Go Home", 'The Playmates', '90'],
#  ['1958-08-09', 'All I Have To Do Is Dream', 'The Everly Brothers', '91'],
#  ['1958-08-09', 'La Paloma', 'Billy Vaughn', '92'],
#  ['1958-08-09', 'I Believe In You', 'Robert', '93'],
#  ['1958-08-09', 'Midnighter', 'The Champs', '94'],
#  ['1958-08-09', 'Chariot Rock', 'The Champs', '95'],
#  ['1958-08-09', 'Down In Virginia', 'Jimmy Reed', '96'],
#  ['1958-08-09', 'Sunday Barbecue', 'Tennessee Ernie Ford', '97'],
#  ['1958-08-09', 'Gotta Have Rain', 'Eydie Gorme', '98'],
#  ['1958-08-09', 'Nothing In The World', 'Nat King Cole', '99'],
#  ['1958-08-09', 'Baubles, Bangles And Beads', 'The Kirby Stone Four', '100'],
#  ['1958-08-16', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '1'],
#  ['1958-08-16', 'Little Star', 'The Elegants', '2'],
#  ['1958-08-16', 'My True Love', 'Jack Scott', '3'],
#  ['1958-08-16', 'Poor Little Fool', 'Ricky Nelson', '4'],
#  ['1958-08-16', 'Patricia', 'Perez Prado', '5'],
#  ['1958-08-16', 'Just A Dream', 'Jimmy Clanton', '5'],
#  ['1958-08-16', 'When', 'Kalin Twins', '7'],
#  ['1958-08-16', "Rebel-'rouser", 'Duane Eddy', '8'],
#  ['1958-08-16', 'Fever', 'Peggy Lee', '9'],
#  ['1958-08-16', 'Splish Splash', 'Bobby Darin', '10'],
#  ['1958-08-16', 'Ginger Bread', 'Frankie Avalon', '11'],
#  ['1958-08-16', 'Willie And The Hand Jive', 'The Johnny Otis Show', '12'],
#  ['1958-08-16', 'Hard Headed Woman', 'Elvis Presley', '13'],
#  ['1958-08-16', 'Everybody Loves A Lover', 'Doris Day', '14'],
#  ['1958-08-16', 'If Dreams Came True', 'Pat Boone', '15'],
#  ['1958-08-16', 'Born Too Late', 'Poni-Tails', '16'],
#  ['1958-08-16', 'Bird Dog', 'The Everly Brothers', '17'],
#  ['1958-08-16', 'Yakety Yak', 'The Coasters', '18'],
#  ['1958-08-16', 'Western Movies', 'The Olympics', '19'],
#  ['1958-08-16', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '20'],
#  ['1958-08-16', 'One Summer Night', 'The Danleers', '21'],
#  ['1958-08-16', 'Somebody Touched Me', 'Buddy Knox', '22'],
#  ['1958-08-16',
#   'Left Right Out Of Your Heart (Hi Lee Hi Lo Hi Lup Up Up)',
#   'Patti Page',
#   '23'],
#  ['1958-08-16', 'Are You Really Mine', 'Jimmie Rodgers', '24'],
#  ['1958-08-16', 'Devoted To You', 'The Everly Brothers', '25'],
#  ['1958-08-16', 'Early In The Morning', 'The Rinky-Dinks', '26'],
#  ['1958-08-16', "Susie Darlin'", 'Robin Luke', '27'],
#  ['1958-08-16', 'Think It Over', 'The Crickets', '28'],
#  ['1958-08-16', 'Chantilly Lace', 'Big Bopper', '29'],
#  ['1958-08-16', 'A Certain Smile', 'Johnny Mathis', '30'],
#  ['1958-08-16', 'Stupid Cupid', 'Connie Francis', '31'],
#  ['1958-08-16', 'Endless Sleep', 'Jody Reynolds', '32'],
#  ['1958-08-16', 'For Your Precious Love', 'Jerry Butler', '33'],
#  ['1958-08-16', 'Moon Talk', 'Perry Como', '34'],
#  ['1958-08-16', 'Blue Blue Day', 'Don Gibson', '35'],
#  ['1958-08-16', 'Enchanted Island', 'The Four Lads', '36'],
#  ['1958-08-16', 'Early In The Morning', 'Buddy Holly', '37'],
#  ['1958-08-16', 'Rock-in Robin', 'Bobby Day', '38'],
#  ['1958-08-16', 'Guess Things Happen That Way', 'Johnny Cash', '39'],
#  ['1958-08-16', 'Angel Baby', 'Dean Martin', '40'],
#  ['1958-08-16', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '41'],
#  ['1958-08-16', 'What Am I Living For', 'Chuck Willis', '42'],
#  ['1958-08-16', 'Do You Want To Dance', 'Bobby Freeman', '43'],
#  ['1958-08-16', 'Summertime Blues', 'Eddie Cochran', '44'],
#  ['1958-08-16', "That's How Much I Love You", 'Pat Boone', '45'],
#  ['1958-08-16', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '46'],
#  ['1958-08-16', 'La Paloma', 'Billy Vaughn', '47'],
#  ['1958-08-16', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '48'],
#  ['1958-08-16', 'You Cheated', 'The Slades', '49'],
#  ['1958-08-16', 'The Freeze', 'Tony', '50'],
#  ['1958-08-16',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '51'],
#  ['1958-08-16', 'How The Time Flies', 'Jerry Wallace', '52'],
#  ['1958-08-16', 'Come What May', 'Clyde McPhatter', '53'],
#  ['1958-08-16', 'Win Your Love For Me', 'Sam Cooke', '54'],
#  ['1958-08-16', "Don't Ask Me Why", 'Elvis Presley', '55'],
#  ['1958-08-16', 'Kathy-O', 'The Diamonds', '56'],
#  ['1958-08-16', 'Over And Over', 'Bobby Day', '57'],
#  ['1958-08-16', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '58'],
#  ['1958-08-16', 'Baubles, Bangles And Beads', 'The Kirby Stone Four', '59'],
#  ['1958-08-16', 'Borrowed Dreams', 'Bobby Helms', '60'],
#  ['1958-08-16', 'Hey Girl - Hey Boy', 'Oscar McLollie', '61'],
#  ['1958-08-16', 'Crazy Eyes For You', 'Bobby Hamilton', '62'],
#  ['1958-08-16', 'Tears On My Pillow', 'Little Anthony', '63'],
#  ['1958-08-16', 'The Wizard', 'Jimmie Rodgers', '64'],
#  ['1958-08-16', 'Blue Boy', 'Jim Reeves', '65'],
#  ['1958-08-16', "You're A Sweetheart", 'Little Willie John', '66'],
#  ['1958-08-16', 'Near You', 'Roger Williams', '67'],
#  ['1958-08-16', 'Alone With You', 'Faron Young', '68'],
#  ['1958-08-16', 'Midnight', 'Paul Anka', '69'],
#  ['1958-08-16', 'No Chemise, Please', 'Gerry Granahan', '70'],
#  ['1958-08-16', 'Padre', 'Toni Arden', '71'],
#  ['1958-08-16', 'Lazy Summer Night', 'The Four Preps', '71'],
#  ['1958-08-16', 'Happy Years', 'The Diamonds', '73'],
#  ['1958-08-16', 'Summertime, Summertime', 'The Jamies', '74'],
#  ['1958-08-16', 'Just Like In The Movies', 'The Upbeats', '75'],
#  ['1958-08-16', 'Straighten Up & Fly Right', 'DeJohn Sisters', '76'],
#  ['1958-08-16', 'Secretly', 'Jimmie Rodgers', '77'],
#  ['1958-08-16', 'Chariot Rock', 'The Champs', '78'],
#  ['1958-08-16', 'Delicious!', 'Jim Backus', '79'],
#  ['1958-08-16', "Let's Go Steady For The Summer", "The Three G's", '80'],
#  ['1958-08-16', 'The Purple People Eater', 'Sheb Wooley', '81'],
#  ['1958-08-16', 'Gas Money', 'Jan', '81'],
#  ['1958-08-16', 'Cerveza', 'Boots Brown', '83'],
#  ['1958-08-16', 'Blip Blop', 'Bill Doggett', '84'],
#  ['1958-08-16', "You're Making A Mistake", 'The Platters', '85'],
#  ['1958-08-16', "Harvey's Got A Girl Friend", 'Royal Teens', '86'],
#  ['1958-08-16', 'Gotta Have Rain', 'Eydie Gorme', '87'],
#  ['1958-08-16', 'Dance Everyone Dance', 'Betty Madigan', '88'],
#  ['1958-08-16', 'Devotion', 'Janice Harper', '89'],
#  ['1958-08-16', 'My Life', 'Chuck Willis', '90'],
#  ['1958-08-16', 'Down The Aisle Of Love', 'The Quin-Tones', '91'],
#  ['1958-08-16', 'Return To Me', 'Dean Martin', '92'],
#  ['1958-08-16', 'Down In Virginia', 'Jimmy Reed', '93'],
#  ['1958-08-16', 'Fire Of Love', 'Jody Reynolds', '94'],
#  ['1958-08-16', 'Put A Ring On My Finger', 'Les Paul', '95'],
#  ['1958-08-16', "It's All In The Game", 'Tommy Edwards', '96'],
#  ['1958-08-16', 'Ma Ma Ma Marie', 'The Gaylords', '97'],
#  ['1958-08-16', 'Where The Blue Of The Night', 'Tommy Mara', '98'],
#  ['1958-08-16', 'Who Are They To Say', 'The DeCastro Sisters', '99'],
#  ['1958-08-16', 'Going To Chicago Blues', 'Count Basie', '100'],
#  ['1958-08-23', 'Little Star', 'The Elegants', '1'],
#  ['1958-08-23', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '2'],
#  ['1958-08-23', 'Bird Dog', 'The Everly Brothers', '3'],
#  ['1958-08-23', 'Just A Dream', 'Jimmy Clanton', '4'],
#  ['1958-08-23', 'My True Love', 'Jack Scott', '5'],
#  ['1958-08-23', 'Poor Little Fool', 'Ricky Nelson', '6'],
#  ['1958-08-23', 'Patricia', 'Perez Prado', '7'],
#  ['1958-08-23', 'Born Too Late', 'Poni-Tails', '8'],
#  ['1958-08-23', 'Fever', 'Peggy Lee', '8'],
#  ['1958-08-23', 'When', 'Kalin Twins', '10'],
#  ['1958-08-23', "Rebel-'rouser", 'Duane Eddy', '11'],
#  ['1958-08-23', 'Willie And The Hand Jive', 'The Johnny Otis Show', '12'],
#  ['1958-08-23', 'Western Movies', 'The Olympics', '13'],
#  ['1958-08-23', 'Everybody Loves A Lover', 'Doris Day', '14'],
#  ['1958-08-23', 'Devoted To You', 'The Everly Brothers', '15'],
#  ['1958-08-23', 'Splish Splash', 'Bobby Darin', '16'],
#  ['1958-08-23', 'Ginger Bread', 'Frankie Avalon', '17'],
#  ['1958-08-23', 'If Dreams Came True', 'Pat Boone', '18'],
#  ['1958-08-23', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '19'],
#  ['1958-08-23', 'Are You Really Mine', 'Jimmie Rodgers', '20'],
#  ['1958-08-23', 'Hard Headed Woman', 'Elvis Presley', '21'],
#  ['1958-08-23', 'Stupid Cupid', 'Connie Francis', '22'],
#  ['1958-08-23', "Susie Darlin'", 'Robin Luke', '23'],
#  ['1958-08-23', 'Summertime Blues', 'Eddie Cochran', '24'],
#  ['1958-08-23', 'Rock-in Robin', 'Bobby Day', '25'],
#  ['1958-08-23', 'Tears On My Pillow', 'Little Anthony', '26'],
#  ['1958-08-23', 'One Summer Night', 'The Danleers', '27'],
#  ['1958-08-23', 'Somebody Touched Me', 'Buddy Knox', '28'],
#  ['1958-08-23', 'Early In The Morning', 'The Rinky-Dinks', '29'],
#  ['1958-08-23', 'Chantilly Lace', 'Big Bopper', '30'],
#  ['1958-08-23', 'Think It Over', 'The Crickets', '31'],
#  ['1958-08-23', 'Early In The Morning', 'Buddy Holly', '32'],
#  ['1958-08-23',
#   'Left Right Out Of Your Heart (Hi Lee Hi Lo Hi Lup Up Up)',
#   'Patti Page',
#   '33'],
#  ['1958-08-23', 'A Certain Smile', 'Johnny Mathis', '34'],
#  ['1958-08-23', 'Yakety Yak', 'The Coasters', '35'],
#  ['1958-08-23', 'Moon Talk', 'Perry Como', '36'],
#  ['1958-08-23', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '37'],
#  ['1958-08-23',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '38'],
#  ['1958-08-23', 'La Paloma', 'Billy Vaughn', '39'],
#  ['1958-08-23', "It's All In The Game", 'Tommy Edwards', '40'],
#  ['1958-08-23', 'Over And Over', 'Bobby Day', '41'],
#  ['1958-08-23', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '42'],
#  ['1958-08-23', 'Blue Blue Day', 'Don Gibson', '43'],
#  ['1958-08-23', 'Lazy Summer Night', 'The Four Preps', '44'],
#  ['1958-08-23', 'Win Your Love For Me', 'Sam Cooke', '45'],
#  ['1958-08-23', 'For Your Precious Love', 'Jerry Butler', '46'],
#  ['1958-08-23', 'Do You Want To Dance', 'Bobby Freeman', '47'],
#  ['1958-08-23', 'Enchanted Island', 'The Four Lads', '48'],
#  ['1958-08-23', 'How The Time Flies', 'Jerry Wallace', '49'],
#  ['1958-08-23', 'What Am I Living For', 'Chuck Willis', '50'],
#  ['1958-08-23', 'The Wizard', 'Jimmie Rodgers', '51'],
#  ['1958-08-23', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '52'],
#  ['1958-08-23', 'Kathy-O', 'The Diamonds', '53'],
#  ['1958-08-23', "Don't Ask Me Why", 'Elvis Presley', '54'],
#  ['1958-08-23', 'Guess Things Happen That Way', 'Johnny Cash', '55'],
#  ['1958-08-23', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '56'],
#  ['1958-08-23', 'Carol', 'Chuck Berry', '57'],
#  ['1958-08-23', 'The Freeze', 'Tony', '58'],
#  ['1958-08-23', 'Put A Ring On My Finger', 'Les Paul', '59'],
#  ['1958-08-23', 'Angel Baby', 'Dean Martin', '60'],
#  ['1958-08-23', 'Summertime, Summertime', 'The Jamies', '61'],
#  ['1958-08-23', 'The Ways Of A Woman In Love', 'Johnny Cash', '62'],
#  ['1958-08-23', 'Padre', 'Toni Arden', '63'],
#  ['1958-08-23', "That's How Much I Love You", 'Pat Boone', '64'],
#  ['1958-08-23', 'When Will I Know', 'George Hamilton IV', '65'],
#  ['1958-08-23', 'Gotta Have Rain', 'Eydie Gorme', '66'],
#  ['1958-08-23', 'Cerveza', 'Boots Brown', '67'],
#  ['1958-08-23', 'Dance Everyone Dance', 'Betty Madigan', '68'],
#  ['1958-08-23', 'Chariot Rock', 'The Champs', '69'],
#  ['1958-08-23', 'Alone With You', 'Faron Young', '70'],
#  ['1958-08-23', 'Endless Sleep', 'Jody Reynolds', '71'],
#  ['1958-08-23', 'City Lights', 'Ray Price', '72'],
#  ['1958-08-23', 'Straighten Up & Fly Right', 'DeJohn Sisters', '73'],
#  ['1958-08-23', 'Count Every Star', 'The Rivieras', '74'],
#  ['1958-08-23', 'Blue Boy', 'Jim Reeves', '75'],
#  ['1958-08-23', 'Hey Girl - Hey Boy', 'Oscar McLollie', '76'],
#  ['1958-08-23', 'Happy Years', 'The Diamonds', '77'],
#  ['1958-08-23', 'The Green Mosquito', 'The Tune Rockers', '78'],
#  ['1958-08-23', 'Midnight', 'Paul Anka', '79'],
#  ['1958-08-23', 'Strange Are The Ways Of Love', 'Gogi Grant', '80'],
#  ['1958-08-23', "Prisoner's Song", 'Warren Storm', '81'],
#  ['1958-08-23', 'Topsy II', 'Cozy Cole', '82'],
#  ['1958-08-23', 'Leroy', 'Jack Scott', '83'],
#  ['1958-08-23', 'Borrowed Dreams', 'Bobby Helms', '84'],
#  ['1958-08-23', 'Drip Drop', 'The Drifters', '85'],
#  ['1958-08-23', 'Devotion', 'Janice Harper', '86'],
#  ['1958-08-23', 'Down The Aisle Of Love', 'The Quin-Tones', '87'],
#  ['1958-08-23', 'Near You', 'Roger Williams', '88'],
#  ['1958-08-23', 'My Life', 'Chuck Willis', '89'],
#  ['1958-08-23', 'Fire Of Love', 'Jody Reynolds', '90'],
#  ['1958-08-23', 'Ramrod', 'Duane Eddy', '91'],
#  ['1958-08-23', 'Just Like In The Movies', 'The Upbeats', '92'],
#  ['1958-08-23', 'The Purple People Eater', 'Sheb Wooley', '93'],
#  ['1958-08-23', 'You Cheated', 'The Shields', '94'],
#  ['1958-08-23', 'No One Knows', 'Dion', '95'],
#  ['1958-08-23', 'Return To Me', 'Dean Martin', '96'],
#  ['1958-08-23', 'Little Brass Band', 'David Seville', '97'],
#  ['1958-08-23', "You're A Sweetheart", 'Little Willie John', '98'],
#  ['1958-08-23', 'You Cheated', 'The Slades', '99'],
#  ['1958-08-23', 'Treasure Of Your Love', 'Eileen Rodgers', '100'],
#  ['1958-08-30', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '1'],
#  ['1958-08-30', 'Little Star', 'The Elegants', '2'],
#  ['1958-08-30', 'Bird Dog', 'The Everly Brothers', '3'],
#  ['1958-08-30', 'Just A Dream', 'Jimmy Clanton', '4'],
#  ['1958-08-30', 'Poor Little Fool', 'Ricky Nelson', '5'],
#  ['1958-08-30', 'Patricia', 'Perez Prado', '6'],
#  ['1958-08-30', 'My True Love', 'Jack Scott', '7'],
#  ['1958-08-30', 'When', 'Kalin Twins', '8'],
#  ['1958-08-30', 'Ginger Bread', 'Frankie Avalon', '9'],
#  ['1958-08-30', 'Are You Really Mine', 'Jimmie Rodgers', '10'],
#  ['1958-08-30', 'Born Too Late', 'Poni-Tails', '11'],
#  ['1958-08-30', 'Fever', 'Peggy Lee', '12'],
#  ['1958-08-30', "Rebel-'rouser", 'Duane Eddy', '13'],
#  ['1958-08-30', 'Western Movies', 'The Olympics', '14'],
#  ['1958-08-30', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '15'],
#  ['1958-08-30', 'Willie And The Hand Jive', 'The Johnny Otis Show', '16'],
#  ['1958-08-30', 'Rock-in Robin', 'Bobby Day', '17'],
#  ['1958-08-30', 'Splish Splash', 'Bobby Darin', '18'],
#  ['1958-08-30', 'Everybody Loves A Lover', 'Doris Day', '19'],
#  ['1958-08-30', 'Summertime Blues', 'Eddie Cochran', '20'],
#  ['1958-08-30', 'Devoted To You', 'The Everly Brothers', '21'],
#  ['1958-08-30', "It's All In The Game", 'Tommy Edwards', '22'],
#  ['1958-08-30', 'If Dreams Came True', 'Pat Boone', '23'],
#  ['1958-08-30', 'Tears On My Pillow', 'Little Anthony', '24'],
#  ['1958-08-30', 'Stupid Cupid', 'Connie Francis', '25'],
#  ['1958-08-30', 'Hard Headed Woman', 'Elvis Presley', '26'],
#  ['1958-08-30',
#   'Left Right Out Of Your Heart (Hi Lee Hi Lo Hi Lup Up Up)',
#   'Patti Page',
#   '27'],
#  ['1958-08-30', 'Somebody Touched Me', 'Buddy Knox', '28'],
#  ['1958-08-30', "Susie Darlin'", 'Robin Luke', '29'],
#  ['1958-08-30', 'Moon Talk', 'Perry Como', '30'],
#  ['1958-08-30', 'La Paloma', 'Billy Vaughn', '31'],
#  ['1958-08-30', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '32'],
#  ['1958-08-30', 'Early In The Morning', 'The Rinky-Dinks', '33'],
#  ['1958-08-30', 'A Certain Smile', 'Johnny Mathis', '34'],
#  ['1958-08-30', 'One Summer Night', 'The Danleers', '35'],
#  ['1958-08-30', 'Early In The Morning', 'Buddy Holly', '36'],
#  ['1958-08-30', 'Yakety Yak', 'The Coasters', '37'],
#  ['1958-08-30', 'Lazy Summer Night', 'The Four Preps', '38'],
#  ['1958-08-30',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '39'],
#  ['1958-08-30', 'Chantilly Lace', 'Big Bopper', '40'],
#  ['1958-08-30', 'Win Your Love For Me', 'Sam Cooke', '41'],
#  ['1958-08-30', 'Think It Over', 'The Crickets', '42'],
#  ['1958-08-30', 'Down The Aisle Of Love', 'The Quin-Tones', '43'],
#  ['1958-08-30', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '44'],
#  ['1958-08-30', 'The Wizard', 'Jimmie Rodgers', '45'],
#  ['1958-08-30', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '46'],
#  ['1958-08-30', 'Over And Over', 'Bobby Day', '47'],
#  ['1958-08-30', 'For Your Precious Love', 'Jerry Butler', '48'],
#  ['1958-08-30', 'Put A Ring On My Finger', 'Les Paul', '49'],
#  ['1958-08-30', 'How The Time Flies', 'Jerry Wallace', '50'],
#  ['1958-08-30', 'What Am I Living For', 'Chuck Willis', '51'],
#  ['1958-08-30', 'Blue Blue Day', 'Don Gibson', '52'],
#  ['1958-08-30', 'Ramrod', 'Duane Eddy', '53'],
#  ['1958-08-30', 'Guess Things Happen That Way', 'Johnny Cash', '54'],
#  ['1958-08-30', 'Near You', 'Roger Williams', '55'],
#  ['1958-08-30', 'Carol', 'Chuck Berry', '56'],
#  ['1958-08-30', 'Summertime, Summertime', 'The Jamies', '57'],
#  ['1958-08-30', 'The Ways Of A Woman In Love', 'Johnny Cash', '58'],
#  ['1958-08-30', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '59'],
#  ['1958-08-30', 'The Green Mosquito', 'The Tune Rockers', '60'],
#  ['1958-08-30', 'Kathy-O', 'The Diamonds', '61'],
#  ['1958-08-30', 'Dance Everyone Dance', 'Betty Madigan', '62'],
#  ['1958-08-30', 'Cerveza', 'Boots Brown', '63'],
#  ['1958-08-30', 'Gotta Have Rain', 'Eydie Gorme', '64'],
#  ['1958-08-30', 'My Life', 'Chuck Willis', '65'],
#  ['1958-08-30', 'Fire Of Love', 'Jody Reynolds', '66'],
#  ['1958-08-30', 'Chariot Rock', 'The Champs', '67'],
#  ['1958-08-30', 'When Will I Know', 'George Hamilton IV', '68'],
#  ['1958-08-30', 'You Cheated', 'The Shields', '69'],
#  ['1958-08-30', "Don't Ask Me Why", 'Elvis Presley', '70'],
#  ['1958-08-30', 'Enchanted Island', 'The Four Lads', '71'],
#  ['1958-08-30', 'City Lights', 'Ray Price', '72'],
#  ['1958-08-30', 'Count Every Star', 'The Rivieras', '73'],
#  ['1958-08-30', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '74'],
#  ['1958-08-30', 'Do You Want To Dance', 'Bobby Freeman', '75'],
#  ['1958-08-30', 'The Freeze', 'Tony', '76'],
#  ['1958-08-30', 'Where The Blue Of The Night', 'Tommy Mara', '77'],
#  ['1958-08-30', 'Little Brass Band', 'David Seville', '78'],
#  ['1958-08-30', 'Promise Me, Love', 'Andy Williams', '79'],
#  ['1958-08-30',
#   'Volare (Nel Blu, Dipinto Di Blu)',
#   'The McGuire Sisters',
#   '80'],
#  ['1958-08-30', 'Topsy II', 'Cozy Cole', '81'],
#  ['1958-08-30', 'Devotion', 'Janice Harper', '82'],
#  ['1958-08-30', 'Strange Are The Ways Of Love', 'Gogi Grant', '83'],
#  ['1958-08-30', 'No One Knows', 'Dion', '84'],
#  ['1958-08-30', "Please Don't Do It", 'Dale Wright', '85'],
#  ['1958-08-30', 'Treasure Of Your Love', 'Eileen Rodgers', '86'],
#  ['1958-08-30', "That's How Much I Love You", 'Pat Boone', '87'],
#  ['1958-08-30', 'Angel Baby', 'Dean Martin', '88'],
#  ['1958-08-30', 'Leroy', 'Jack Scott', '89'],
#  ['1958-08-30', "Prisoner's Song", 'Warren Storm', '90'],
#  ['1958-08-30', 'Hey Girl - Hey Boy', 'Oscar McLollie', '91'],
#  ['1958-08-30', 'Endless Sleep', 'Jody Reynolds', '92'],
#  ['1958-08-30', 'Over The Weekend', 'The Playboys', '93'],
#  ['1958-08-30', 'Blue Ribbon Baby', 'Tommy Sands', '94'],
#  ['1958-08-30', 'Old MacDonald', 'The Chargers', '95'],
#  ['1958-08-30', 'Week End', 'The Kingsmen', '96'],
#  ['1958-08-30', 'Up Until Now', 'Johnnie Ray', '97'],
#  ['1958-08-30', 'La-Do-Dada', 'Dale Hawkins', '98'],
#  ['1958-08-30', 'Pickle Up A Doodle', 'Teresa Brewer', '99'],
#  ['1958-08-30', 'Big Daddy', 'Jill Corey', '100'],
#  ['1958-09-06', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '1'],
#  ['1958-09-06', 'Little Star', 'The Elegants', '2'],
#  ['1958-09-06', 'Bird Dog', 'The Everly Brothers', '3'],
#  ['1958-09-06', 'Just A Dream', 'Jimmy Clanton', '4'],
#  ['1958-09-06', 'Patricia', 'Perez Prado', '5'],
#  ['1958-09-06', 'Poor Little Fool', 'Ricky Nelson', '6'],
#  ['1958-09-06', 'My True Love', 'Jack Scott', '7'],
#  ['1958-09-06', 'Rock-in Robin', 'Bobby Day', '8'],
#  ['1958-09-06', 'Ginger Bread', 'Frankie Avalon', '9'],
#  ['1958-09-06', 'Western Movies', 'The Olympics', '10'],
#  ['1958-09-06', "It's All In The Game", 'Tommy Edwards', '11'],
#  ['1958-09-06', 'Fever', 'Peggy Lee', '12'],
#  ['1958-09-06', 'Tears On My Pillow', 'Little Anthony', '13'],
#  ['1958-09-06', 'Born Too Late', 'Poni-Tails', '14'],
#  ['1958-09-06', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '15'],
#  ['1958-09-06', 'Are You Really Mine', 'Jimmie Rodgers', '16'],
#  ['1958-09-06', 'Willie And The Hand Jive', 'The Johnny Otis Show', '17'],
#  ['1958-09-06', 'Everybody Loves A Lover', 'Doris Day', '18'],
#  ['1958-09-06', "Rebel-'rouser", 'Duane Eddy', '19'],
#  ['1958-09-06', 'Stupid Cupid', 'Connie Francis', '20'],
#  ['1958-09-06', 'When', 'Kalin Twins', '21'],
#  ['1958-09-06', 'Devoted To You', 'The Everly Brothers', '22'],
#  ['1958-09-06', 'Down The Aisle Of Love', 'The Quin-Tones', '23'],
#  ['1958-09-06', 'If Dreams Came True', 'Pat Boone', '24'],
#  ['1958-09-06', 'Near You', 'Roger Williams', '25'],
#  ['1958-09-06', 'La Paloma', 'Billy Vaughn', '26'],
#  ['1958-09-06', 'Lazy Summer Night', 'The Four Preps', '27'],
#  ['1958-09-06', "Susie Darlin'", 'Robin Luke', '28'],
#  ['1958-09-06', 'Moon Talk', 'Perry Como', '29'],
#  ['1958-09-06', 'The Ways Of A Woman In Love', 'Johnny Cash', '30'],
#  ['1958-09-06', 'Summertime Blues', 'Eddie Cochran', '31'],
#  ['1958-09-06', 'One Summer Night', 'The Danleers', '32'],
#  ['1958-09-06', 'Somebody Touched Me', 'Buddy Knox', '33'],
#  ['1958-09-06', 'Chantilly Lace', 'Big Bopper', '34'],
#  ['1958-09-06', 'Win Your Love For Me', 'Sam Cooke', '35'],
#  ['1958-09-06', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '36'],
#  ['1958-09-06', 'A Certain Smile', 'Johnny Mathis', '37'],
#  ['1958-09-06', 'Early In The Morning', 'The Rinky-Dinks', '38'],
#  ['1958-09-06',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '39'],
#  ['1958-09-06', 'Put A Ring On My Finger', 'Les Paul', '40'],
#  ['1958-09-06', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '41'],
#  ['1958-09-06', 'Dance Everyone Dance', 'Betty Madigan', '42'],
#  ['1958-09-06', 'No One Knows', 'Dion', '43'],
#  ['1958-09-06', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '44'],
#  ['1958-09-06', 'Splish Splash', 'Bobby Darin', '45'],
#  ['1958-09-06', 'You Cheated', 'The Shields', '46'],
#  ['1958-09-06', 'Early In The Morning', 'Buddy Holly', '47'],
#  ['1958-09-06', 'Summertime, Summertime', 'The Jamies', '48'],
#  ['1958-09-06', 'Blue Blue Day', 'Don Gibson', '49'],
#  ['1958-09-06', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '50'],
#  ['1958-09-06', 'Ramrod', 'Duane Eddy', '51'],
#  ['1958-09-06', 'Carol', 'Chuck Berry', '52'],
#  ['1958-09-06', 'Over And Over', 'Bobby Day', '53'],
#  ['1958-09-06', 'The Wizard', 'Jimmie Rodgers', '54'],
#  ['1958-09-06',
#   'Left Right Out Of Your Heart (Hi Lee Hi Lo Hi Lup Up Up)',
#   'Patti Page',
#   '55'],
#  ['1958-09-06', 'Hard Headed Woman', 'Elvis Presley', '56'],
#  ['1958-09-06', 'Guess Things Happen That Way', 'Johnny Cash', '57'],
#  ['1958-09-06', 'How The Time Flies', 'Jerry Wallace', '58'],
#  ['1958-09-06', 'The Green Mosquito', 'The Tune Rockers', '59'],
#  ['1958-09-06', 'Think It Over', 'The Crickets', '60'],
#  ['1958-09-06', 'My Life', 'Chuck Willis', '61'],
#  ['1958-09-06', 'Cerveza', 'Boots Brown', '62'],
#  ['1958-09-06', 'Gotta Have Rain', 'Eydie Gorme', '63'],
#  ['1958-09-06', 'Enchanted Island', 'The Four Lads', '64'],
#  ['1958-09-06', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '65'],
#  ['1958-09-06', 'Topsy II', 'Cozy Cole', '66'],
#  ['1958-09-06', 'Chariot Rock', 'The Champs', '67'],
#  ['1958-09-06', 'Promise Me, Love', 'Andy Williams', '68'],
#  ['1958-09-06', 'Treasure Of Your Love', 'Eileen Rodgers', '69'],
#  ['1958-09-06', 'La-Do-Dada', 'Dale Hawkins', '70'],
#  ['1958-09-06', 'City Lights', 'Ray Price', '71'],
#  ['1958-09-06', "Your Cheatin' Heart", 'George Hamilton IV', '72'],
#  ['1958-09-06', 'What Am I Living For', 'Chuck Willis', '73'],
#  ['1958-09-06', 'Yakety Yak', 'The Coasters', '74'],
#  ['1958-09-06', 'When Will I Know', 'George Hamilton IV', '75'],
#  ['1958-09-06', 'Where The Blue Of The Night', 'Tommy Mara', '76'],
#  ['1958-09-06', "Please Don't Do It", 'Dale Wright', '77'],
#  ['1958-09-06', 'Blue Boy', 'Jim Reeves', '78'],
#  ['1958-09-06', 'Alone With You', 'Faron Young', '79'],
#  ['1958-09-06', 'Kathy-O', 'The Diamonds', '80'],
#  ['1958-09-06', 'Up Until Now', 'Johnnie Ray', '81'],
#  ['1958-09-06', 'Count Every Star', 'The Rivieras', '82'],
#  ['1958-09-06', 'Strange Are The Ways Of Love', 'Gogi Grant', '83'],
#  ['1958-09-06', 'Week End', 'The Kingsmen', '84'],
#  ['1958-09-06', "I'll Make It All Up To You", 'Jerry Lee Lewis', '85'],
#  ['1958-09-06', "That's How Much I Love You", 'Pat Boone', '86'],
#  ['1958-09-06', 'Over The Weekend', 'The Playboys', '87'],
#  ['1958-09-06', 'Firefly', 'Tony Bennett', '88'],
#  ['1958-09-06', 'Blue Ribbon Baby', 'Tommy Sands', '89'],
#  ['1958-09-06', 'Hey Girl - Hey Boy', 'Oscar McLollie', '90'],
#  ['1958-09-06', "You're A Sweetheart", 'Little Willie John', '91'],
#  ['1958-09-06', 'Invitation To The Blues', 'Ray Price', '92'],
#  ['1958-09-06', "Guess I've Been Around Too Long", 'Carl Smith', '93'],
#  ['1958-09-06', 'Yes I Want You', 'Ivory Joe Hunter', '94'],
#  ['1958-09-06', 'The Ballad Of Thunder Road', 'Robert Mitchum', '95'],
#  ['1958-09-06', 'My Lucky Love', 'Doug Franklin', '96'],
#  ['1958-09-06', 'Endless Sleep', 'Jody Reynolds', '97'],
#  ['1958-09-06', 'Leroy', 'Jack Scott', '98'],
#  ['1958-09-06', 'Angel Baby', 'Dean Martin', '99'],
#  ['1958-09-06', 'The Freeze', 'Tony', '100'],
#  ['1958-09-13', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '1'],
#  ['1958-09-13', 'Bird Dog', 'The Everly Brothers', '2'],
#  ['1958-09-13', 'Little Star', 'The Elegants', '3'],
#  ['1958-09-13', "It's All In The Game", 'Tommy Edwards', '4'],
#  ['1958-09-13', 'Just A Dream', 'Jimmy Clanton', '5'],
#  ['1958-09-13', 'Rock-in Robin', 'Bobby Day', '6'],
#  ['1958-09-13', 'Born Too Late', 'Poni-Tails', '7'],
#  ['1958-09-13', 'Western Movies', 'The Olympics', '8'],
#  ['1958-09-13', 'Tears On My Pillow', 'Little Anthony', '9'],
#  ['1958-09-13', "Susie Darlin'", 'Robin Luke', '10'],
#  ['1958-09-13', 'Patricia', 'Perez Prado', '11'],
#  ['1958-09-13', 'My True Love', 'Jack Scott', '12'],
#  ['1958-09-13', 'Poor Little Fool', 'Ricky Nelson', '13'],
#  ['1958-09-13', 'Devoted To You', 'The Everly Brothers', '14'],
#  ['1958-09-13', 'Are You Really Mine', 'Jimmie Rodgers', '15'],
#  ['1958-09-13', 'Summertime Blues', 'Eddie Cochran', '16'],
#  ['1958-09-13', 'Ginger Bread', 'Frankie Avalon', '17'],
#  ['1958-09-13', 'Stupid Cupid', 'Connie Francis', '18'],
#  ['1958-09-13', 'Everybody Loves A Lover', 'Doris Day', '19'],
#  ['1958-09-13', 'Down The Aisle Of Love', 'The Quin-Tones', '20'],
#  ['1958-09-13', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '21'],
#  ['1958-09-13', 'Fever', 'Peggy Lee', '22'],
#  ['1958-09-13', 'Lazy Summer Night', 'The Four Preps', '23'],
#  ['1958-09-13', 'The Ways Of A Woman In Love', 'Johnny Cash', '24'],
#  ['1958-09-13', 'How The Time Flies', 'Jerry Wallace', '25'],
#  ['1958-09-13', 'Near You', 'Roger Williams', '26'],
#  ['1958-09-13',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '27'],
#  ['1958-09-13', 'Ramrod', 'Duane Eddy', '28'],
#  ['1958-09-13', 'Carol', 'Chuck Berry', '29'],
#  ['1958-09-13', 'Summertime, Summertime', 'The Jamies', '30'],
#  ['1958-09-13', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '31'],
#  ['1958-09-13', 'Willie And The Hand Jive', 'The Johnny Otis Show', '32'],
#  ['1958-09-13', 'You Cheated', 'The Shields', '33'],
#  ['1958-09-13', 'Dance Everyone Dance', 'Betty Madigan', '34'],
#  ['1958-09-13', 'Chantilly Lace', 'Big Bopper', '35'],
#  ['1958-09-13', 'Somebody Touched Me', 'Buddy Knox', '36'],
#  ['1958-09-13', 'No One Knows', 'Dion', '37'],
#  ['1958-09-13', 'Put A Ring On My Finger', 'Les Paul', '38'],
#  ['1958-09-13', 'Win Your Love For Me', 'Sam Cooke', '39'],
#  ['1958-09-13', 'When', 'Kalin Twins', '40'],
#  ['1958-09-13', "Rebel-'rouser", 'Duane Eddy', '41'],
#  ['1958-09-13', 'La Paloma', 'Billy Vaughn', '42'],
#  ['1958-09-13', 'One Summer Night', 'The Danleers', '43'],
#  ['1958-09-13', 'Firefly', 'Tony Bennett', '44'],
#  ['1958-09-13', 'The Wizard', 'Jimmie Rodgers', '45'],
#  ['1958-09-13', 'Moon Talk', 'Perry Como', '46'],
#  ['1958-09-13', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '47'],
#  ['1958-09-13', 'The Green Mosquito', 'The Tune Rockers', '48'],
#  ['1958-09-13', 'Promise Me, Love', 'Andy Williams', '49'],
#  ['1958-09-13', 'Topsy II', 'Cozy Cole', '50'],
#  ['1958-09-13', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '51'],
#  ['1958-09-13', 'Early In The Morning', 'Buddy Holly', '52'],
#  ['1958-09-13', 'A Certain Smile', 'Johnny Mathis', '53'],
#  ['1958-09-13', 'Treasure Of Your Love', 'Eileen Rodgers', '54'],
#  ['1958-09-13', 'If Dreams Came True', 'Pat Boone', '55'],
#  ['1958-09-13', 'My Life', 'Chuck Willis', '56'],
#  ['1958-09-13', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '57'],
#  ['1958-09-13', 'Splish Splash', 'Bobby Darin', '58'],
#  ['1958-09-13', 'Ten Commandments Of Love', 'Harvey', '59'],
#  ['1958-09-13', 'Over And Over', 'Bobby Day', '60'],
#  ['1958-09-13', 'There Goes My Heart', 'Joni James', '61'],
#  ['1958-09-13', 'Over The Weekend', 'The Playboys', '62'],
#  ['1958-09-13', 'La-Do-Dada', 'Dale Hawkins', '63'],
#  ['1958-09-13', 'Blue Blue Day', 'Don Gibson', '64'],
#  ['1958-09-13', "It's Only Make Believe", 'Conway Twitty', '65'],
#  ['1958-09-13', 'Cerveza', 'Boots Brown', '66'],
#  ['1958-09-13', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '67'],
#  ['1958-09-13', 'Think It Over', 'The Crickets', '68'],
#  ['1958-09-13', 'Early In The Morning', 'The Rinky-Dinks', '69'],
#  ['1958-09-13', 'The Secret', 'Gordon MacRae', '70'],
#  ['1958-09-13',
#   'Left Right Out Of Your Heart (Hi Lee Hi Lo Hi Lup Up Up)',
#   'Patti Page',
#   '71'],
#  ['1958-09-13', 'Baby Face', 'Little Richard', '72'],
#  ['1958-09-13', 'Break-Up', 'Jerry Lee Lewis', '73'],
#  ['1958-09-13', 'Blue Ribbon Baby', 'Tommy Sands', '74'],
#  ['1958-09-13', 'My Lucky Love', 'Doug Franklin', '75'],
#  ['1958-09-13', 'Mexican Hat Rock', 'The Applejacks', '76'],
#  ['1958-09-13', 'Count Every Star', 'The Rivieras', '77'],
#  ['1958-09-13', 'Hard Headed Woman', 'Elvis Presley', '78'],
#  ['1958-09-13', 'Where The Blue Of The Night', 'Tommy Mara', '79'],
#  ['1958-09-13', 'Chariot Rock', 'The Champs', '80'],
#  ['1958-09-13', 'You Cheated', 'The Slades', '81'],
#  ['1958-09-13', 'Fire Of Love', 'Jody Reynolds', '82'],
#  ['1958-09-13', 'Alone With You', 'Faron Young', '83'],
#  ['1958-09-13', 'Big Brown Eyes', 'The Redjacks', '84'],
#  ['1958-09-13', 'Gas Money', 'Jan', '85'],
#  ['1958-09-13', 'Week End', 'The Kingsmen', '86'],
#  ['1958-09-13', 'The End', 'Earl Grant', '87'],
#  ['1958-09-13', 'The Ballad Of Thunder Road', 'Robert Mitchum', '88'],
#  ['1958-09-13', 'Blue Boy', 'Jim Reeves', '89'],
#  ['1958-09-13', 'Yakety Yak', 'The Coasters', '90'],
#  ['1958-09-13', 'Guess Things Happen That Way', 'Johnny Cash', '91'],
#  ['1958-09-13', 'Topsy I', 'Cozy Cole', '92'],
#  ['1958-09-13', "Please Don't Do It", 'Dale Wright', '93'],
#  ['1958-09-13', 'What Am I Living For', 'Chuck Willis', '94'],
#  ['1958-09-13', 'Kathy-O', 'The Diamonds', '95'],
#  ['1958-09-13', 'Up Until Now', 'Johnnie Ray', '96'],
#  ['1958-09-13', 'Gotta Have Rain', 'Eydie Gorme', '97'],
#  ['1958-09-13', 'I Wish', 'The Platters', '98'],
#  ['1958-09-13', "Your Cheatin' Heart", 'George Hamilton IV', '99'],
#  ['1958-09-13', 'Enchanted Island', 'The Four Lads', '100'],
#  ['1958-09-20', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '1'],
#  ['1958-09-20', 'Bird Dog', 'The Everly Brothers', '2'],
#  ['1958-09-20', "It's All In The Game", 'Tommy Edwards', '3'],
#  ['1958-09-20', 'Little Star', 'The Elegants', '4'],
#  ['1958-09-20', 'Rock-in Robin', 'Bobby Day', '5'],
#  ['1958-09-20', 'Just A Dream', 'Jimmy Clanton', '6'],
#  ['1958-09-20', 'Tears On My Pillow', 'Little Anthony', '7'],
#  ['1958-09-20', "Susie Darlin'", 'Robin Luke', '8'],
#  ['1958-09-20', 'Born Too Late', 'Poni-Tails', '9'],
#  ['1958-09-20', 'Devoted To You', 'The Everly Brothers', '10'],
#  ['1958-09-20', 'Summertime Blues', 'Eddie Cochran', '11'],
#  ['1958-09-20', 'Near You', 'Roger Williams', '12'],
#  ['1958-09-20', 'My True Love', 'Jack Scott', '13'],
#  ['1958-09-20', 'How The Time Flies', 'Jerry Wallace', '14'],
#  ['1958-09-20', 'Patricia', 'Perez Prado', '15'],
#  ['1958-09-20', 'Western Movies', 'The Olympics', '16'],
#  ['1958-09-20', 'Stupid Cupid', 'Connie Francis', '17'],
#  ['1958-09-20', 'Everybody Loves A Lover', 'Doris Day', '18'],
#  ['1958-09-20', 'Poor Little Fool', 'Ricky Nelson', '19'],
#  ['1958-09-20', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '20'],
#  ['1958-09-20', 'Lazy Summer Night', 'The Four Preps', '21'],
#  ['1958-09-20', 'Down The Aisle Of Love', 'The Quin-Tones', '22'],
#  ['1958-09-20', 'Carol', 'Chuck Berry', '23'],
#  ['1958-09-20', 'Are You Really Mine', 'Jimmie Rodgers', '24'],
#  ['1958-09-20', 'The Ways Of A Woman In Love', 'Johnny Cash', '25'],
#  ['1958-09-20', 'Summertime, Summertime', 'The Jamies', '26'],
#  ['1958-09-20', 'Ginger Bread', 'Frankie Avalon', '27'],
#  ['1958-09-20', 'No One Knows', 'Dion', '28'],
#  ['1958-09-20', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '29'],
#  ['1958-09-20', 'Firefly', 'Tony Bennett', '30'],
#  ['1958-09-20', 'You Cheated', 'The Shields', '31'],
#  ['1958-09-20', 'Put A Ring On My Finger', 'Les Paul', '32'],
#  ['1958-09-20', 'Fever', 'Peggy Lee', '33'],
#  ['1958-09-20', 'Chantilly Lace', 'Big Bopper', '34'],
#  ['1958-09-20', 'Promise Me, Love', 'Andy Williams', '35'],
#  ['1958-09-20', 'Somebody Touched Me', 'Buddy Knox', '36'],
#  ['1958-09-20', 'Ramrod', 'Duane Eddy', '37'],
#  ['1958-09-20',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '38'],
#  ['1958-09-20', 'Win Your Love For Me', 'Sam Cooke', '39'],
#  ['1958-09-20', 'Dance Everyone Dance', 'Betty Madigan', '40'],
#  ['1958-09-20', "It's Only Make Believe", 'Conway Twitty', '41'],
#  ['1958-09-20', 'Willie And The Hand Jive', 'The Johnny Otis Show', '42'],
#  ['1958-09-20', 'Topsy II', 'Cozy Cole', '43'],
#  ['1958-09-20', 'The Green Mosquito', 'The Tune Rockers', '44'],
#  ['1958-09-20', 'Treasure Of Your Love', 'Eileen Rodgers', '45'],
#  ['1958-09-20', 'Ten Commandments Of Love', 'Harvey', '46'],
#  ['1958-09-20', 'The Secret', 'Gordon MacRae', '47'],
#  ['1958-09-20', 'Over And Over', 'Bobby Day', '48'],
#  ['1958-09-20', 'The End', 'Earl Grant', '49'],
#  ['1958-09-20', 'Blue Ribbon Baby', 'Tommy Sands', '50'],
#  ['1958-09-20', 'There Goes My Heart', 'Joni James', '51'],
#  ['1958-09-20', "Rebel-'rouser", 'Duane Eddy', '52'],
#  ['1958-09-20', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '53'],
#  ['1958-09-20', 'For My Good Fortune', 'Pat Boone', '54'],
#  ['1958-09-20', 'The Wizard', 'Jimmie Rodgers', '55'],
#  ['1958-09-20', "Fibbin'", 'Patti Page', '56'],
#  ['1958-09-20', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '57'],
#  ['1958-09-20', 'One Summer Night', 'The Danleers', '58'],
#  ['1958-09-20', 'Chariot Rock', 'The Champs', '59'],
#  ['1958-09-20', 'The Day The Rains Came', 'Jane Morgan', '60'],
#  ['1958-09-20', 'La Paloma', 'Billy Vaughn', '61'],
#  ['1958-09-20', 'La-Do-Dada', 'Dale Hawkins', '62'],
#  ['1958-09-20', 'Baby Face', 'Little Richard', '63'],
#  ['1958-09-20', 'When', 'Kalin Twins', '64'],
#  ['1958-09-20', 'Mexican Hat Rock', 'The Applejacks', '65'],
#  ['1958-09-20', 'A Certain Smile', 'Johnny Mathis', '66'],
#  ['1958-09-20', 'Over The Weekend', 'The Playboys', '67'],
#  ['1958-09-20', 'Moon Talk', 'Perry Como', '68'],
#  ['1958-09-20', "Gee, But It's Lonely", 'Pat Boone', '69'],
#  ['1958-09-20', 'Break-Up', 'Jerry Lee Lewis', '70'],
#  ['1958-09-20', 'Topsy I', 'Cozy Cole', '71'],
#  ['1958-09-20', 'Splish Splash', 'Bobby Darin', '72'],
#  ['1958-09-20', 'Early In The Morning', 'The Rinky-Dinks', '73'],
#  ['1958-09-20', "This Little Girl's Gone Rockin'", 'Ruth Brown', '74'],
#  ['1958-09-20', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '75'],
#  ['1958-09-20',
#   'Nine More Miles (The "Faster-Faster" Song)',
#   'Georgie Young',
#   '76'],
#  ['1958-09-20', "Come On, Let's Go", 'Ritchie Valens', '77'],
#  ['1958-09-20', "Please Don't Do It", 'Dale Wright', '78'],
#  ['1958-09-20', 'Cerveza', 'Boots Brown', '79'],
#  ['1958-09-20', 'My Lucky Love', 'Doug Franklin', '80'],
#  ['1958-09-20', 'Hideaway', 'The Four Esquires', '81'],
#  ['1958-09-20', 'If Dreams Came True', 'Pat Boone', '82'],
#  ['1958-09-20', "Your Cheatin' Heart", 'George Hamilton IV', '83'],
#  ['1958-09-20', 'Wendy, Wendy', 'The Four Coins', '84'],
#  ['1958-09-20', 'Real Wild Child', 'Ivan', '85'],
#  ['1958-09-20', 'You Cheated', 'The Slades', '86'],
#  ['1958-09-20', 'Blue Blue Day', 'Don Gibson', '87'],
#  ['1958-09-20', 'To Know Him, Is To Love Him', 'The Teddy Bears', '88'],
#  ['1958-09-20', 'Big Brown Eyes', 'The Redjacks', '89'],
#  ['1958-09-20', 'Fire Of Love', 'Jody Reynolds', '90'],
#  ['1958-09-20', 'I Wish', 'The Platters', '91'],
#  ['1958-09-20', 'Young School Girl', 'Fats Domino', '92'],
#  ['1958-09-20', "Nothin' Shakin'", 'Eddie Fontaine', '93'],
#  ['1958-09-20', 'Hard Headed Woman', 'Elvis Presley', '94'],
#  ['1958-09-20', 'By The Light Of The Silvery Moon', 'Jimmy Bowen', '95'],
#  ['1958-09-20', 'We Have Love', 'Jackie Wilson', '96'],
#  ['1958-09-20', 'You Got That Touch', 'Sonny James', '97'],
#  ['1958-09-20', 'Many A Time', 'Steve Lawrence', '98'],
#  ['1958-09-20', 'When Will I Know', 'George Hamilton IV', '99'],
#  ['1958-09-20', 'Itchy Twitchy Feeling', 'The Swallows', '100'],
#  ['1958-09-27', "It's All In The Game", 'Tommy Edwards', '1'],
#  ['1958-09-27', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '2'],
#  ['1958-09-27', 'Bird Dog', 'The Everly Brothers', '3'],
#  ['1958-09-27', 'Rock-in Robin', 'Bobby Day', '4'],
#  ['1958-09-27', 'Little Star', 'The Elegants', '5'],
#  ['1958-09-27', 'Tears On My Pillow', 'Little Anthony', '6'],
#  ['1958-09-27', "Susie Darlin'", 'Robin Luke', '7'],
#  ['1958-09-27', 'Summertime Blues', 'Eddie Cochran', '8'],
#  ['1958-09-27', 'Just A Dream', 'Jimmy Clanton', '9'],
#  ['1958-09-27', 'Near You', 'Roger Williams', '10'],
#  ['1958-09-27', 'Born Too Late', 'Poni-Tails', '11'],
#  ['1958-09-27', 'Devoted To You', 'The Everly Brothers', '12'],
#  ['1958-09-27', 'How The Time Flies', 'Jerry Wallace', '13'],
#  ['1958-09-27', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '14'],
#  ['1958-09-27', 'The End', 'Earl Grant', '15'],
#  ['1958-09-27', 'Chantilly Lace', 'Big Bopper', '16'],
#  ['1958-09-27', 'Stupid Cupid', 'Connie Francis', '17'],
#  ['1958-09-27', 'Carol', 'Chuck Berry', '18'],
#  ['1958-09-27', 'My True Love', 'Jack Scott', '19'],
#  ['1958-09-27', 'Patricia', 'Perez Prado', '20'],
#  ['1958-09-27', 'You Cheated', 'The Shields', '21'],
#  ['1958-09-27', 'Everybody Loves A Lover', 'Doris Day', '22'],
#  ['1958-09-27', 'Firefly', 'Tony Bennett', '23'],
#  ['1958-09-27', 'Lazy Summer Night', 'The Four Preps', '24'],
#  ['1958-09-27', 'Promise Me, Love', 'Andy Williams', '25'],
#  ['1958-09-27', 'Western Movies', 'The Olympics', '26'],
#  ['1958-09-27', 'Down The Aisle Of Love', 'The Quin-Tones', '27'],
#  ['1958-09-27', 'Summertime, Summertime', 'The Jamies', '28'],
#  ['1958-09-27', 'Are You Really Mine', 'Jimmie Rodgers', '29'],
#  ['1958-09-27', 'No One Knows', 'Dion', '30'],
#  ['1958-09-27', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '31'],
#  ['1958-09-27', 'Treasure Of Your Love', 'Eileen Rodgers', '32'],
#  ['1958-09-27', "It's Only Make Believe", 'Conway Twitty', '33'],
#  ['1958-09-27', 'Put A Ring On My Finger', 'Les Paul', '34'],
#  ['1958-09-27', 'Somebody Touched Me', 'Buddy Knox', '35'],
#  ['1958-09-27', 'Poor Little Fool', 'Ricky Nelson', '36'],
#  ['1958-09-27', 'Win Your Love For Me', 'Sam Cooke', '37'],
#  ['1958-09-27', 'Ramrod', 'Duane Eddy', '38'],
#  ['1958-09-27', 'Topsy II', 'Cozy Cole', '39'],
#  ['1958-09-27', 'Fever', 'Peggy Lee', '40'],
#  ['1958-09-27',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '41'],
#  ['1958-09-27', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '42'],
#  ['1958-09-27', 'The Secret', 'Gordon MacRae', '43'],
#  ['1958-09-27', 'La Paloma', 'Billy Vaughn', '44'],
#  ['1958-09-27', 'La-Do-Dada', 'Dale Hawkins', '45'],
#  ['1958-09-27', "Gee, But It's Lonely", 'Pat Boone', '46'],
#  ['1958-09-27', 'Willie And The Hand Jive', 'The Johnny Otis Show', '47'],
#  ['1958-09-27', "Fibbin'", 'Patti Page', '48'],
#  ['1958-09-27', 'Ten Commandments Of Love', 'Harvey', '49'],
#  ['1958-09-27', 'The Green Mosquito', 'The Tune Rockers', '50'],
#  ['1958-09-27', 'Mexican Hat Rock', 'The Applejacks', '51'],
#  ['1958-09-27', 'Break-Up', 'Jerry Lee Lewis', '52'],
#  ['1958-09-27', 'The Day The Rains Came', 'Jane Morgan', '53'],
#  ['1958-09-27', 'Hideaway', 'The Four Esquires', '54'],
#  ['1958-09-27', 'For My Good Fortune', 'Pat Boone', '55'],
#  ['1958-09-27', 'Baby Face', 'Little Richard', '56'],
#  ['1958-09-27', "This Little Girl's Gone Rockin'", 'Ruth Brown', '57'],
#  ['1958-09-27', 'Over And Over', 'Bobby Day', '58'],
#  ['1958-09-27', 'No One But You (In My Heart)', 'The Ames Brothers', '59'],
#  ['1958-09-27', 'Pussy Cat', 'The Ames Brothers', '60'],
#  ['1958-09-27', 'Dance Everyone Dance', 'Betty Madigan', '61'],
#  ['1958-09-27', 'There Goes My Heart', 'Joni James', '62'],
#  ['1958-09-27', 'I Wish', 'The Platters', '63'],
#  ['1958-09-27', 'Ginger Bread', 'Frankie Avalon', '64'],
#  ['1958-09-27', 'The Ways Of A Woman In Love', 'Johnny Cash', '65'],
#  ['1958-09-27', "Look Who's Blue", 'Don Gibson', '66'],
#  ['1958-09-27', 'You Cheated', 'The Slades', '67'],
#  ['1958-09-27', 'Blue Ribbon Baby', 'Tommy Sands', '68'],
#  ['1958-09-27',
#   'Nine More Miles (The "Faster-Faster" Song)',
#   'Georgie Young',
#   '69'],
#  ['1958-09-27', 'Cerveza', 'Boots Brown', '70'],
#  ['1958-09-27', 'Come Closer To Me (Acercate Mas)', 'Nat King Cole', '71'],
#  ['1958-09-27', 'When I Grow Too Old To Dream', 'Ed Townsend', '72'],
#  ['1958-09-27', "Nothin' Shakin'", 'Eddie Fontaine', '73'],
#  ['1958-09-27', 'Call Me', 'Johnny Mathis', '74'],
#  ['1958-09-27', 'Wendy, Wendy', 'The Four Coins', '75'],
#  ['1958-09-27', "Come On, Let's Go", 'Ritchie Valens', '76'],
#  ['1958-09-27', "Please Don't Do It", 'Dale Wright', '77'],
#  ['1958-09-27', 'Betty Lou Got A New Pair Of Shoes', 'Bobby Freeman', '78'],
#  ['1958-09-27', 'Give Myself A Party', 'Don Gibson', '79'],
#  ['1958-09-27', 'To Know Him, Is To Love Him', 'The Teddy Bears', '80'],
#  ['1958-09-27', 'If Dreams Came True', 'Pat Boone', '81'],
#  ['1958-09-27', 'A Certain Smile', 'Johnny Mathis', '82'],
#  ['1958-09-27', 'Tom Dooley', 'The Kingston Trio', '83'],
#  ['1958-09-27', 'Over The Weekend', 'The Playboys', '84'],
#  ['1958-09-27', 'Real Wild Child', 'Ivan', '85'],
#  ['1958-09-27', 'When', 'Kalin Twins', '86'],
#  ['1958-09-27', 'The Day I Died', 'The Playmates', '87'],
#  ['1958-09-27', 'Topsy I', 'Cozy Cole', '88'],
#  ['1958-09-27', 'With Your Love', 'Jack Scott', '89'],
#  ['1958-09-27', 'Moon Talk', 'Perry Como', '90'],
#  ['1958-09-27', 'Bullwhip Rock', 'Cyclones', '91'],
#  ['1958-09-27', 'Tic Toc', 'Lee Allen', '92'],
#  ['1958-09-27', 'We Have Love', 'Jackie Wilson', '93'],
#  ['1958-09-27', 'You Got That Touch', 'Sonny James', '94'],
#  ['1958-09-27', "Your Cheatin' Heart", 'George Hamilton IV', '95'],
#  ['1958-09-27', 'Leave Me Alone (Let Me Cry)', 'Dicky Doo', '96'],
#  ['1958-09-27', 'Many A Time', 'Steve Lawrence', '97'],
#  ['1958-09-27', 'Early In The Morning', 'The Rinky-Dinks', '98'],
#  ['1958-09-27', 'The Ballad Of Thunder Road', 'Robert Mitchum', '99'],
#  ['1958-09-27', 'Forget Me Not', 'Kalin Twins', '100'],
#  ['1958-10-04', "It's All In The Game", 'Tommy Edwards', '1'],
#  ['1958-10-04', 'Bird Dog', 'The Everly Brothers', '2'],
#  ['1958-10-04', 'Rock-in Robin', 'Bobby Day', '3'],
#  ['1958-10-04', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '4'],
#  ['1958-10-04', 'Little Star', 'The Elegants', '5'],
#  ['1958-10-04', 'Tears On My Pillow', 'Little Anthony', '6'],
#  ['1958-10-04', "Susie Darlin'", 'Robin Luke', '7'],
#  ['1958-10-04', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '8'],
#  ['1958-10-04', 'Summertime Blues', 'Eddie Cochran', '9'],
#  ['1958-10-04', 'Near You', 'Roger Williams', '10'],
#  ['1958-10-04', 'How The Time Flies', 'Jerry Wallace', '11'],
#  ['1958-10-04', 'Just A Dream', 'Jimmy Clanton', '12'],
#  ['1958-10-04', 'The End', 'Earl Grant', '13'],
#  ['1958-10-04', 'Born Too Late', 'Poni-Tails', '14'],
#  ['1958-10-04', 'Chantilly Lace', 'Big Bopper', '15'],
#  ['1958-10-04', 'You Cheated', 'The Shields', '16'],
#  ['1958-10-04', 'Promise Me, Love', 'Andy Williams', '17'],
#  ['1958-10-04', 'Patricia', 'Perez Prado', '18'],
#  ['1958-10-04', 'Carol', 'Chuck Berry', '19'],
#  ['1958-10-04', "It's Only Make Believe", 'Conway Twitty', '20'],
#  ['1958-10-04', 'Devoted To You', 'The Everly Brothers', '21'],
#  ['1958-10-04', 'Topsy II', 'Cozy Cole', '22'],
#  ['1958-10-04', 'Firefly', 'Tony Bennett', '23'],
#  ['1958-10-04', 'My True Love', 'Jack Scott', '24'],
#  ['1958-10-04', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '25'],
#  ['1958-10-04', 'Treasure Of Your Love', 'Eileen Rodgers', '26'],
#  ['1958-10-04', 'No One Knows', 'Dion', '27'],
#  ['1958-10-04', 'Stupid Cupid', 'Connie Francis', '28'],
#  ['1958-10-04', 'Somebody Touched Me', 'Buddy Knox', '29'],
#  ['1958-10-04', 'Are You Really Mine', 'Jimmie Rodgers', '30'],
#  ['1958-10-04', 'Down The Aisle Of Love', 'The Quin-Tones', '31'],
#  ['1958-10-04', 'Western Movies', 'The Olympics', '32'],
#  ['1958-10-04', 'Lazy Summer Night', 'The Four Preps', '33'],
#  ['1958-10-04', 'Pussy Cat', 'The Ames Brothers', '34'],
#  ['1958-10-04', "Gee, But It's Lonely", 'Pat Boone', '35'],
#  ['1958-10-04', 'Summertime, Summertime', 'The Jamies', '36'],
#  ['1958-10-04', 'Tom Dooley', 'The Kingston Trio', '37'],
#  ['1958-10-04', 'Fever', 'Peggy Lee', '38'],
#  ['1958-10-04', 'The Secret', 'Gordon MacRae', '39'],
#  ['1958-10-04', 'Mexican Hat Rock', 'The Applejacks', '40'],
#  ['1958-10-04', 'Win Your Love For Me', 'Sam Cooke', '41'],
#  ['1958-10-04', 'I Wish', 'The Platters', '42'],
#  ['1958-10-04', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '43'],
#  ['1958-10-04', 'La-Do-Dada', 'Dale Hawkins', '44'],
#  ['1958-10-04', 'Everybody Loves A Lover', 'Doris Day', '45'],
#  ['1958-10-04', "Fibbin'", 'Patti Page', '46'],
#  ['1958-10-04', 'Poor Little Fool', 'Ricky Nelson', '47'],
#  ['1958-10-04', 'The Day The Rains Came', 'Jane Morgan', '48'],
#  ['1958-10-04', 'Ramrod', 'Duane Eddy', '49'],
#  ['1958-10-04', "This Little Girl's Gone Rockin'", 'Ruth Brown', '50'],
#  ['1958-10-04', 'There Goes My Heart', 'Joni James', '51'],
#  ['1958-10-04', 'Put A Ring On My Finger', 'Les Paul', '52'],
#  ['1958-10-04', 'La Paloma', 'Billy Vaughn', '53'],
#  ['1958-10-04', 'For My Good Fortune', 'Pat Boone', '54'],
#  ['1958-10-04', 'Baby Face', 'Little Richard', '55'],
#  ['1958-10-04', 'To Know Him, Is To Love Him', 'The Teddy Bears', '56'],
#  ['1958-10-04', 'Hideaway', 'The Four Esquires', '57'],
#  ['1958-10-04',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '58'],
#  ['1958-10-04', 'When I Grow Too Old To Dream', 'Ed Townsend', '59'],
#  ['1958-10-04', 'Call Me', 'Johnny Mathis', '60'],
#  ['1958-10-04', 'The Green Mosquito', 'The Tune Rockers', '61'],
#  ['1958-10-04', "Look Who's Blue", 'Don Gibson', '62'],
#  ['1958-10-04',
#   'Nine More Miles (The "Faster-Faster" Song)',
#   'Georgie Young',
#   '63'],
#  ['1958-10-04', "Nothin' Shakin'", 'Eddie Fontaine', '64'],
#  ['1958-10-04', 'No One But You (In My Heart)', 'The Ames Brothers', '65'],
#  ['1958-10-04', 'Ginger Bread', 'Frankie Avalon', '66'],
#  ['1958-10-04', 'Willie And The Hand Jive', 'The Johnny Otis Show', '67'],
#  ['1958-10-04', 'Ten Commandments Of Love', 'Harvey', '68'],
#  ['1958-10-04', 'Hoopa Hoola', 'Betty Johnson', '69'],
#  ['1958-10-04', 'The Ways Of A Woman In Love', 'Johnny Cash', '70'],
#  ['1958-10-04', 'Give Myself A Party', 'Don Gibson', '71'],
#  ['1958-10-04', 'Wendy, Wendy', 'The Four Coins', '72'],
#  ['1958-10-04', 'The Hula Hoop Song', 'Georgia Gibbs', '73'],
#  ['1958-10-04', 'With Your Love', 'Jack Scott', '74'],
#  ['1958-10-04', 'Forget Me Not', 'Kalin Twins', '75'],
#  ['1958-10-04', 'You Cheated', 'The Slades', '76'],
#  ['1958-10-04', 'Over The Weekend', 'The Playboys', '77'],
#  ['1958-10-04', 'Topsy I', 'Cozy Cole', '78'],
#  ['1958-10-04', 'The Ballad Of Thunder Road', 'Robert Mitchum', '79'],
#  ['1958-10-04', 'Break-Up', 'Jerry Lee Lewis', '80'],
#  ['1958-10-04', 'The Day I Died', 'The Playmates', '81'],
#  ['1958-10-04', 'If Dreams Came True', 'Pat Boone', '82'],
#  ['1958-10-04', 'Bullwhip Rock', 'Cyclones', '83'],
#  ['1958-10-04', "Come On, Let's Go", 'Ritchie Valens', '84'],
#  ['1958-10-04', 'Blue Ribbon Baby', 'Tommy Sands', '85'],
#  ['1958-10-04', 'Leave Me Alone (Let Me Cry)', 'Dicky Doo', '86'],
#  ['1958-10-04', "Well I'm Your Man", 'Johnny Tillotson', '87'],
#  ['1958-10-04', 'All Over Again', 'Johnny Cash', '88'],
#  ['1958-10-04', 'Real Wild Child', 'Ivan', '89'],
#  ['1958-10-04', "A Lover's Question", 'Clyde McPhatter', '90'],
#  ['1958-10-04', 'Over And Over', 'Bobby Day', '91'],
#  ['1958-10-04', 'Need You', 'Donnie Owens', '92'],
#  ['1958-10-04', "It's Raining Outside", 'The Platters', '93'],
#  ['1958-10-04', 'Dance Everyone Dance', 'Betty Madigan', '94'],
#  ['1958-10-04', 'Queen Of The Hop', 'Bobby Darin', '95'],
#  ['1958-10-04', 'Fried Onions', "Lord Rockingham's XI", '96'],
#  ['1958-10-04', 'The Blob', 'The Five Blobs', '97'],
#  ['1958-10-04', 'Just Young', 'Paul Anka', '98'],
#  ['1958-10-04', 'The Hula Hoop Song', 'Teresa Brewer', '99'],
#  ['1958-10-04', 'Just Young', 'Andy Rose', '100'],
#  ['1958-10-11', "It's All In The Game", 'Tommy Edwards', '1'],
#  ['1958-10-11', 'Rock-in Robin', 'Bobby Day', '2'],
#  ['1958-10-11', 'Bird Dog', 'The Everly Brothers', '3'],
#  ['1958-10-11', 'Tears On My Pillow', 'Little Anthony', '4'],
#  ['1958-10-11', "Susie Darlin'", 'Robin Luke', '5'],
#  ['1958-10-11', 'Nel Blu Dipinto Di Blu (Volaré)', 'Domenico Modugno', '6'],
#  ['1958-10-11', 'The End', 'Earl Grant', '7'],
#  ['1958-10-11', 'Little Star', 'The Elegants', '8'],
#  ['1958-10-11', 'Tea For Two Cha Cha', 'The Tommy Dorsey Orchestra', '9'],
#  ['1958-10-11', 'Near You', 'Roger Williams', '10'],
#  ['1958-10-11', 'Chantilly Lace', 'Big Bopper', '11'],
#  ['1958-10-11', 'Summertime Blues', 'Eddie Cochran', '12'],
#  ['1958-10-11', 'Topsy II', 'Cozy Cole', '13'],
#  ['1958-10-11', 'Just A Dream', 'Jimmy Clanton', '14'],
#  ['1958-10-11', 'You Cheated', 'The Shields', '15'],
#  ['1958-10-11', "It's Only Make Believe", 'Conway Twitty', '16'],
#  ['1958-10-11', 'Tom Dooley', 'The Kingston Trio', '17'],
#  ['1958-10-11', 'How The Time Flies', 'Jerry Wallace', '18'],
#  ['1958-10-11', 'Devoted To You', 'The Everly Brothers', '19'],
#  ['1958-10-11', 'Firefly', 'Tony Bennett', '20'],
#  ['1958-10-11', 'Born Too Late', 'Poni-Tails', '21'],
#  ['1958-10-11', 'Promise Me, Love', 'Andy Williams', '22'],
#  ['1958-10-11', 'For My Good Fortune', 'Pat Boone', '23'],
#  ['1958-10-11', 'No One Knows', 'Dion', '24'],
#  ['1958-10-11', 'The Day The Rains Came', 'Jane Morgan', '25'],
#  ['1958-10-11', 'Are You Really Mine', 'Jimmie Rodgers', '26'],
#  ['1958-10-11', 'Mexican Hat Rock', 'The Applejacks', '27'],
#  ['1958-10-11', 'Treasure Of Your Love', 'Eileen Rodgers', '28'],
#  ['1958-10-11', 'Pussy Cat', 'The Ames Brothers', '29'],
#  ['1958-10-11', 'Patricia', 'Perez Prado', '30'],
#  ['1958-10-11', 'My True Love', 'Jack Scott', '31'],
#  ['1958-10-11', 'La-Do-Dada', 'Dale Hawkins', '32'],
#  ['1958-10-11', 'Win Your Love For Me', 'Sam Cooke', '33'],
#  ['1958-10-11', 'Carol', 'Chuck Berry', '34'],
#  ['1958-10-11', 'Down The Aisle Of Love', 'The Quin-Tones', '35'],
#  ['1958-10-11', 'Itchy Twitchy Feeling', 'Bobby Hendricks', '36'],
#  ['1958-10-11', 'Somebody Touched Me', 'Buddy Knox', '37'],
#  ['1958-10-11', "This Little Girl's Gone Rockin'", 'Ruth Brown', '38'],
#  ['1958-10-11', 'The Secret', 'Gordon MacRae', '39'],
#  ['1958-10-11', 'To Know Him, Is To Love Him', 'The Teddy Bears', '40'],
#  ['1958-10-11', 'Ten Commandments Of Love', 'Harvey', '41'],
#  ['1958-10-11', 'Western Movies', 'The Olympics', '42'],
#  ['1958-10-11', 'Stupid Cupid', 'Connie Francis', '43'],
#  ['1958-10-11', "Gee, But It's Lonely", 'Pat Boone', '44'],
#  ['1958-10-11', 'Summertime, Summertime', 'The Jamies', '45'],
#  ['1958-10-11', 'Call Me', 'Johnny Mathis', '46'],
#  ['1958-10-11', 'The Hula Hoop Song', 'Georgia Gibbs', '47'],
#  ['1958-10-11', "Fibbin'", 'Patti Page', '48'],
#  ['1958-10-11', 'Put A Ring On My Finger', 'Les Paul', '49'],
#  ['1958-10-11', 'Baby Face', 'Little Richard', '50'],
#  ['1958-10-11', 'I Wish', 'The Platters', '51'],
#  ['1958-10-11', 'With Your Love', 'Jack Scott', '52'],
#  ['1958-10-11', 'No One But You (In My Heart)', 'The Ames Brothers', '53'],
#  ['1958-10-11', 'The Green Mosquito', 'The Tune Rockers', '54'],
#  ['1958-10-11', 'Topsy I', 'Cozy Cole', '55'],
#  ['1958-10-11', 'Fever', 'Peggy Lee', '56'],
#  ['1958-10-11', 'Everybody Loves A Lover', 'Doris Day', '57'],
#  ['1958-10-11',
#   'Nine More Miles (The "Faster-Faster" Song)',
#   'Georgie Young',
#   '58'],
#  ['1958-10-11', 'When I Grow Too Old To Dream', 'Ed Townsend', '59'],
#  ['1958-10-11', 'You Cheated', 'The Slades', '60'],
#  ['1958-10-11', 'There Goes My Heart', 'Joni James', '61'],
#  ['1958-10-11', 'Forget Me Not', 'Kalin Twins', '62'],
#  ['1958-10-11', 'Leave Me Alone (Let Me Cry)', 'Dicky Doo', '63'],
#  ['1958-10-11', 'Ramrod', 'Duane Eddy', '64'],
#  ['1958-10-11',
#   'She Was Only Seventeen (He Was One Year More)',
#   'Marty Robbins',
#   '65'],
#  ['1958-10-11', 'Volare (Nel Blu Dipinto Di Blu)', 'Dean Martin', '66'],
#  ['1958-10-11', "Look Who's Blue", 'Don Gibson', '67'],
#  ['1958-10-11', 'Real Wild Child', 'Ivan', '68'],
#  ['1958-10-11', 'Give Myself A Party', 'Don Gibson', '69'],
#  ['1958-10-11', 'I Got A Feeling', 'Ricky Nelson', '70'],
#  ['1958-10-11', 'Poor Little Fool', 'Ricky Nelson', '71'],
#  ['1958-10-11', 'Lazy Summer Night', 'The Four Preps', '72'],
#  ['1958-10-11', 'Hoopa Hoola', 'Betty Johnson', '73'],
#  ['1958-10-11', 'The Hula Hoop Song', 'Teresa Brewer', '74'],
#  ['1958-10-11', 'The Ways Of A Woman In Love', 'Johnny Cash', '75'],
#  ['1958-10-11', 'Need You', 'Donnie Owens', '76'],
#  ['1958-10-11', 'The Ballad Of Thunder Road', 'Robert Mitchum', '77'],
#  ['1958-10-11', 'Queen Of The Hop', 'Bobby Darin', '78'],
#  ['1958-10-11', 'Hideaway', 'The Four Esquires', '79'],
#  ['1958-10-11', "Come On, Let's Go", 'Ritchie Valens', '80'],
#  ['1958-10-11', 'Just Young', 'Paul Anka', '81'],
#  ['1958-10-11', 'What Little Girl', 'Frankie Avalon', '82'],
#  ['1958-10-11', 'The Blob', 'The Five Blobs', '83'],
#  ['1958-10-11', 'Blue Ribbon Baby', 'Tommy Sands', '84'],
#  ['1958-10-11', 'Guaglione', 'Perez Prado', '85'],
#  ['1958-10-11', "Fallin'", 'Connie Francis', '86'],
#  ['1958-10-11', "Love Makes The World Go 'round", 'Perry Como', '87'],
#  ['1958-10-11', 'All Over Again', 'Johnny Cash', '88'],
#  ['1958-10-11', 'Go Chase A Moonbeam', 'Jerry Vale', '89'],
#  ['1958-10-11', 'Dance Everyone Dance', 'Betty Madigan', '90'],
#  ['1958-10-11', 'Over And Over', 'Bobby Day', '91'],
#  ['1958-10-11', 'Just Young', 'Andy Rose', '92'],
#  ['1958-10-11', 'Break-Up', 'Jerry Lee Lewis', '93'],
#  ['1958-10-11', 'Bluebell', 'Mitch Miller', '94'],
#  ['1958-10-11', 'Ginger Bread', 'Frankie Avalon', '95'],
#  ['1958-10-11', 'Geraldine', 'Jack Scott', '96'],
#  ['1958-10-11', "Non Dimenticar (Don't Forget)", 'Nat King Cole', '97'],
#  ['1958-10-11', 'La Paloma', 'Billy Vaughn', '98'],
#  ['1958-10-11', "Well I'm Your Man", 'Johnny Tillotson', '99'],
#  ['1958-10-11', "I'll Wait For You", 'Frankie Avalon', '100'],
#  ...]

# %% [markdown]
# Let's start by creating a dictionary of dictionaries which maps years to songs and their ranking. We'll say that a song ranked at #1 gets a score of 100, #2 gets a 99 and so on. This will help us visualize the most popular songs of each year.
