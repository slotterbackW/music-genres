# %% [markdown]
# # The Rise and Fall of Different Music Genres
# #### By: Will Slotterback, Erik Ryde, and Todd Roberts
# In deciding what to work on for this project we first thought about interesting datasets we could use. One dataset which came to mind was the Billboard Hot 100. Billboard has been tracking the top 100 most popular songs in the U.S. every week since the late 50's so they've amassed a massive dataset of musical tastes in the U.S. This data already provides a really interesting picture of changing preferences in the U.S. but on its own its hard to tease out broad musical trends. To do this we need a way to categorize the different songs. The obvious choice is to do it by genre, but Billboard doesn't have data on the genre of song, just its popularity. To get this data we instead need to turn to the Spotify API where we can correlate the genre of an artist with songs that artist has produced. Though this isn't a perfect method -- artists do often cross genres and produce new types of songs -- it is accurate enough to produce valuable results. Using this data we can then plot the rise and fall of different musical genres in American history and understand questions like: What is the most popular genre of all time? Spoiler: It's not Ska.

# %% [markdown]
# ## Gathering our Data
# The first step in collecting our data is scraping the Billboard Hot 100 to gather the list of most popular songs. Billboard used to provide an API for this, but has since deprecated it, so we chose instead to use the [billboard-top-100](https://github.com/darthbatman/billboard-top-100) library. Billboard chart urls follow the predictable pattern of `billboard.com/charts/*chart_name*/*date*` so this library takes a chart name, and a date, and scrapes the HTML for that chart in order to produce a list of the songs in that chart. We wrote a utility function around this  that allowed us to fetch all of the charts starting from a specific date and write them to a file. This function (and a few other utility functions) can be seen in our [source](https://github.com/slotterbackW/music-genres/blob/master/api/billboard.js).
#
# Running this function with the date: *August 9th, 1958* or the earliest date Billboard charts are available produced a very large dataset, as you can see below.

# %%
with open('./data/songs.txt') as songs_file:
    list_of_songs = songs_file.readlines()
    print(len(list_of_songs))
# Out:
# 314501

# %% [markdown]
# Wow that's a lot of music! For reference the average song is about three minutes long, so if you listened to all the songs in our dataset one after another it would take you 655 days, or over a year and a half.
#
# Our dataset is not complete, however. We want to be able to look at broad trends in the data we have, but right now the individual songs are too granular. We need to categorize these songs by their genre. As mentioned above, to do this we'll use the Spotify API to fetch the genre for a song's artist and then correlate that with the song. Unfortunately our data isn't the cleanest right now, so before we fetch genre's we need to clean it up a little bit.
#
# The first problem with our data is that the artist names we have don't always represent one artist. For example the 1960's classic *Stuck On You* lists "Elvis Presley With The Jordanaires" as the artist. As is obvious to human reader this is actually two artists, *Elvis Presley* and *The Jordanaires*, but the computer doesn't know that. Our method for solving this is to split artist names on a series of delimeters, and say that a song is officially by the first artist in that list.
#
# The other issue with our data is that there are lots of duplicates. Because especially successful songs will last on the Hot 100 chart for many weeks the same song could show up multiple times. We don't want to waste resources fetching the same artist name multiple times, so making sure the names of artists we have are unique is an important concern of ours.
#
# Ok let's get into some code. The first thing we'll do is grab the raw list of artists.

# %%
raw_artists = []
with open('./data/songs.txt') as songs_file:
    # Our data is separated by bar characters
    raw_artists = [line.split('|')[2] for line in songs_file]

# %% [markdown]
# Then we'll polish the raw artist data so that it only contains the primary artist we care about. To do this we'll use a method we wrote which splits a string based on a list of delimiters. [[source](https://github.com/slotterbackW/music-genres/blob/master/analysis_helpers.py#L20)]

# %%
DELIMITERS = ['and', 'with', 'featuring', 'ft.', 'ft', '&', 'X']
from analysis_helpers import multi_split

artist_names = []
for raw_artist in raw_artists[1:]:
    # We'll consider the first artist who's name appears in the artist field the "primary" artist.
    artist_names.append(multi_split(raw_artist, DELIMITERS)[0])

artist_names
# Out:
# ['Ricky Nelson',
#  'Domenico Modugno',
#  'Perez Prado',
#  'Bobby Darin',
#  'Kalin Twins',
#  'Jack Scott',
#  'Elvis Presley',
#  'Duane Eddy',
#  'Jimmy Clanton',
#  'The Johnny Otis Show',
#  'The Coasters',
#  'Pat Boone',
#  'Peggy Lee',
#  'The Elegants',
#  'Frankie Avalon',
#  'Doris Day',
#  'The Danleers',
#  'Poni-Tails',
#  'Patti Page',
#  'Jody Reynolds',
#  'The Olympics',
#  'Johnny Cash',
#  'Jerry Butler',
#  'The Rinky-Dinks',
#  'Buddy Knox',
#  'Jimmie Rodgers',
#  'Bobby Freeman',
#  'Johnny Mathis',
#  'The Four Lads',
#  'Perry Como',
#  'Chuck Willis',
#  'The Crickets',
#  'Bobby Day',
#  'The Everly Brothers',
#  'Connie Francis',
#  'Don Gibson',
#  'Dean Martin',
#  'Big Bopper',
#  'Dean Martin',
#  'Buddy Holly',
#  'Jimmie Rodgers',
#  'Robin Luke',
#  'The Everly Brothers',
#  'Bobby Freeman',
#  'Jim Reeves',
#  'Nat King Cole',
#  'Sheb Wooley',
#  'The Slades',
#  'Clyde McPhatter',
#  'Bobby Hendricks',
#  'Faron Young',
#  'Eddie Cochran',
#  'Bobby Day',
#  'Elvis Presley',
#  'Tony',
#  'Jack Scott',
#  'Pat Boone',
#  'The Drifters',
#  'Gerry Granahan',
#  'Dion',
#  'Sam Cooke',
#  'Bobby Hamilton',
#  'Dean Martin',
#  'Eydie Gorme',
#  'Toni Arden',
#  'Jerry Lee Lewis',
#  'Bill Haley',
#  'The Platters',
#  'Jimmy Bowen',
#  'Lee Andrews',
#  'Paul Anka',
#  'Fats Domino',
#  'Little Anthony',
#  'The Diamonds',
#  "The Three G's",
#  'Marty Robbins',
#  'Jan',
#  'Royal Teens',
#  'Marty Robbins',
#  'The Diamonds',
#  'Nat King Cole',
#  'Tony Bennett',
#  'Kitty Wells',
#  'Little Willie John',
#  'Jimmie Rodgers',
#  'The Drifters',
#  'Johnny Cash',
#  'Boots Brown',
#  'Joe South',
#  'The Playmates',
#  'The Everly Brothers',
#  'Billy Vaughn',
#  'Robert',
#  'The Champs',
#  'The Champs',
#  'Jimmy Reed',
#  'Tennessee Ernie Ford',
#  'Eydie Gorme',
#  'Nat King Cole',
#  'The Kirby Stone Four',
#  'Domenico Modugno',
#  'The Elegants',
#  'Jack Scott',
#  'Ricky Nelson',
#  'Perez Prado',
#  'Jimmy Clanton',
#  'Kalin Twins',
#  'Duane Eddy',
#  'Peggy Lee',
#  'Bobby Darin',
#  'Frankie Avalon',
#  'The Johnny Otis Show',
#  'Elvis Presley',
#  'Doris Day',
#  'Pat Boone',
#  'Poni-Tails',
#  'The Everly Brothers',
#  'The Coasters',
#  'The Olympics',
#  'Dean Martin',
#  'The Danleers',
#  'Buddy Knox',
#  'Patti Page',
#  'Jimmie Rodgers',
#  'The Everly Brothers',
#  'The Rinky-Dinks',
#  'Robin Luke',
#  'The Crickets',
#  'Big Bopper',
#  'Johnny Mathis',
#  'Connie Francis',
#  'Jody Reynolds',
#  'Jerry Butler',
#  'Perry Como',
#  'Don Gibson',
#  'The Four Lads',
#  'Buddy Holly',
#  'Bobby Day',
#  'Johnny Cash',
#  'Dean Martin',
#  'Bobby Hendricks',
#  'Chuck Willis',
#  'Bobby Freeman',
#  'Eddie Cochran',
#  'Pat Boone',
#  'Bobby Freeman',
#  'Billy Vaughn',
#  'Nat King Cole',
#  'The Slades',
#  'Tony',
#  'Marty Robbins',
#  'Jerry Wallace',
#  'Clyde McPhatter',
#  'Sam Cooke',
#  'Elvis Presley',
#  'The Diamonds',
#  'Bobby Day',
#  'Jimmy Bowen',
#  'The Kirby Stone Four',
#  'Bobby Helms',
#  'Oscar McLollie',
#  'Bobby Hamilton',
#  'Little Anthony',
#  'Jimmie Rodgers',
#  'Jim Reeves',
#  'Little Willie John',
#  'Roger Williams',
#  'Faron Young',
#  'Paul Anka',
#  'Gerry Granahan',
#  'Toni Arden',
#  'The Four Preps',
#  'The Diamonds',
#  'The Jamies',
#  'The Upbeats',
#  'DeJohn Sisters',
#  'Jimmie Rodgers',
#  'The Champs',
#  'Jim Backus',
#  "The Three G's",
#  'Sheb Wooley',
#  'Jan',
#  'Boots Brown',
#  'Bill Doggett',
#  'The Platters',
#  'Royal Teens',
#  'Eydie Gorme',
#  'Betty Madigan',
#  'Janice Harper',
#  'Chuck Willis',
#  'The Quin-Tones',
#  'Dean Martin',
#  'Jimmy Reed',
#  'Jody Reynolds',
#  'Les Paul',
#  'Tommy Edwards',
#  'The Gaylords',
#  'Tommy Mara',
#  'The DeCastro Sisters',
#  'Count Basie',
#  'The Elegants',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'Jimmy Clanton',
#  'Jack Scott',
#  'Ricky Nelson',
#  'Perez Prado',
#  'Poni-Tails',
#  'Peggy Lee',
#  'Kalin Twins',
#  'Duane Eddy',
#  'The Johnny Otis Show',
#  'The Olympics',
#  'Doris Day',
#  'The Everly Brothers',
#  'Bobby Darin',
#  'Frankie Avalon',
#  'Pat Boone',
#  'Dean Martin',
#  'Jimmie Rodgers',
#  'Elvis Presley',
#  'Connie Francis',
#  'Robin Luke',
#  'Eddie Cochran',
#  'Bobby Day',
#  'Little Anthony',
#  'The Danleers',
#  'Buddy Knox',
#  'The Rinky-Dinks',
#  'Big Bopper',
#  'The Crickets',
#  'Buddy Holly',
#  'Patti Page',
#  'Johnny Mathis',
#  'The Coasters',
#  'Perry Como',
#  'Bobby Freeman',
#  'Marty Robbins',
#  'Billy Vaughn',
#  'Tommy Edwards',
#  'Bobby Day',
#  'Bobby Hendricks',
#  'Don Gibson',
#  'The Four Preps',
#  'Sam Cooke',
#  'Jerry Butler',
#  'Bobby Freeman',
#  'The Four Lads',
#  'Jerry Wallace',
#  'Chuck Willis',
#  'Jimmie Rodgers',
#  'Jimmy Bowen',
#  'The Diamonds',
#  'Elvis Presley',
#  'Johnny Cash',
#  'Nat King Cole',
#  'Chuck Berry',
#  'Tony',
#  'Les Paul',
#  'Dean Martin',
#  'The Jamies',
#  'Johnny Cash',
#  'Toni Arden',
#  'Pat Boone',
#  'George Hamilton IV',
#  'Eydie Gorme',
#  'Boots Brown',
#  'Betty Madigan',
#  'The Champs',
#  'Faron Young',
#  'Jody Reynolds',
#  'Ray Price',
#  'DeJohn Sisters',
#  'The Rivieras',
#  'Jim Reeves',
#  'Oscar McLollie',
#  'The Diamonds',
#  'The Tune Rockers',
#  'Paul Anka',
#  'Gogi Grant',
#  'Warren Storm',
#  'Cozy Cole',
#  'Jack Scott',
#  'Bobby Helms',
#  'The Drifters',
#  'Janice Harper',
#  'The Quin-Tones',
#  'Roger Williams',
#  'Chuck Willis',
#  'Jody Reynolds',
#  'Duane Eddy',
#  'The Upbeats',
#  'Sheb Wooley',
#  'The Shields',
#  'Dion',
#  'Dean Martin',
#  'David Seville',
#  'Little Willie John',
#  'The Slades',
#  'Eileen Rodgers',
#  'Domenico Modugno',
#  'The Elegants',
#  'The Everly Brothers',
#  'Jimmy Clanton',
#  'Ricky Nelson',
#  'Perez Prado',
#  'Jack Scott',
#  'Kalin Twins',
#  'Frankie Avalon',
#  'Jimmie Rodgers',
#  'Poni-Tails',
#  'Peggy Lee',
#  'Duane Eddy',
#  'The Olympics',
#  'Dean Martin',
#  'The Johnny Otis Show',
#  'Bobby Day',
#  'Bobby Darin',
#  'Doris Day',
#  'Eddie Cochran',
#  'The Everly Brothers',
#  'Tommy Edwards',
#  'Pat Boone',
#  'Little Anthony',
#  'Connie Francis',
#  'Elvis Presley',
#  'Patti Page',
#  'Buddy Knox',
#  'Robin Luke',
#  'Perry Como',
#  'Billy Vaughn',
#  'Bobby Hendricks',
#  'The Rinky-Dinks',
#  'Johnny Mathis',
#  'The Danleers',
#  'Buddy Holly',
#  'The Coasters',
#  'The Four Preps',
#  'Marty Robbins',
#  'Big Bopper',
#  'Sam Cooke',
#  'The Crickets',
#  'The Quin-Tones',
#  'Bobby Freeman',
#  'Jimmie Rodgers',
#  'Nat King Cole',
#  'Bobby Day',
#  'Jerry Butler',
#  'Les Paul',
#  'Jerry Wallace',
#  'Chuck Willis',
#  'Don Gibson',
#  'Duane Eddy',
#  'Johnny Cash',
#  'Roger Williams',
#  'Chuck Berry',
#  'The Jamies',
#  'Johnny Cash',
#  'Jimmy Bowen',
#  'The Tune Rockers',
#  'The Diamonds',
#  'Betty Madigan',
#  'Boots Brown',
#  'Eydie Gorme',
#  'Chuck Willis',
#  'Jody Reynolds',
#  'The Champs',
#  'George Hamilton IV',
#  'The Shields',
#  'Elvis Presley',
#  'The Four Lads',
#  'Ray Price',
#  'The Rivieras',
#  'The Tommy Dorsey Orchestra',
#  'Bobby Freeman',
#  'Tony',
#  'Tommy Mara',
#  'David Seville',
#  'Andy Williams',
#  'The McGuire Sisters',
#  'Cozy Cole',
#  'Janice Harper',
#  'Gogi Grant',
#  'Dion',
#  'Dale Wright',
#  'Eileen Rodgers',
#  'Pat Boone',
#  'Dean Martin',
#  'Jack Scott',
#  'Warren Storm',
#  'Oscar McLollie',
#  'Jody Reynolds',
#  'The Playboys',
#  'Tommy Sands',
#  'The Chargers',
#  'The Kingsmen',
#  'Johnnie Ray',
#  'Dale Hawkins',
#  'Teresa Brewer',
#  'Jill Corey',
#  'Domenico Modugno',
#  'The Elegants',
#  'The Everly Brothers',
#  'Jimmy Clanton',
#  'Perez Prado',
#  'Ricky Nelson',
#  'Jack Scott',
#  'Bobby Day',
#  'Frankie Avalon',
#  'The Olympics',
#  'Tommy Edwards',
#  'Peggy Lee',
#  'Little Anthony',
#  'Poni-Tails',
#  'Dean Martin',
#  'Jimmie Rodgers',
#  'The Johnny Otis Show',
#  'Doris Day',
#  'Duane Eddy',
#  'Connie Francis',
#  'Kalin Twins',
#  'The Everly Brothers',
#  'The Quin-Tones',
#  'Pat Boone',
#  'Roger Williams',
#  'Billy Vaughn',
#  'The Four Preps',
#  'Robin Luke',
#  'Perry Como',
#  'Johnny Cash',
#  'Eddie Cochran',
#  'The Danleers',
#  'Buddy Knox',
#  'Big Bopper',
#  'Sam Cooke',
#  'Bobby Hendricks',
#  'Johnny Mathis',
#  'The Rinky-Dinks',
#  'Marty Robbins',
#  'Les Paul',
#  'Nat King Cole',
#  'Betty Madigan',
#  'Dion',
#  'The Tommy Dorsey Orchestra',
#  'Bobby Darin',
#  'The Shields',
#  'Buddy Holly',
#  'The Jamies',
#  'Don Gibson',
#  'Bobby Freeman',
#  'Duane Eddy',
#  'Chuck Berry',
#  'Bobby Day',
#  'Jimmie Rodgers',
#  'Patti Page',
#  'Elvis Presley',
#  'Johnny Cash',
#  'Jerry Wallace',
#  'The Tune Rockers',
#  'The Crickets',
#  'Chuck Willis',
#  'Boots Brown',
#  'Eydie Gorme',
#  'The Four Lads',
#  'Jimmy Bowen',
#  'Cozy Cole',
#  'The Champs',
#  'Andy Williams',
#  'Eileen Rodgers',
#  'Dale Hawkins',
#  'Ray Price',
#  'George Hamilton IV',
#  'Chuck Willis',
#  'The Coasters',
#  'George Hamilton IV',
#  'Tommy Mara',
#  'Dale Wright',
#  'Jim Reeves',
#  'Faron Young',
#  'The Diamonds',
#  'Johnnie Ray',
#  'The Rivieras',
#  'Gogi Grant',
#  'The Kingsmen',
#  'Jerry Lee Lewis',
#  'Pat Boone',
#  'The Playboys',
#  'Tony Bennett',
#  'Tommy Sands',
#  'Oscar McLollie',
#  'Little Willie John',
#  'Ray Price',
#  'Carl Smith',
#  'Ivory Joe Hunter',
#  'Robert Mitchum',
#  'Doug Franklin',
#  'Jody Reynolds',
#  'Jack Scott',
#  'Dean Martin',
#  'Tony',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'The Elegants',
#  'Tommy Edwards',
#  'Jimmy Clanton',
#  'Bobby Day',
#  'Poni-Tails',
#  'The Olympics',
#  'Little Anthony',
#  'Robin Luke',
#  'Perez Prado',
#  'Jack Scott',
#  'Ricky Nelson',
#  'The Everly Brothers',
#  'Jimmie Rodgers',
#  'Eddie Cochran',
#  'Frankie Avalon',
#  'Connie Francis',
#  'Doris Day',
#  'The Quin-Tones',
#  'Dean Martin',
#  'Peggy Lee',
#  'The Four Preps',
#  'Johnny Cash',
#  'Jerry Wallace',
#  'Roger Williams',
#  'Marty Robbins',
#  'Duane Eddy',
#  'Chuck Berry',
#  'The Jamies',
#  'The Tommy Dorsey Orchestra',
#  'The Johnny Otis Show',
#  'The Shields',
#  'Betty Madigan',
#  'Big Bopper',
#  'Buddy Knox',
#  'Dion',
#  'Les Paul',
#  'Sam Cooke',
#  'Kalin Twins',
#  'Duane Eddy',
#  'Billy Vaughn',
#  'The Danleers',
#  'Tony Bennett',
#  'Jimmie Rodgers',
#  'Perry Como',
#  'Bobby Hendricks',
#  'The Tune Rockers',
#  'Andy Williams',
#  'Cozy Cole',
#  'Nat King Cole',
#  'Buddy Holly',
#  'Johnny Mathis',
#  'Eileen Rodgers',
#  'Pat Boone',
#  'Chuck Willis',
#  'Bobby Freeman',
#  'Bobby Darin',
#  'Harvey',
#  'Bobby Day',
#  'Joni James',
#  'The Playboys',
#  'Dale Hawkins',
#  'Don Gibson',
#  'Conway Twitty',
#  'Boots Brown',
#  'Jimmy Bowen',
#  'The Crickets',
#  'The Rinky-Dinks',
#  'Gordon MacRae',
#  'Patti Page',
#  'Little Richard',
#  'Jerry Lee Lewis',
#  'Tommy Sands',
#  'Doug Franklin',
#  'The Applejacks',
#  'The Rivieras',
#  'Elvis Presley',
#  'Tommy Mara',
#  'The Champs',
#  'The Slades',
#  'Jody Reynolds',
#  'Faron Young',
#  'The Redjacks',
#  'Jan',
#  'The Kingsmen',
#  'Earl Grant',
#  'Robert Mitchum',
#  'Jim Reeves',
#  'The Coasters',
#  'Johnny Cash',
#  'Cozy Cole',
#  'Dale Wright',
#  'Chuck Willis',
#  'The Diamonds',
#  'Johnnie Ray',
#  'Eydie Gorme',
#  'The Platters',
#  'George Hamilton IV',
#  'The Four Lads',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'Tommy Edwards',
#  'The Elegants',
#  'Bobby Day',
#  'Jimmy Clanton',
#  'Little Anthony',
#  'Robin Luke',
#  'Poni-Tails',
#  'The Everly Brothers',
#  'Eddie Cochran',
#  'Roger Williams',
#  'Jack Scott',
#  'Jerry Wallace',
#  'Perez Prado',
#  'The Olympics',
#  'Connie Francis',
#  'Doris Day',
#  'Ricky Nelson',
#  'The Tommy Dorsey Orchestra',
#  'The Four Preps',
#  'The Quin-Tones',
#  'Chuck Berry',
#  'Jimmie Rodgers',
#  'Johnny Cash',
#  'The Jamies',
#  'Frankie Avalon',
#  'Dion',
#  'Dean Martin',
#  'Tony Bennett',
#  'The Shields',
#  'Les Paul',
#  'Peggy Lee',
#  'Big Bopper',
#  'Andy Williams',
#  'Buddy Knox',
#  'Duane Eddy',
#  'Marty Robbins',
#  'Sam Cooke',
#  'Betty Madigan',
#  'Conway Twitty',
#  'The Johnny Otis Show',
#  'Cozy Cole',
#  'The Tune Rockers',
#  'Eileen Rodgers',
#  'Harvey',
#  'Gordon MacRae',
#  'Bobby Day',
#  'Earl Grant',
#  'Tommy Sands',
#  'Joni James',
#  'Duane Eddy',
#  'Nat King Cole',
#  'Pat Boone',
#  'Jimmie Rodgers',
#  'Patti Page',
#  'Bobby Hendricks',
#  'The Danleers',
#  'The Champs',
#  'Jane Morgan',
#  'Billy Vaughn',
#  'Dale Hawkins',
#  'Little Richard',
#  'Kalin Twins',
#  'The Applejacks',
#  'Johnny Mathis',
#  'The Playboys',
#  'Perry Como',
#  'Pat Boone',
#  'Jerry Lee Lewis',
#  'Cozy Cole',
#  'Bobby Darin',
#  'The Rinky-Dinks',
#  'Ruth Brown',
#  'Bobby Freeman',
#  'Georgie Young',
#  'Ritchie Valens',
#  'Dale Wright',
#  'Boots Brown',
#  'Doug Franklin',
#  'The Four Esquires',
#  'Pat Boone',
#  'George Hamilton IV',
#  'The Four Coins',
#  'Ivan',
#  'The Slades',
#  'Don Gibson',
#  'The Teddy Bears',
#  'The Redjacks',
#  'Jody Reynolds',
#  'The Platters',
#  'Fats Domino',
#  'Eddie Fontaine',
#  'Elvis Presley',
#  'Jimmy Bowen',
#  'Jackie Wilson',
#  'Sonny James',
#  'Steve Lawrence',
#  'George Hamilton IV',
#  'The Swallows',
#  'Tommy Edwards',
#  'Domenico Modugno',
#  'The Everly Brothers',
#  'Bobby Day',
#  'The Elegants',
#  'Little Anthony',
#  'Robin Luke',
#  'Eddie Cochran',
#  'Jimmy Clanton',
#  'Roger Williams',
#  'Poni-Tails',
#  'The Everly Brothers',
#  'Jerry Wallace',
#  'The Tommy Dorsey Orchestra',
#  'Earl Grant',
#  'Big Bopper',
#  'Connie Francis',
#  'Chuck Berry',
#  'Jack Scott',
#  'Perez Prado',
#  'The Shields',
#  'Doris Day',
#  'Tony Bennett',
#  'The Four Preps',
#  'Andy Williams',
#  'The Olympics',
#  'The Quin-Tones',
#  'The Jamies',
#  'Jimmie Rodgers',
#  'Dion',
#  'Dean Martin',
#  'Eileen Rodgers',
#  'Conway Twitty',
#  'Les Paul',
#  'Buddy Knox',
#  'Ricky Nelson',
#  'Sam Cooke',
#  'Duane Eddy',
#  'Cozy Cole',
#  'Peggy Lee',
#  'Marty Robbins',
#  'Bobby Hendricks',
#  'Gordon MacRae',
#  'Billy Vaughn',
#  'Dale Hawkins',
#  'Pat Boone',
#  'The Johnny Otis Show',
#  'Patti Page',
#  'Harvey',
#  'The Tune Rockers',
#  'The Applejacks',
#  'Jerry Lee Lewis',
#  'Jane Morgan',
#  'The Four Esquires',
#  'Pat Boone',
#  'Little Richard',
#  'Ruth Brown',
#  'Bobby Day',
#  'The Ames Brothers',
#  'The Ames Brothers',
#  'Betty Madigan',
#  'Joni James',
#  'The Platters',
#  'Frankie Avalon',
#  'Johnny Cash',
#  'Don Gibson',
#  'The Slades',
#  'Tommy Sands',
#  'Georgie Young',
#  'Boots Brown',
#  'Nat King Cole',
#  'Ed Townsend',
#  'Eddie Fontaine',
#  'Johnny Mathis',
#  'The Four Coins',
#  'Ritchie Valens',
#  'Dale Wright',
#  'Bobby Freeman',
#  'Don Gibson',
#  'The Teddy Bears',
#  'Pat Boone',
#  'Johnny Mathis',
#  'The Kingston Trio',
#  'The Playboys',
#  'Ivan',
#  'Kalin Twins',
#  'The Playmates',
#  'Cozy Cole',
#  'Jack Scott',
#  'Perry Como',
#  'Cyclones',
#  'Lee Allen',
#  'Jackie Wilson',
#  'Sonny James',
#  'George Hamilton IV',
#  'Dicky Doo',
#  'Steve Lawrence',
#  'The Rinky-Dinks',
#  'Robert Mitchum',
#  'Kalin Twins',
#  'Tommy Edwards',
#  'The Everly Brothers',
#  'Bobby Day',
#  'Domenico Modugno',
#  'The Elegants',
#  'Little Anthony',
#  'Robin Luke',
#  'The Tommy Dorsey Orchestra',
#  'Eddie Cochran',
#  'Roger Williams',
#  'Jerry Wallace',
#  'Jimmy Clanton',
#  'Earl Grant',
#  'Poni-Tails',
#  'Big Bopper',
#  'The Shields',
#  'Andy Williams',
#  'Perez Prado',
#  'Chuck Berry',
#  'Conway Twitty',
#  'The Everly Brothers',
#  'Cozy Cole',
#  'Tony Bennett',
#  'Jack Scott',
#  'Bobby Hendricks',
#  'Eileen Rodgers',
#  'Dion',
#  'Connie Francis',
#  'Buddy Knox',
#  'Jimmie Rodgers',
#  'The Quin-Tones',
#  'The Olympics',
#  'The Four Preps',
#  'The Ames Brothers',
#  'Pat Boone',
#  'The Jamies',
#  'The Kingston Trio',
#  'Peggy Lee',
#  'Gordon MacRae',
#  'The Applejacks',
#  'Sam Cooke',
#  'The Platters',
#  'Dean Martin',
#  'Dale Hawkins',
#  'Doris Day',
#  'Patti Page',
#  'Ricky Nelson',
#  'Jane Morgan',
#  'Duane Eddy',
#  'Ruth Brown',
#  'Joni James',
#  'Les Paul',
#  'Billy Vaughn',
#  'Pat Boone',
#  'Little Richard',
#  'The Teddy Bears',
#  'The Four Esquires',
#  'Marty Robbins',
#  'Ed Townsend',
#  'Johnny Mathis',
#  'The Tune Rockers',
#  'Don Gibson',
#  'Georgie Young',
#  'Eddie Fontaine',
#  'The Ames Brothers',
#  'Frankie Avalon',
#  'The Johnny Otis Show',
#  'Harvey',
#  'Betty Johnson',
#  'Johnny Cash',
#  'Don Gibson',
#  'The Four Coins',
#  'Georgia Gibbs',
#  'Jack Scott',
#  'Kalin Twins',
#  'The Slades',
#  'The Playboys',
#  'Cozy Cole',
#  'Robert Mitchum',
#  'Jerry Lee Lewis',
#  'The Playmates',
#  'Pat Boone',
#  'Cyclones',
#  'Ritchie Valens',
#  'Tommy Sands',
#  'Dicky Doo',
#  'Johnny Tillotson',
#  'Johnny Cash',
#  'Ivan',
#  'Clyde McPhatter',
#  'Bobby Day',
#  'Donnie Owens',
#  'The Platters',
#  'Betty Madigan',
#  'Bobby Darin',
#  "Lord Rockingham's XI",
#  'The Five Blobs',
#  'Paul Anka',
#  'Teresa Brewer',
#  'Andy Rose',
#  'Tommy Edwards',
#  'Bobby Day',
#  'The Everly Brothers',
#  'Little Anthony',
#  'Robin Luke',
#  'Domenico Modugno',
#  'Earl Grant',
#  'The Elegants',
#  'The Tommy Dorsey Orchestra',
#  'Roger Williams',
#  'Big Bopper',
#  'Eddie Cochran',
#  'Cozy Cole',
#  'Jimmy Clanton',
#  'The Shields',
#  'Conway Twitty',
#  'The Kingston Trio',
#  'Jerry Wallace',
#  'The Everly Brothers',
#  'Tony Bennett',
#  'Poni-Tails',
#  'Andy Williams',
#  'Pat Boone',
#  'Dion',
#  'Jane Morgan',
#  'Jimmie Rodgers',
#  'The Applejacks',
#  'Eileen Rodgers',
#  'The Ames Brothers',
#  'Perez Prado',
#  'Jack Scott',
#  'Dale Hawkins',
#  'Sam Cooke',
#  'Chuck Berry',
#  'The Quin-Tones',
#  'Bobby Hendricks',
#  'Buddy Knox',
#  'Ruth Brown',
#  'Gordon MacRae',
#  'The Teddy Bears',
#  'Harvey',
#  'The Olympics',
#  'Connie Francis',
#  'Pat Boone',
#  'The Jamies',
#  'Johnny Mathis',
#  'Georgia Gibbs',
#  'Patti Page',
#  'Les Paul',
#  'Little Richard',
#  'The Platters',
#  'Jack Scott',
#  'The Ames Brothers',
#  'The Tune Rockers',
#  'Cozy Cole',
#  'Peggy Lee',
#  'Doris Day',
#  'Georgie Young',
#  'Ed Townsend',
#  'The Slades',
#  'Joni James',
#  'Kalin Twins',
#  'Dicky Doo',
#  'Duane Eddy',
#  'Marty Robbins',
#  'Dean Martin',
#  'Don Gibson',
#  'Ivan',
#  'Don Gibson',
#  'Ricky Nelson',
#  'Ricky Nelson',
#  'The Four Preps',
#  'Betty Johnson',
#  'Teresa Brewer',
#  'Johnny Cash',
#  'Donnie Owens',
#  'Robert Mitchum',
#  'Bobby Darin',
#  'The Four Esquires',
#  'Ritchie Valens',
#  'Paul Anka',
#  'Frankie Avalon',
#  'The Five Blobs',
#  'Tommy Sands',
#  'Perez Prado',
#  'Connie Francis',
#  'Perry Como',
#  'Johnny Cash',
#  'Jerry Vale',
#  'Betty Madigan',
#  'Bobby Day',
#  'Andy Rose',
#  'Jerry Lee Lewis',
#  'Mitch Miller',
#  'Frankie Avalon',
#  'Jack Scott',
#  'Nat King Cole',
#  'Billy Vaughn',
#  'Johnny Tillotson',
#  'Frankie Avalon',
#  ...]

# %% [markdown]
# Ok we've managed to clean up our data, so that we now have useful artist names. The next step is to remove duplicates. To do this we'll create a dictionary of artists and utilize the unique key property of dictionaries to make sure our artist names are unique.

# %%
artist_dict = {name: 0 for name in artist_names}

# %% [markdown]
# We can now see how many duplicates we eliminated by checking the length of the two collections.

# %%
artist_names_len = len(artist_names)
artist_dict_len = len(artist_dict.keys())
print(f'Artist names has {artist_names_len} values.')
print(f'Artist dict has {artist_dict_len} values.')
print(f'We eliminated {artist_names_len - artist_dict_len} duplicate artist names.')
# Out:
# Artist names has 314500 values.
# Artist dict has 7188 values.
# We eliminated 307312 duplicate artist names.

# %% [markdown]
# Now that we have a collection of unique artist names the next step is to fetch the genres for those artists from the Spotify API. This is so that we can correlate the genre of an artist with their songs and eventually do our analysis.

# %%
# First get auth token for spotify API
import spotipy
import spotipy.util as util

username = 'slotterback' # using my spotify account
scope = 'user-read-private'
client_id = '6ed1f612bf9a487c9d0f7048115291d3'
redirect_uri = 'http://localhost/'
from secrets import SPOTIFY_API_KEY
client_secret = SPOTIFY_API_KEY()
token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
token
# Out:
# 'BQAatscKcDNoAl3Eo3-TTtcw1q1TIVSKfvL5v4veQV0RCIp6PEk-iN0J7ycQPkoKIO0FDutdqkGaGN0rO5rNyDgkDaZUOq7X0Ft08h6eyORc4SVhW5N-1qQh48nlVgE_oxl9_Ob_TZobxqlLLIRLRlf7Ofpk0YS1HRE'

# %%
sp = spotipy.Spotify(auth=token)
artist_names_to_ids = {}

for artist in artist_names:
    results = sp.search(q='artist:' + artist, type='artist')
    result_items = results['artists']['items']
    id = None
    for items in result_items:
        if items['name'] == artist:
            print(f"Found artist {artist}, Id: {items['id']}")
            artist_names_to_ids[artist] = items['id']
            break
    
artist_names_to_ids
# Out:
# Found artist Ricky Nelson, Id: 73sSFVlM6pkweLXE8qw1OS
# Found artist Domenico Modugno, Id: 4llklDtTTyMYMY2LfFOkTI
# Found artist Bobby Darin, Id: 0EodhzA6yW1bIdD5B4tcmJ
# Found artist Kalin Twins, Id: 6LXtFndRkOihPIa2dWY3FH
# Found artist Jack Scott, Id: 4ucP0bNegd7Q4ewdOKIBfz
# Found artist Elvis Presley, Id: 43ZHCT0cAZBISjO8DG9PnE
# Found artist Duane Eddy, Id: 1I5Cu7bqjkRg85idwYsD91
# Found artist Jimmy Clanton, Id: 2XZXvrqedRMiKv6UWjAT4B
# Found artist The Coasters, Id: 3QZKZBEmr54lAVI5XvmjnM
# Found artist Pat Boone, Id: 7fmKtIgmxqNEKjATioVNsu
# Found artist Peggy Lee, Id: 602DnpaSXJB4b9DZrvxbDc
# Found artist The Elegants, Id: 7bNoMfBqbaLJrfH3Vw1q6L
# Found artist Frankie Avalon, Id: 5zNOI87gG4RttFmYAZWaxQ
# Found artist Doris Day, Id: 3ESG6pj6a0LvUKklENalT6
# Found artist The Danleers, Id: 1W0oUYvRe6jjI2SuaiigFv
# Found artist Patti Page, Id: 4nZN9kln8toEzOifhWG2uF
# Found artist Jody Reynolds, Id: 4j07I8NDDAMIy4BWc6aqOj
# Found artist The Olympics, Id: 3KtW4xANJkgfEnFgMxaj8h
# Found artist Johnny Cash, Id: 6kACVPfCOnqzgfEF5ryl0x
# Found artist Jerry Butler, Id: 0U2mUJuJkthantMGmsJygP
# Found artist Buddy Knox, Id: 0b5Tz3szM4KK8esFKV2Zsb
# Found artist Jimmie Rodgers, Id: 0Y0ZlznP6vzTS1qAm5dvTN
# Found artist Bobby Freeman, Id: 5oMWW19j0AXl7Sy4Xn9rmg
# Found artist Johnny Mathis, Id: 21LGsW7bziR4Ledx7WZ1Wf
# Found artist The Four Lads, Id: 3stlWzoChlEtbdZAz6CNC3
# Found artist Perry Como, Id: 5v8jlSmAQfrkTjAlpUfWtu
# Found artist Chuck Willis, Id: 21uawITknPcgjwdJuvpcGE
# Found artist The Crickets, Id: 4r7JUeiYy24L7BuzCq9EjR
# Found artist Bobby Day, Id: 4SLfKHcufUqU46DiTAHIsj
# Found artist The Everly Brothers, Id: 4ACplpEqD6JIVgKrafauzs
# Found artist Connie Francis, Id: 3EY5DxGdy7x4GelivOjS2Q
# Found artist Don Gibson, Id: 4xcYVPssil6vbG6tq3W43S
# Found artist Dean Martin, Id: 49e4v89VmlDcFCMyDv9wQ9
# Found artist Dean Martin, Id: 49e4v89VmlDcFCMyDv9wQ9
# Found artist Buddy Holly, Id: 3wYyutjgII8LJVVOLrGI0D
# Found artist Jimmie Rodgers, Id: 0Y0ZlznP6vzTS1qAm5dvTN
# Found artist Robin Luke, Id: 6BlIMhCsEbMvvrLhMcOHkn
# Found artist The Everly Brothers, Id: 4ACplpEqD6JIVgKrafauzs
# Found artist Bobby Freeman, Id: 5oMWW19j0AXl7Sy4Xn9rmg
# Found artist Jim Reeves, Id: 2Ev0e8GUIX4u7d9etNLTXg
# Found artist Nat King Cole, Id: 7v4imS0moSyGdXyLgVTIV7
# Found artist Sheb Wooley, Id: 2dOTS74R4yPISc7AVU9QzD
# Found artist The Slades, Id: 0j0Z5OJJ0kKHcmy1zIujYA
# Found artist Clyde McPhatter, Id: 4WL6MC4jDW7w7K9hfc4MVS
# Found artist Bobby Hendricks, Id: 23j9dIV7tltqbu7XAGwll9
# Found artist Faron Young, Id: 6uvq6FeVsmhOWfJHxVNeBL
# Found artist Eddie Cochran, Id: 1p0t3JtUTayV2wb1RGN9mO
# Found artist Bobby Day, Id: 4SLfKHcufUqU46DiTAHIsj
# Found artist Elvis Presley, Id: 43ZHCT0cAZBISjO8DG9PnE
# Found artist Jack Scott, Id: 4ucP0bNegd7Q4ewdOKIBfz
# Found artist Pat Boone, Id: 7fmKtIgmxqNEKjATioVNsu
# Found artist The Drifters, Id: 1FqqOl9itIUpXr4jZPIVoT
# Found artist Gerry Granahan, Id: 4HjYPDDEhqsK7pklKeVWj0
# Found artist Dion, Id: 15FyiY3ChN0QRspHIQYq0W
# Found artist Sam Cooke, Id: 6hnWRPzGGKiapVX1UCdEAC
# Found artist Bobby Hamilton, Id: 4KMie4yaFEDP1jD0U6udiS
# Found artist Dean Martin, Id: 49e4v89VmlDcFCMyDv9wQ9
# Found artist Toni Arden, Id: 3f47kMra4vxv9McXckx3up
# Found artist Jerry Lee Lewis, Id: 2zyz0VJqrDXeFDIyrfVXSo
# Found artist The Platters, Id: 6KWcxMWVNVIYbdOQyJtsSy
# Found artist Jimmy Bowen, Id: 6nUcMkLeIkY6By8FS5vj0V
# Found artist Lee Andrews, Id: 3mFuZPYNpQfxCrwK3gg526
# Found artist Paul Anka, Id: 7ceUfdWq2t5nbatS6ollHh
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1e7ad449ad94> in <module>()
#       2 artist_names_to_ids = {}
#       3 for artist in artist_names:
# ----> 4     results = sp.search(q='artist:' + artist, type='artist')
#       5     result_items = results['artists']['items']
#       6     id = None
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     283     def recv_into(self, *args, **kwargs):
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#     287             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:
